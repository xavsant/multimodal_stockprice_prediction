# %%
#>=50% of annotators agreed on the financial sentiment 
from pathlib import Path
import pandas as pd

file_path = r'C:/Users/Tammy/Documents/GitHub/multimodal_stockprice_prediction/data/clean/stock_text_data/Apple_Inc_text_data.csv'
# Load the CSV file with the specified encoding and column names
df = pd.read_csv(file_path,encoding='utf-8')

import re
# Cleaning function
def clean_text(text):
    # Remove non-ASCII characters
    text = re.sub(r'[^\x00-\x7F]+', '', text)

    # Convert to lowercase
    text = text.lower()

    # Remove punctuation and special characters (except spaces)
    text = re.sub(r'[^\w\s]', '', text)

    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
# Check the first few rows of the data
df.head()
# Out:
#                    pub_date  \
# 0  2015-04-07T09:17:59+0000
# 1  2015-04-14T20:46:01+0000
# 2  2015-04-13T22:00:31+0000
# 3  2015-04-22T19:42:26+0000
# 4  2015-04-01T10:21:53+0000
#
#                                             abstract  \
# 0  Want to work at Amazon, Apple or McKinsey? Som...
# 1  Get recommendations from New York Times report...
# 2  The business unit will partner with companies ...
# 3  With superstars first in line, Apple appears t...
# 4  In an industry that avoids controversy, the he...
#
#                                            lead_para  \
# 0  With some 13,000 graduate schools of business ...
# 1  Get recommendations from New York Times report...
# 2  IBM is taking its Watson artificial-intelligen...
# 3  Two weeks ago, Pharrell Williams posted an Ins...
# 4  The technology industry’s leaders have found t...
#
#                                             headline doc_type section_name  \
# 0  M.B.A. Programs That Get You Where You Want to Go  article    Education
# 1                                 What We’re Reading  article        Blogs
# 2  IBM Creates Watson Health to Analyze Medical Data  article   Technology
# 3  What’s That on Beyoncé’s Wrist? Let Me Guess ....  article        Style
# 4  Daily Report: Tech Leaders Come Together to Op...  article   Technology
#
#   type_of_material  rank                                            web_url
# 0             News     7  https://www.nytimes.com/2015/04/12/education/e...
# 1             News    13  https://news.blogs.nytimes.com/2015/04/14/what...
# 2             News     8  https://bits.blogs.nytimes.com/2015/04/13/ibm-...
# 3             News     1  https://www.nytimes.com/2015/04/23/style/whats...
# 4             News     3  https://bits.blogs.nytimes.com/2015/04/01/dail...

# %%
#reformat date
# format datetime again
df['pub_date'] = pd.to_datetime(df['pub_date']) 
df['pub_date'] = df['pub_date'].dt.date

# %%
#cleaning
df['abstract'] = df['abstract'].apply(clean_text) # change this line for abstract

# %%
# Select only the 'pub_date' and 'headline' columns
df_new = df[['pub_date', 'abstract']] #change this line for abstract
  
# Check the new DataFrame
df_new.head()
# Out:
#      pub_date                                           abstract
# 0  2015-04-07  want to work at amazon apple or mckinsey some ...
# 1  2015-04-14  get recommendations from new york times report...
# 2  2015-04-13  the business unit will partner with companies ...
# 3  2015-04-22  with superstars first in line apple appears to...
# 4  2015-04-01  in an industry that avoids controversy the hea...

# %%
#set up gemini to process textual templates
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()
# Load environment variables from the .env file
API_KEY = os.getenv("API_KEY")
client = genai.Client(api_key=API_KEY)#insert api key

# %%
system_instruction = (
    "You are a financial analyst and an expert in detecting sentiment in financial news."
)

# %% [markdown]
# ## Function to call Gemini API

# %%
from google.genai import types
import json
# Function to get sentiment based on model output
def gemini_predict(prompt):
    try:
        # Generate content from the model
        response = client.models.generate_content(
            model='gemini-2.0-flash-lite', 
            contents=prompt,
            config=types.GenerateContentConfig(
            system_instruction=system_instruction,
            max_output_tokens=60,  # Label only
            temperature=0.5,      # More flexibility
            top_k=5,              # Limit to top 5 choices
            top_p=0.7,            # Consider tokens covering 70% probability mass
            response_mime_type='application/json',
            stop_sequences=['}']   # No stop sequence to avoid premature stops
            )
        )
        
        response_text = response.text.strip()
        
        # Attempt to fix incomplete JSON by appending a missing closing brace
        if not response_text.endswith('}'):
            response_text += '}'
        
        # Attempt to parse JSON
        try:
            response_json = json.loads(response_text)  # Parse JSON
            sentiment = response_json.get("Sentiment", "").strip()
            
            if sentiment not in ['Positive', 'Negative', 'Neutral']:
                sentiment = 'Neutral'
            
            return sentiment
        
        except json.JSONDecodeError:
            print(f"JSON Parsing Error. Response: {response_text}")
            return 'Error'
    
    except Exception as e:
        print(f"API Error: {e}")
        return 'Error'

# %% [markdown]
# ## Experiment with few-shot prompting

# %%
def find_sentiment_few_shot(text):
    prompt = f"""
    Classify the sentiment of the financial abstract as 'Positive', 'Negative', or 'Neutral'. 
    Use 'Neutral' only if truly unclear. Be decisive—choose 'Positive' or 'Negative' whenever possible.

    Return the result in JSON format:

    Example:
    {{ "Sentiment": "Positive" }}

    Example 1:
    Abstract: "Company Close to Finalizing Its 40 billion dollar funding." 
    Sentiment: Positive

    Example 2:
    Abstract: "Trump blocks 10% of funds for key agency in US-China Tech Race."
    Sentiment: Negative

    Example 3:
    Abstracte: "Why Company B could be a key to a Company C's Deal."
    Sentiment: Neutral

    Example 4:
    Abstract: "Artificial intelligence boom might help mitigate some tariff pain."
    Sentiment: Neutral

    Example 5:
    Abstract: "Major banks face regulatory hurdles, impacting earnings outlook."
    Sentiment: Negative

    Example 6:
    Abstract: "Company’s $32 billion deal may signal a turning point for slow IPO, M&A markets."
    Sentiment: Positive

    Example 7:
    Abstract: "Company X enters a strategic partnership with Company Y to expand its operations in Asia."
    Sentiment: Positive

    Abstract: "{text}"
    Response (in JSON format):
    {{ "Sentiment":"""
    
    sentiment = gemini_predict(prompt)
    return sentiment

# %%
def apply_without_delay(df, sentiment_column):
    sentiment_list = []
    
    for idx, abstract in enumerate(df[sentiment_column]):
        print(f"Processing {idx + 1}/{len(df)}: {abstract}")  # Progress indicator
        
        sentiment = find_sentiment_few_shot(abstract).lower()  # Gemini prediction in lowercase
        sentiment_list.append(sentiment)
    
    # Add Gemini's predictions while keeping original labels intact
    df['gemini_sentiment'] = sentiment_list
    return df

# %%
df_new =  apply_without_delay(df_new, 'abstract')
print(df_new[['pub_date', 'abstract', 'gemini_sentiment']])
# Out:
# Processing 1/2143: want to work at amazon apple or mckinsey some business schools have impressive records placing graduates in certain fields and even companies
# Processing 2/2143: get recommendations from new york times reporters and editors highlighting interesting stories from around the web in this installment great reads from stacy cowley quentin hardy and others
# Processing 3/2143: the business unit will partner with companies including apple medtronic and johnson johnson offering ibms watson technology as a cloudbased tool at many levels of the health care industry
# Processing 4/2143: with superstars first in line apple appears to be seeking exclusivity by limiting where its watches are sold and who wears them
# Processing 5/2143: in an industry that avoids controversy the heads of several prominent companies including apple and salesforcecom have chosen to pick a battle
# Processing 6/2143: spending seven days learning to use and getting used to the apple watch proved to be a mostly rewarding experience
# Processing 7/2143: the itunes software can automatically sync with ipads iphones and ipod touch players but even if the feature is enabled in itunes a few conditions apply
# Processing 8/2143: laurence d fink chief of blackrock the worlds largest asset manager warns of harm in dividends and stock buybacks
# Processing 9/2143: when apps are streamlined and firstgeneration bugs are fixed the apple watch has the potential to be a lifechanger with video
# Processing 10/2143: tips for time warner cable customers who want to use their iphones to manage dvr recordings
# Processing 11/2143: apple ibm and japan post are partnering to provide a technology service for older adults the venture reflects the larger ambitions of each company
# Processing 12/2143: mobile apps can be used to summon a car or order food with a simple tap but making a charitable donation is not as easy
# Processing 13/2143: when apple introduces its new tv box this summer the remote control will gain a touch pad and also be slightly thicker than the current version
# Processing 14/2143: get recommendations from new york times reporters and editors highlighting interesting stories from around the web in this installment great reads from john branch lynda richardson and others
# Processing 15/2143: the purchase further bolsters apples mapping technology and services
# Processing 16/2143: apple is boosting the profile of two designers richard howarth and alan dye under longtime design head jony ive who gains the new title of chief design officer
# Processing 17/2143: get the most out of speechrecognition mobile assistants also how to use speedtest websites to measure broadband speeds
# Processing 18/2143: the federal court also ruled that the iphones overall look could not be protected and part of the 930 million in damages must be recalculated
# Processing 19/2143: will the apple watch become as indispensable on the road as a passport siri wont say but we will
# Processing 20/2143: times insider talked to andrew phelps a product manager and eric bishop a mobile editor about the timess apple watch news app
# Processing 21/2143: the retail executive angela ahrendts says that the phantom a nonapple wireless speaker which starts at 1990 will receive prominent display treatment
# Processing 22/2143: james b comey told senators that one of the attackers in a recent shooting in garland tex exchanged 109 messages with an overseas terrorist that investigators could not read
# Processing 23/2143: despite a starry cast and stellar reviews the film did poorly and silicon valley may be partly to blame
# Processing 24/2143: faced with proposed crackdowns on encrypted communications after terrorist attacks in paris and california apple argued that lawmakers calling for such access do not understand the technical challenges
# Processing 25/2143: you may have a few other troubleshooting steps available if the rebuild command under the mailbox menu has not resolved the problem
# Processing 26/2143: the composer daniel pemberton discusses how the soundtrack came together for the danny boyle film steve jobs
# Processing 27/2143: the new streaming service apple music will show a film of ms swifts concert in australia part of her world tour promoting her latest album
# Processing 28/2143: the split view feature lets you work in two apps at once without having to fuss with windows sizes or placement
# Processing 29/2143: after wearing an apple watch for eight months a times white house correspondent is convinced that smartwatches will eventually be considered essential
# Processing 30/2143: the speedy adoption of new technology is increasingly seen as the key to corporate success according to the annual innovation scorecard from the boston consulting group
# Processing 31/2143: apples smart keyboard was designed for its newer larger ipad pro tablet but there are cheaper alternatives
# Processing 32/2143: the deal in a huge digital market may give a boost to apple pay which lets users pay for goods by holding a mobile device near a credit card reader
# Processing 33/2143: the american technology company reached a deal after an inquiry into whether it had moved revenue from its italian operations through an irish subsidiary
# Processing 34/2143: apple unveiled its best apps list for 2015 featuring what the company deems the most innovative and top software downloads of the year
# Processing 35/2143: it does not appear that criticism of the lack of inclusion in the tech industrys work force will dissipate anytime soon
# Processing 36/2143: if you have reached the end of the free threemonth trial of the streaming service and find it is not for you heres how to stop the monthly bills
# Processing 37/2143: the top free application in apples app store there for much of last week wasnt a mobile game or a social network but a tool of protest
# Processing 38/2143: the latest technology is stuck in the oldest stereotypes
# Processing 39/2143: samsung has agreed to pay apple 548 million to settle a patent dispute but their legal battle continues
# Processing 40/2143: one executive jeff williams was promoted to the job of chief operating officer a position that had gone unfilled since 2011
# Processing 41/2143: james b stewart on cnbc discusses why apple became twice as big as microsoft one reason apples willingness to destroy its own products in the interest of innovation
# Processing 42/2143: you probably didnt know about these five features hidden in the iphones ios 8 operating system use them and youll be using your phone like a pro
# Processing 43/2143: like ibm in the 1980s the stock market giant has room to grow but there are early signs of the end of its dominance
# Processing 44/2143: apple increasingly reliant on china for growth reports on monday ford will post earnings on tuesday and fiat chrysler on wednesday on thursday tesla is expected to announce two new battery products
# Processing 45/2143: even with an upgrade there are several ways to work with microsoft office files also backing up data on an amazon fire tablet
# Processing 46/2143: select destination fashion boutiques around the world have their own stock and will be offering the watch for sale at the end of the week
# Processing 47/2143: the hbo now app which lets viewers see the networks shows without a standard cable plan represents a big change from just a few years ago
# Processing 48/2143: apple watch began shipping friday what you need to know about the gadget
# Processing 49/2143: american technology companies are no strangers to antitrust challenges by european regulators but the cost has tended to be measured in money and time not business practices
# Processing 50/2143: more than onequarter of the companys revenue last quarter came from china which is becoming an increasingly vital part of apples business
# Processing 51/2143: get recommendations from new york times reporters and editors highlighting interesting stories from around the web in this installment great reads from john branch dan levin and others
# Processing 52/2143: plus gisele retires again cannes is antiselfies and more from the week in style
# Processing 53/2143: the mac can install any updates it finds when it checks in daily with apples servers
# Processing 54/2143: despite all the mortal threats it faces this continent could yet represent a beacon of hope engendered by a spirit of collaboration
# Processing 55/2143: pressure is mounting for american tech companies including google to stop using complex tax structures and pay more on their european operations
# Processing 56/2143: you can send the message to someone not in the original conversation by taking a couple of steps
# Processing 57/2143: android is the most popular operating system in the world by far but it is under siege by lowend upstarts and fares poorly versus apples ios in ad revenue
# Processing 58/2143: the apple watch does exactly what i wanted it to do helps me to connect when i need to and disconnect when i dont
# Processing 59/2143: how to take screenshots on a windows tablet also how to use iphoto after the latest mac update replaces it with a different app
# Processing 60/2143: google is set to unveil a payments initiative for merchants and a refashioned consumer app while its rival reportedly plans a rewards program for apple pay
# Processing 61/2143: in case there werent already enough books or movies about steve jobs its time to get ready for more
# Processing 62/2143: for the first installment of his new column ts critic at large jody rosen considers the cultural history of the gadget everyones talking about
# Processing 63/2143: ms swifts victory in a oneday battle against apple this week showed she has a rare power to influence the music business
# Processing 64/2143: this weeks business news will include apples conference for software developers gms annual meeting with investors and the european parliaments vote on the plans for a landmark trade deal
# Processing 65/2143: apple is set to unveil new app tools for its watch on monday as well as software updates and a streaming music service missing will be the apple tv
# Processing 66/2143: mr lowe formerly britains most influential radio jock is in the mix of apples revamped music strategy
# Processing 67/2143: apple music starting at 10 a month will allow users to search for songs and stream them over the internet similar to spotify
# Processing 68/2143: the tech giant has managed to keep government regulators at bay and to appease a pop star angry over apple music but the true test remains how well the companys products work
# Processing 69/2143: the attorneys general of new york and connecticut are investigating apples negotiations with music companies in search of potential antitrust violations
# Processing 70/2143: some independent booksellers gain a portion of ebook sales through partnerships with bigger ebookstores like kobo and amazon source
# Processing 71/2143: before apples new plan to increase app production takes off try some of these existing offerings including a realtime weather app and a sevenminute workout app
# Processing 72/2143: ms swifts victory in a oneday battle against apple this week showed she has a rare power to influence the music business
# Processing 73/2143: the risk is less that cars from technology giants would destroy mercedesbenz or bmw but rather that carmakers would become mere providers of hardware
# Processing 74/2143: we asked readers to send us questions about apples newest smartphones the iphone 6s and 6s plus which go on sale friday here are some answers
# Processing 75/2143: a reporter offers first impressions of the coming iphone ipad and apple tv
# Processing 76/2143: this week shareholders of charter communications and time warner cable vote on the proposed merger the chinese president visits the united states and janet yellen delivers a speech about inflation
# Processing 77/2143: apps recommended for watchos 2 include the forecaster carrot weather citymapper for various modes of travel and the recording program just press record
# Processing 78/2143: the premier met with technology executives over the weekend to seek ideas and assistance in bringing his nation fully into the digital world
# Processing 79/2143: the worlds richest tech company introduced new iphones an overhauled apple tv and a jumbosize ipad on wednesday
# Processing 80/2143: as portrayed by michael fassbender acting from a script written by aaron sorkin mr jobs is part genius and part monster a man who seems to go out of his way to be cruel but who has a genius understanding of technology and marketing
# Processing 81/2143: voice recognition and artificial intelligence have improved so fast that we are nearing ambient computing or robotic assistants that are always on hand
# Processing 82/2143: apple is still working out whether it will make a selfdriving car an electric car 0r a combination of the two a person with knowledge of the product said
# Processing 83/2143: citing customer privacy apple and google have enabled wrongdoers to hide their criminal activity
# Processing 84/2143: the executive eddy cue said he was thrilled with the early results for the streaming service which was introduced on june 30
# Processing 85/2143: how to see if a mac has been infected and what to do about it plus changing uppercase to lowercase and vice versa in microsoft word
# Processing 86/2143: turning off the default motion tracking function defending against pc scams and requesting order history reports from amazon
# Processing 87/2143: if the market doesnt start to turn around soon all the giant fundraising rounds may be in limbo as well as the life of some of todays startups
# Processing 88/2143: facebook is wading into the increasingly crowded field of digital personal assistants with a new offering called m
# Processing 89/2143: many readers of a recent editorial were dissatisfied with rented cable boxes but some had already bought their own and others have given up cable entirely
# Processing 90/2143: the early audiencebuilding of both users and developers is crucial for microsoft and the early results look encouraging
# Processing 91/2143: microsoft collects personal data on users of windows 10 but privacy controls can be adjusted
# Processing 92/2143: the sudden and rapid selloff across global markets has caught many on wall street off guard
# Processing 93/2143: unlike the nasdaq composite index at its dotcom peak in 2000 todays index has companies that are more mature and less concentrated in technology
# Processing 94/2143: the new system will not have a lower price than its competitors and wont offer a free version supported by ads
# Processing 95/2143: european officials proposed new disclosure rules meant to make it more difficult for countries to work out special taxavoidance deals with multinationals
# Processing 96/2143: this has nothing to do with apple we can still be friends my animus is for the smartwatch and what it will do to us things are too complicated as it is
# Processing 97/2143: in an industry that avoids controversy the heads of several prominent companies including apple and salesforcecom have chosen to pick a battle
# Processing 98/2143: a wristwatch but not as we know it
# Processing 99/2143: once you wore a barrel to signify poverty now you launch a kickstarter campaign
# Processing 100/2143: with its vast share of the industrys profits apple was the target at the mobile world congress where samsung and microsoft are trying to position their products as business tools
# Processing 101/2143: with the rollout of the apple watch comments have flowed in from around the world
# Processing 102/2143: technology from apple google blackberry and motorola is increasingly allowing users to send texts and make phone calls from almost any device
# Processing 103/2143: a quarter in which apple sold an enormous number of iphones also saw compliance with workweek rules decrease
# Processing 104/2143: the apple watch is scheduled to debut in april a bit later than the company had hoped because of technology challenges
# Processing 105/2143: the move comes just a few months after the release of apple pay apples mobile payments product
# Processing 106/2143: both kantar worldpanel and canalys research firms that track global smartphone sales said apples mobile operating system gained market share in china at the expense of googles android
# Processing 107/2143: learn about the differences between amazon fire tv and fire tv stick besides price and also discover how to transfer airline boarding passes between iphones
# Processing 108/2143: tips on how to archive gmail messages to tidy up your inbox and solutions for when your laptop battery begins to fade
# Processing 109/2143: how to use twostep verification to guard against unauthorized access to your email
# Processing 110/2143: tips on how to transfer photographs into iphoto on your mac and advice for connecting to a virtual private network from a mobile device
# Processing 111/2143: the company plans to invest 2 billion in creating a data center in mesa ariz after it dropped plans to produce sapphire a hardened and light material at the facility
# Processing 112/2143: the computer giant was ordered to pay 5329 million to smartflash which is based in a building down the street from where the trial was held apple plans to appeal
# Processing 113/2143: the unusual move for amazon is not about retail sales but rather about shoring up its fire tv streaming devices which are crucial to its vision for the future
# Processing 114/2143: its cheaper to own your smartphone outright but earlyupgrade plans from apple and wireless carriers offer some other advantages
# Processing 115/2143: upgrading from an older version of windows can sometimes damage the device drivers including the one for the sound card but the fix can be simple
# Processing 116/2143: despite strong sales of the new iphone models apples forecast for the holiday season traditionally its strongest quarter was cautious
# Processing 117/2143: the automaker had a net loss of 184 billion in its third quarter an indicator of how the fallout from its diesel deception could hurt its bottom line
# Processing 118/2143: frank and ross set the ingenuity of the martian and genius of steve jobs against our gloomy national mood a world apart beasts of no nation offers a vivid illustration of brutality
# Processing 119/2143: a balenciaga appointment urban volunteers and keanu for neiman marcus
# Processing 120/2143: apple and google along with other technology companies made it into the top 10 of interbrands annual report
# Processing 121/2143: the ebooks can indeed be lent but for only 14 days and only once
# Processing 122/2143: security experts were still looking through looppays systems but said there was no indication that samsungs systems had been infiltrated
# Processing 123/2143: microsoft is embracing a fragmented view of the future in which no single device or even single category of devices reigns supreme the plan is rife with risk but that doesnt mean it cant work
# Processing 124/2143: two tests were carried out with ad blockers one to measure how much loading times were improved and the second to study battery life
# Processing 125/2143: the obama administration has concluded that it is not possible to give american agencies a back door to encrypted smartphone data without creating an opening for other nations criminals and terrorists
# Processing 126/2143: in a conflict of personalization and privacy personalization has triumphed
# Processing 127/2143: apple designed its device which will be available for preorder on april 10 to suit the tastes of various users from fitness buffs to collectors of luxury watches
# Processing 128/2143: the dow dates from a computerfree era when working out the average of 30 stock prices counted as added value including apple in the index was overdue
# Processing 129/2143: apple brass including its chief timothy d cook are throwing their weight behind the unauthorized biography of mr jobs which goes on sale tuesday
# Processing 130/2143: employment figures will come on monday for the eurozone and on friday for the united states automakers will report their february sales
# Processing 131/2143: apple will demonstrate its new smartwatch on monday hsbcs chief will testify in britains parliament and greece will detail its reform plans
# Processing 132/2143: the app will offer brief news articles written specially for users of the watch which will be available at the end of april
# Processing 133/2143: in an industry where artists seldom have direct control over how their work is consumed musicians will be the majority owners of the company tidal
# Processing 134/2143: apple and google said they were releasing patches to fix the problem which results in part from 1990s american technology export restrictions
# Processing 135/2143: apple and google are using their technology domination to take over car dashboards someday they could try to build entire vehicles
# Processing 136/2143: some of the nations banks are privately complaining that apple pay may not be so great after all but the banks may largely have themselves to blame
# Processing 137/2143: using your phone as a gps unit is handy but can run the battery down always pack a mobile phone charger
# Processing 138/2143: the company is aggressively adding to its renewable energy sources a point of pride for its chief executive timothy d cook
# Processing 139/2143: tips on how to remove a file or folder from microsofts cloudstorage service and advice on how to confirm that your computers firewall is turned on
# Processing 140/2143: in the coming months dealerships around the country will begin selling vehicles capable of running android and applecompatible dashboard systems
# Processing 141/2143: the bus drivers who transport workers to the campuses of six silicon valley employers voted to join the teamsters to negotiate better working conditions and wages
# Processing 142/2143: in the coming months auto dealerships around the country will begin selling vehicles capable of running android and applecompatible dashboard systems
# Processing 143/2143: president obamas budget calls for a lower overall tax rate but also for a onetime 14 percent tax on all cash sitting overseas
# Processing 144/2143: app pins aims to do for smartphone apps what pinterests service has done for photos recipes and many other types of websites in short the service is a type of digital corkboard that lets visitors save or pin items they like or places they want to go
# Processing 145/2143: apples share of the industrys profits increased while samsung the only other company turning a profit on its phones saw sales shrink
# Processing 146/2143: the company has collected about 200 people over the last few years to develop technologies for an electric car according to two people with knowledge of the companys plans
# Processing 147/2143: apples new financing plan a lease in all but name makes available for phones a payment structure that is more familiar in the auto market
# Processing 148/2143: it would seem that the demise of the mechanical watch would be fast approaching but highend timepieces are doing just fine
# Processing 149/2143: global preorders for the companys iphone 6s and iphone 6s plus are on track to beat last years sales of 10 million new iphones in the first weekend last year
# Processing 150/2143: if your computer did not come with a microphone you can command microsofts virtual assistant with an external or headset microphone
# Processing 151/2143: apps for the new devices and updated operating system include games microsofts office suite the flipboard news aggregator and content blockers
# Processing 152/2143: the company has made some small and useful improvements but this is still a product of limited use for most people
# Processing 153/2143: apple is holding a product event this wednesday that is set to be the talk of the tech world as the company once again mixes new products with theater
# Processing 154/2143: volatility buffers may have deepened market turmoil 3 nomura traders charged media general to buy meredith corporation
# Processing 155/2143: the app released through apple and android stores tries to offer a blend of digital mischief and communication that has come to be a hallmark of senator rand pauls online campaign
# Processing 156/2143: this week china will report on its economy puerto rico may strike a deal to restructure its debt and stephen colbert will start on cbss the late show
# Processing 157/2143: mr rogerss departure comes as a surprise the music streaming service he led began only two months ago
# Processing 158/2143: recovering discarded photos before they are gone for good and shutting down misbehaving applications
# Processing 159/2143: compton a soundtrack had 25 million streams worldwide in its first week on apples new service but is expected to open in second place in the united states
# Processing 160/2143: how to protect from a vulnerability by which android devices could be compromised by malicious code also figuring out the ios step counter
# Processing 161/2143: reports of amazon layoffs a new digital assistant service and artificial intelligence in general
# Processing 162/2143: the pharmacy chain is the latest retailer to accept the mobile payments which involve little more than waving a phone to conduct a transaction
# Processing 163/2143: in this aging bull market investors are showing signs of a sea change in their attitudes
# Processing 164/2143: on some days market psychology can count for more than longterm fundamentals pushing panicked investors to sell
# Processing 165/2143: the chief executive of apple said business was booming in china where the company has long laid the groundwork to reap big sales
# Processing 166/2143: its compatible with both ios and android and it does some useful things but its not without downsides
# Processing 167/2143: the new streaming service which will cost 10 a month will compete with spotify and be offered alongside an overhauled itunes radio
# Processing 168/2143: microsoft is allowing those currently running windows 7 or 81 to reserve a copy of its newest operating system more than a month before its released
# Processing 169/2143: the company voluntarily issued the recall in the united states and canada after receiving complaints that the products can overheat
# Processing 170/2143: the sporty rubber strap has evolved into a haute fashion statement wearing one is like wearing sneakers with a thom browne suit
# Processing 171/2143: seeking meaning in abstract photographic views of earth from orbit or inside a split stone
# Processing 172/2143: when apples chief executive gave a speech on the tech industrys privacy practices he failed to fairly explore the benefits of free adsupported services
# Processing 173/2143: a federal appeals court said it agreed with a 2013 decision that apple conspired with publishers to raise prices for ebooks
# Processing 174/2143: apple announced a new streaming service a newsreader app and improvements to siri apple pay and its operating systems
# Processing 175/2143: ever wonder what the iphones grandparents looked like chances are lonnie mimms has one in the massive collection of vintage computers he keeps outside of atlanta
# Processing 176/2143: burberry is launching a channel on apple music the two companies share a history with apple recruiting burberrys then chief executive angela ahrendts in 2013
# Processing 177/2143: were not creating the new businesses we should be and these giants have to be broken up
# Processing 178/2143: also look for a review of apps for windows 10 ahead of the presentation of the newest iphone next week
# Processing 179/2143: these organizations thrived in the 1980s and 90s and were the backbone of apples faithful but for some members the tech giants success has been hard to reconcile
# Processing 180/2143: patrick drahi a potential player in us cable decoding steve jobs arctic oil bonanza still frozen
# Processing 181/2143: first impressions of the collaboration between two iconic brands
# Processing 182/2143: the tech world has focused mostly on news related to china so far this week with the main tech news event apples unveiling of new products set to take place on wednesday
# Processing 183/2143: apple watch herms clooney as arm candy and more
# Processing 184/2143: the latest generation of iphones has several important new features and improvements upon screens and processors are they enough to justify getting a new phone depends on how long youve held on to the last one
# Processing 185/2143: how to get your windows 10 operating system to recognize a printer plus the internet speed necessary for smooth highdefinition streaming on apple tv
# Processing 186/2143: and how to get itunes on a pc play over bluetooth speakers
# Processing 187/2143: greece is expected to pay 425 billion euros due on bonds later this week earnings reports will be announced by apple morgan stanley credit suisse and general motors
# Processing 188/2143: if the new service is successful it could deliver billions of dollars in revenue to the music industry and establish streaming music as a stable business
# Processing 189/2143: some technology pundits have declared the device a flop but apple has a history of using incremental improvements to make its products indispensable
# Processing 190/2143: apples proposal that automakers write apps for technology company software raises concerns about security and safety
# Processing 191/2143: while the quarters phone sales were onethird higher than a year ago at 475 million they fell short of analysts estimates and the stock fell
# Processing 192/2143: stephen joseph first sued in san francisco over graffiti he lost but the city cleaned up the graffiti his latest victory is trans fats he has learned that you can lose in court but carry the day
# Processing 193/2143: also how to move documents and photos to a new computer after switching to windows 10
# Processing 194/2143: some technology pundits have declared the device a flop but apple has a history of using incremental improvements to make its products indispensable
# Processing 195/2143: how to rid the bookmarks menu of a utility you dont use plus browsing with chrome on windows 10 and learning macbook trackpad gestures
# Processing 196/2143: lonnie mimms has been a collector all his life but vintage computers are his real obsession namely ones made by apple by his own estimate he has invested more than a million dollars in his computer collection
# Processing 197/2143: after a sixweek dalliance with a handsome muchballyhooed new suitor aka the apple watch a writer decides to move on
# Processing 198/2143: for the latest updates from the companys annual developer conference follow two new york times reporters farhad manjoo and brian x chen who will be providing live updates from the keynote address in san francisco
# Processing 199/2143: the beggars group a powerful independent record company and merlin a trade group announced that they reached a licensing deal with apple
# Processing 200/2143: i have a recurring problem with most streamingservice playlists though i keep listening out of animal curiosity for what comes next i am almost never surprised
# Processing 201/2143: at least 715 percent of the revenue from apple music will be paid in royalties but labels and music publishers will not be paid during a threemonth trial
# Processing 202/2143: masters of one of the worlds most revered forms of analog craftsmanship take on the smartwatch
# Processing 203/2143: spotify says that because online streaming services let users listen to anything they want people are increasingly breaking away from rigid genres
# Processing 204/2143: apple is set to unveil new app tools for its watch on monday as well as software updates and a streaming music service
# Processing 205/2143: if apple music is successful it could deliver billions of dollars in revenue to the music industry and establish streaming music as a stable business
# Processing 206/2143: this week data on durable goods orders consumer confidence and economic growth will be released in addition several companies including apple and exxon mobil will report earnings
# Processing 207/2143: despite their very different companies the chief executives of general electric and apple have something in common they believe businesses will increasingly rely upon personalized technology to run their operations
# Processing 208/2143: amazon opens the latest battle against google and apple by banning the sale of its rivals streaming media players
# Processing 209/2143: farhad manjoo is off this week so mike isaac joins deputy tech editor jim kerstetter to discuss googles plan to fold its two operating systems into the android brand
# Processing 210/2143: its plethora of innovations and apps leads me to conclude that the upgraded box is now the best tv streaming device
# Processing 211/2143: shes the highestpaid female executive in the united states but after more than a year at apple shes rarely seen
# Processing 212/2143: the screenwriter says his new movie is not a biopic so true the film simply doesnt understand its subject
# Processing 213/2143: timothy d cook the companys chief executive said the new streaming service had 15 million total users with 65 million paying customers
# Processing 214/2143: apple pay is getting a lift with its adoption by three restaurant chains starbucks kfc and chilis
# Processing 215/2143: the screenwriter talks on why finding entertainment in the failure of others is wrong and how characters from the west wing would respond to donald trump
# Processing 216/2143: amazon prime music available free to prime subscribers has a far smaller catalog than spotify and apple music but it may appeal to families and listeners who dont require all the latest hits
# Processing 217/2143: a look at how the new features in microsofts latest operating system compare with version 81 and what to do if youre getting text messages on your ipad but not your iphone
# Processing 218/2143: a portrait of a volatile boy wonder and his path to technological vanguard
# Processing 219/2143: initial impressions of the apple watch are that it is goodlooking for a smart watch and not hard to use but whether it is yet a necessary purchase remains unsettled
# Processing 220/2143: becoming steve jobs a new biography by brent schlender and rick tetzeli focuses on the period between mr jobss first and second stints as apples leader
# Processing 221/2143: brent schlender and rick tetzeli who wrote becoming steve jobs discuss the evolution of steve jobs and how they won apples cooperation for the unauthorized biography of its former chief executive
# Processing 222/2143: the service which could be announced later this year would offer a bundle of channels that is smaller and cheaper than a typical cable subscription according to people briefed on the plans
# Processing 223/2143: the internal revenue service is not emailing you to request personal information not now not ever
# Processing 224/2143: genius alone didnt bring apple back it took management chops
# Processing 225/2143: the service will cost 1499 a month and will include current and past programming as well as movies
# Processing 226/2143: the apple watch is scheduled to start selling in april but will buyers want it while consumers have shown little interest in smartwatches so far few people wanted tablets or smartphones before the ipad and iphone were released
# Processing 227/2143: the step is a reminder of the soaring valuations among consumerdriven technology and social media companies
# Processing 228/2143: the apple watch is good looking for a smartwatch and not hard to use according to initial impressions but who knows if it is really a necessary purchase
# Processing 229/2143: thirdparty apps and recent operating system updates are often the cause starting the phone in safe mode can help narrow down the search for a culprit
# Processing 230/2143: here are some prominent services offering live tv la carte networks and other ondemand streaming options in the united states
# Processing 231/2143: egypt and more pictures of the day
# Processing 232/2143: apple held an event in san francisco on monday to talk about its latest apps and features including a partnership with hbo and new medical research software
# Processing 233/2143: the new movie about the apple cofounder suggests that the future envisioned by the tech industrys leaders is worth putting up with them
# Processing 234/2143: bernankes frank look at lehman brothers supreme court denies insider trading hearing
# Processing 235/2143: hopstop the transit app owned by apple is no longer available for download but citymapper remains one of the best apps for finding your way in new york city
# Processing 236/2143: tech earnings season is going into full swing with companies including yahoo ibm google and microsoft set to report quarterly results this week their financial data may offer insight into which companies are gaining the upper hand in some tech battles
# Processing 237/2143: the 2016 presidential race is picking up steam so take some control of the information flooding your smartphone while also brushing up on the constitution digitally
# Processing 238/2143: the social media service issued guidance below what wall street was expecting as its new chief executive jack dorsey looks at ways to reignite interest among consumers
# Processing 239/2143: legislative reform is hurting legitimate inventors
# Processing 240/2143: as apple focuses on apps and google pushes the mobile web businesses must grapple with a fragmenting online world
# Processing 241/2143: the app displays an error message instead of news articles possibly in an effort to avoid running afoul of chinese censorship policies
# Processing 242/2143: the most valuable company in the world and a company that aspires to be among the giants both report quarterly earnings on tuesday afternoon one faces big expectations and the other faces genuine concerns about its future
# Processing 243/2143: the company is in talks with banks about a service that would let people use their iphones to send money to one another as easily as they send messages
# Processing 244/2143: setbacks cast harsh light on manhattan prosecutor a rocky quarter for hedge funds marriotts deal to buy starwood hotels
# Processing 245/2143: the move indicates that the german carmaker will continue to invest in advanced technologies despite the burdens of its emissions cheating crisis
# Processing 246/2143: facebook is introducing a new iphone app that lets users sign up for custom notifications from a selection of about 70 news outlets and information providers
# Processing 247/2143: as long as you have an external hard drive large enough to hold your collection you can use it to move your library even between macs and pcs
# Processing 248/2143: ackman takes on berkshire apple plans peertopeer payment service a debate over the feds easy money policies
# Processing 249/2143: flipkart worked with google to create a new mobile website that was unveiled on monday in a move to improve the mobile web experience and steer away from apps
# Processing 250/2143: gaming shopping video and utility apps that have the potential to make your television truly smart
# Processing 251/2143: you can back up the an address book as a vcard file and import it back into the cloud if disaster strikes
# Processing 252/2143: video of the episode showed an employee saying there were fears they might steal something
# Processing 253/2143: sesac a boutique music rights group is purchasing the harry fox agency a move that will allow it to collect fees both when songs are played and when they are sold
# Processing 254/2143: brian x chen the timess consumer technology expert explains why smartphone companies are so interested in what their products are doing to us
# Processing 255/2143: the service brags that its playlists are curated by people not algorithms on the other hand its social network app needs retooling
# Processing 256/2143: enthusiasts think theres always room for new icons but the process for adding fresh emojis is surprisingly complex
# Processing 257/2143: while apples phone sales were onethird higher in the quarter than a year ago at 475 million they fell short of analysts estimates and the stock fell
# Processing 258/2143: facebook and other companies have struggled with how wearers of the device could have a good experience with their apps tailored to a small screen
# Processing 259/2143: different music streaming services have varying costs platforms and catalog sizes see how some of the most popular companies stack up against one another
# Processing 260/2143: in a report about data privacy published by the electronic frontier foundation this week tech companies like yahoo apple and adobe earned top marks while whatsapp and att came in last
# Processing 261/2143: the tech giant has managed to keep regulators at bay and to appease a pop star angry over apple music but the true test remains how well its products work
# Processing 262/2143: the company will be entering a crowded market but its size and reach will be to its advantage
# Processing 263/2143: tips for mirroring your phones display on a mac and how to get desktop notifications from gmail
# Processing 264/2143: square announced a new credit card reader that accepts mobile wallets like apple pay
# Processing 265/2143: when steve jobs returned to apple he saved the company it remains to be seen whether jack dorsey can do the same at twitter
# Processing 266/2143: a conversation between farhad manjoo and vanessa friedman about the appeal and disappointment of apples foray into wearable tech
# Processing 267/2143: ms swift had framed a letter posted to her tumblr page as an explanation for why she was withholding her latest album 1989 from apples new music streaming service
# Processing 268/2143: navigating the new image editing program on the mac and how to quiet a talkative windows computer
# Processing 269/2143: some updates such as security patches are essential but it can make sense to research others before taking the plunge
# Processing 270/2143: more than 13 million iphone 6s and 6s plus phones were sold topping the 10 million iphone 6 and 6 plus devices sold in their first weekend last year
# Processing 271/2143: the efforts to paint steve jobs as either hero or villain miss a larger truth he can be both and still be worthy of acclaim
# Processing 272/2143: government conflicts with apple and microsoft reflect heightened resistance by businesses intent on demonstrating efforts to protect customer information
# Processing 273/2143: the online marketplace will now allow its prime members to download some movies and tv shows to ios and android devices to watch programming offline
# Processing 274/2143: heres what stood out from apples product event on wednesday and a flavor of what happens when you get up close to some of the upgraded gadgets
# Processing 275/2143: the company is about to release its next mobile operating system offering better battery life and a smarter siri
# Processing 276/2143: twitters apps make use of the spellchecking and autocorrection tools built into the operating system on your mobile device
# Processing 277/2143: vying for a spot in living rooms apple which is expected to announce its new system on wednesday may have a tough time luring gamers who use an xbox one or playstation
# Processing 278/2143: timothy d cook apples chief executive discussed civic duty environment and selling to businesses at an event on tuesday
# Processing 279/2143: another mobile payment app enters the fray a genderdiscrimination appeal is dropped and apple unveils new devices
# Processing 280/2143: corporations were right to speak out on this issue they should take the same stand with their campaign spending
# Processing 281/2143: the inexpensive device links a standard audio cable from the music player to a computers usb jack
# Processing 282/2143: the watch is not suited for tech novices it is designed for notificationinundated people who want to manage the way the digital world intrudes on their lives
# Processing 283/2143: get recommendations from new york times reporters and editors highlighting interesting stories from around the web in this installment great reads from quentin hardy jason stallman and others
# Processing 284/2143: the biggest american tech companies face intensifying scrutiny by european regulators with pressure that could potentially curb their sizable profits in the region and affect how they operate around the world
# Processing 285/2143: the technology columnist farhad manjoo asks whether the apple watchs new taptic engine will give us an alternative to constantly checking our phones
# Processing 286/2143: samsung has filed an appeal to the supreme court arguing that the legal framework for design patents is an issue larger than its dispute with apple
# Processing 287/2143: velvet sachet for your contactlens solution computing device smaller than an apple watch glowinthedark pasta maker we have you covered
# Processing 288/2143: the el capitan update includes many enhancements to popular tools and programs but many bugs have also been reported
# Processing 289/2143: until an update to picasa heres a way to get your photos into your computer from usbconnected cameras including iphones
# Processing 290/2143: with the rise of the unicorns it was a year of punchdrunk valuations seamed with anxiety
# Processing 291/2143: abbi jacobson john slattery marcus samuelsson and others on what big thing they chose to pass over in 2015
# Processing 292/2143: apple said it was delaying the release of a software update to apple watch because of a bug in the software
# Processing 293/2143: apps that block all ads are threatening some web publishers livelihoods which in turn could threaten some content on the web
# Processing 294/2143: alex gibneys new documentary subtitled the man in the machine is a merciless anatomy of a complicated public character
# Processing 295/2143: at apples product event on wednesday it is expected to introduce a tv device with more capabilities as the company seeks a bigger presence in homes
# Processing 296/2143: here are our responses to reader queries about the new apple devices introduced at a company event on wednesday
# Processing 297/2143: the smartphone and the larger 6s plus variant took center stage at apples product announcement event but a bigger ipad and a beefedup apple tv had turns in the spotlight
# Processing 298/2143: unlike other tech devices that have become commodities apples iphone remains in demand as both a highly useful item and a status symbol
# Processing 299/2143: live photos which generates a minivideo of a still was fun 3d touch which summons different actions through finger pressure was less useful
# Processing 300/2143: several companies are pressing forward with projects to compete with the smartwatch
# Processing 301/2143: as tech news slowed down ellen pao one of the former partners at kleiner perkins caufield byers said she would drop the appeal in her losing gender discrimination suit citing personal resources
# Processing 302/2143: with the latest earnings reports from microsoft and apple the onceunthinkable became reality apples market capitalization hit 683 billion more than double microsofts 338 billion
# Processing 303/2143: apple google intel and adobe say a new deal has been struck to settle a lawsuit that asserts the companies had agreed not to directly solicit one anothers employees
# Processing 304/2143: with the latest earnings reports from microsoft and apple the onceunthinkable became reality apples market capitalization hit 683 billion more than double microsofts 338 billion
# Processing 305/2143: apple google intel and adobe are said to be offering 415 million to settle accusations that they conspired against their own employees
# Processing 306/2143: the introduction of a largescreen iphone in china helped propel apples profit to 18 billion and its revenue to nearly 75 billion
# ...
# Processing 2047/2143: the agreement at a maryland store the first to unionize raises wages roughly 10 percent over three years and guarantees benefits and severance pay
# Processing 2048/2143: the company faces pressure from governments around the world and complaints from companies that it is still too restrictive
# Processing 2049/2143: the internet giant unveiled the next generation of pixel phones headphones and watches to stand out in a hardware market that has mostly ignored it
# Processing 2050/2143: plus scenes after a ukrainian attack in russia
# Processing 2051/2143: big technology companies show no signs of slowing their spending on artificial intelligence even though a payoff still looks a long way away
# Processing 2052/2143: plus new details on hunter bidens business dealings
# Processing 2053/2143: led by the investment firm thrive capital the new deal would value the artificial intelligence startup at over 100 billion
# Processing 2054/2143: the move tests the european unions new tech competition law which was designed to allow competing app stores
# Processing 2055/2143: after an inquiry by european regulators epic games said apple would allow it to access the software tools necessary to develop a game store
# Processing 2056/2143: do not disturb mode lets smartphone users silence notifications and signals that they may take a while to respond
# Processing 2057/2143: beijing unveiled an annual economic target in line with last years as it looks to refocus on strategically important sectors
# Processing 2058/2143: just when we thought the feud was cooling off openai pulled out the receipts
# Processing 2059/2143: ai fervor has rocketed the chip companys share price upward our columnist asked ai chatbots how big nvidia would become if it kept growing as fast as it had over the past year
# Processing 2060/2143: as the app store approaches its 16th anniversary patchwork rules have turned what was a single store into different shops across many countries
# Processing 2061/2143: the justice departments lawsuit against apple is the latest in a series of regulatory actions that are hitting the tech giant at the same time
# Processing 2062/2143: well see you in court
# Processing 2063/2143: temu shein and streaming and gaming apps looking to break into the us market are spending huge sums to get their wares in front of american consumers
# Processing 2064/2143: to comply with european regulations apple has proposed reducing its commission on app sales while adding new fees and hurdles
# Processing 2065/2143: an oral history of apples groundbreaking 1984 spot which helped to establish the super bowl as tvs biggest commercial showcase
# Processing 2066/2143: the companies that make iphones are bringing their factories to one corner of india to graft them onto a network of manufacturers
# Processing 2067/2143: the tech giant has dropped its plans to develop an electric vehicle but some of the development at the heart of the effort has helped power other products and services
# Processing 2068/2143: companies like meta that could tout their work in the fastgrowing field saw a benefit in their fourthquarter results and won praise from eager investors
# Processing 2069/2143: profits are up and the economy is strong but the tech industry faces two challenges dealing with a frenetic work force expansion in the pandemic and building ai
# Processing 2070/2143: wearables can now track everything from heart rate variability to stride length but access to so much data does not always mean better health
# Processing 2071/2143: plus the apple vision pro hype
# Processing 2072/2143: the iphone makers share price dropped in afterhour trading even though sales and profit topped wall street expectations
# Processing 2073/2143: introducing dj taskrabbit
# Processing 2074/2143: washingtons crackdown on big tech is coming for apple
# Processing 2075/2143: for years apple google meta and others operated unfettered but new laws and regulations have finally compelled them to make major shifts to their products and businesses
# Processing 2076/2143: the justice departments lawsuit against the iphone maker pushes the boundaries of competition rules some experts say that may make winning more difficult
# Processing 2077/2143: after losing two complaints before the us international trade commission apple has stepped up its lobbying to change the agencys practices
# Processing 2078/2143: what is lost when journaling moves into the cloud
# Processing 2079/2143: prosecutors compare their new fight against apple to the seminal case against windows in the 1990s
# Processing 2080/2143: the lawsuit caps years of regulatory scrutiny of apples wildly popular suite of devices and services which have fueled its growth into a nearly 3 trillion public company
# Processing 2081/2143: the inquiries signal the blocs intention to tightly enforce sweeping new competition rules that took effect this month
# Processing 2082/2143: apple said it would appeal the penalty the latest in a series of regulatory setbacks for the tech giant
# Processing 2083/2143: a partnership would extend the long relationship between the companies that has helped deliver everything from maps to search on apples devices
# Processing 2084/2143: billed as the future of computing the 3500 goggles cant replace a laptop for work at times wearing them also made our columnist feel nauseated
# Processing 2085/2143: internal disagreements over the direction of the apple car led the effort to sputter for years before it was canceled this week
# Processing 2086/2143: the car which apple spent billions of dollars researching had been intended as a rival to teslas evs which include autonomous driving features
# Processing 2087/2143: videos many of them stunts or jokes of people wearing apples new virtual reality headset while driving teslas in autopilot mode prompted officials to issue warnings
# Processing 2088/2143: our personal tech columnist tries apples new vision pro and is less than impressed
# Processing 2089/2143: the cases had established the european union as the worlds leading tech watchdog but have since raised questions about its protracted appeals process
# Processing 2090/2143: wolfs a new film starring george clooney and brad pitt was going to get a robust theatrical release but the company is curtailing that plan
# Processing 2091/2143: the taiwanese company has built a manufacturing hub in zhengzhou china for its star customer apple but it is starting almost from scratch in the auto business
# Processing 2092/2143: the criminal charges against pavel durov telegrams founder raised concerns in silicon valley about encryption and the apps approach to privacy and security
# Processing 2093/2143: since 2022 tripp mickle has covered news surrounding one of the biggest technology companies in silicon valley
# Processing 2094/2143: deleting duplicates bad shots and other unwanted files makes it easier to find the good pictures and gives you room to take more
# Processing 2095/2143: programmed to find the fastest route without consideration of literally anything else driving apps endanger and infuriate us on a remarkably regular basis
# Processing 2096/2143: customers in europe may see an influx of new apps and services for making tapandgo purchases
# Processing 2097/2143: who will survive die thrive and how we talked to nearly a dozen top media executives and asked them to predict what lies ahead
# Processing 2098/2143: the 3500 spatial computing device has gathered dust on my shelf can tweaks and upgrades save it from obsolescence
# Processing 2099/2143: apple microsoft and google need more access to our data as they promote new phones and personal computers that are powered by artificial intelligence should we trust them
# Processing 2100/2143: apple and google are getting up close and personal with user data to craft memos summarize documents and generate images
# Processing 2101/2143: major us entertainment companies are hiring a former top fbi official and renewing a push for federal legislation to combat online thievery overseas
# Processing 2102/2143: apple a latecomer to artificial intelligence has struck a deal with openai and developed tools to improve its siri voice assistant which it is set to showcase on monday
# Processing 2103/2143: they really sort of make you feel like its christmas and coachella at the same time
# Processing 2104/2143: the iphone maker which has been slow to embrace artificial intelligence will weave it into the technology that runs on billions of devices
# Processing 2105/2143: tech companies are running low on new experiences to offer us a new ad for the ipad contains revealing hints of where they could go next
# Processing 2106/2143: the companys app store policies are illegal under the european unions digital markets act according to regulators in brussels
# Processing 2107/2143: jonathan kanter the head of the justice departments antitrust division made his boldest move on thursday by accusing apple of antitrust violations
# Processing 2108/2143: plus dont mess with elvis
# Processing 2109/2143: the suit is the federal governments most significant challenge to the reach and influence of the company
# Processing 2110/2143: for years apple google meta and other tech giants operated unfettered now regulators are taking steps to compel them to make major shifts to their products and businesses
# Processing 2111/2143: two research labs known for some of the tech industrys most important innovations have merged in hopes of recapturing their glory days
# Processing 2112/2143: attorney general merrick b garland said that apple has employed a strategy that relies on exclusionary anticompetitive conduct that hurts both consumers and developers
# Processing 2113/2143: the penalties and customer refunds stem from an investigation by the consumer financial protection bureau into apple card which goldman issues
# Processing 2114/2143: the best bromance in tech has had a reality check as openai has tried to change its deal with microsoft and the software maker has tried to hedge its bet on the startup
# Processing 2115/2143: a trendy management style called founder mode illustrates silicon valleys growing tilt toward authoritarianism
# Processing 2116/2143: the initial version of apple intelligence focuses on helping you with words and photos prepare to be impressed and unnerved
# Processing 2117/2143: google microsoft and meta are shoving ai chatbots into our faces sometimes theres a way out
# Processing 2118/2143: sales for the iphone maker were up 6 percent to to 9493 billion but a 144 billion tax bill cut profits that would have topped expectations
# Processing 2119/2143: some app makers worry that a subtle change to the iphones contactsharing permissions could make it hard for them to get the fast growth they need to compete
# Processing 2120/2143: if youre not sure how to describe what you want with keywords use your camera or photo library to get those search results
# Processing 2121/2143: apple is preparing to turn its airpods pro 2 into easytouse aids for people with mild to moderate hearing loss
# Processing 2122/2143: apple earbuds and others can help you hear dining companions heres how to use them
# Processing 2123/2143: margrethe vestager the european unions antitrust regulator who put technologys harms on the global agenda reflected on a decade of taking on the biggest companies and what comes next
# Processing 2124/2143: the executives of techs biggest companies largely ignored donald trump before the 2016 election this time around theyre far more friendly
# Processing 2125/2143: the chip makers stock price has jumped over the last year thanks to its stranglehold on the market for the chips needed to build ai systems
# Processing 2126/2143: word puzzles on linkedin logic challenges in the washington post for news publishers and tech sites looking to both entice and engage users games are serious business
# Processing 2127/2143: plus apples siri gets an ai makeover
# Processing 2128/2143: was it inconvenient yes did t9 texting drive me crazy definitely was it worth doing absolutely
# Processing 2129/2143: the shift is indicative of the importance of new artificial intelligence technology to silicon valley and wall street investors
# Processing 2130/2143: beeper mini customers were using their mac computers to connect to iphone messaging on their android phones now they say apple has blocked the messaging service on their macs
# Processing 2131/2143: starting on thursday the apple watch series 9 and watch ultra 2 will no longer detect peoples blood oxygen levels to comply with a ruling by the international trade commission
# Processing 2132/2143: see how a handful of stocks have had an outsize impact on the performance of the sp 500
# Processing 2133/2143: seven tech stocks including meta nvidia and apple have accounted for roughly 90 percent of the sps gains over the past 12 months
# Processing 2134/2143: the best tech from universal power charging to foldable phones solved practical problems but the worst tech including selfdriving cars and cryptocurrency put us in harms way
# Processing 2135/2143: the new headset teaches a valuable lesson about the cost of tech products the upsells and addons will get you
# Processing 2136/2143: starting with google glass all have been plagued with the same issues even as apple plunges into the market with its vision pro
# Processing 2137/2143: googles routines and apples shortcuts combine multiple steps into one command to make your phone or tablet do more of the work for you
# Processing 2138/2143: facing a weak consumer appetite and fierce competition from domestic rivals amid uschina tensions a typically discountwary apple is offering a fourday sale
# Processing 2139/2143: the vision pro augmented reality device goes on sale friday dont expect apple to host a splashy event to promote it
# Processing 2140/2143: an eu law taking effect in march forced apple to loosen its grip on the app store changes it had long resisted
# Processing 2141/2143: parents movie buffs and office workers might all succumb to the novelty of apples new spatial computing device
# Processing 2142/2143: justice department officials are in the late stages of investigating the iphone maker focusing on how apple has used its other products and services to defend against threats to its core business
# Processing 2143/2143: a wearable tech brand has followed crocs lead creating colorful decorations as part of an accessories collection for apple watch straps
#         pub_date                                           abstract  \
# 0     2015-04-07  want to work at amazon apple or mckinsey some ...
# 1     2015-04-14  get recommendations from new york times report...
# 2     2015-04-13  the business unit will partner with companies ...
# 3     2015-04-22  with superstars first in line apple appears to...
# 4     2015-04-01  in an industry that avoids controversy the hea...
# ...          ...                                                ...
# 2138  2024-01-19  the vision pro augmented reality device goes o...
# 2139  2024-01-25  an eu law taking effect in march forced apple ...
# 2140  2024-01-31  parents movie buffs and office workers might a...
# 2141  2024-01-05  justice department officials are in the late s...
# 2142  2024-01-18  a wearable tech brand has followed crocs lead ...
#
#      gemini_sentiment
# 0             neutral
# 1             neutral
# 2            positive
# 3             neutral
# 4             neutral
# ...               ...
# 2138          neutral
# 2139         negative
# 2140          neutral
# 2141         negative
# 2142          neutral
#
# [2143 rows x 3 columns]
# C:\Users\Tammy\AppData\Local\Temp\ipykernel_27524\816326164.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gemini_sentiment'] = sentiment_list

# %%
df_new['gemini_sentiment'].value_counts()
## Save results to csv

# df_new.to_csv('gemini_sentiment_analysis_results_AAPL_abstract.csv', index=False)
# Out:
# gemini_sentiment
# neutral     1073
# negative     766
# positive     304
# Name: count, dtype: int64
