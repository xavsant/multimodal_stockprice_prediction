# %% [markdown]
# ### Data Processing

# %% [markdown]
# #### Reading JSON data into df

# %%
import pandas as pd
import json
import os
from pathlib import Path

# Iterate through all articles in document
base_dir = Path('../../data/raw')
company = 'Apple_Inc'

def read_file(path):
    # Load content from json
    with open(path, 'r') as file:
        all_data = json.load(file)

    # Select response
    data = all_data['response']['docs']

    return data
    

def read_articles(data):

    column_list = ['pub_date','abstract','snippet','lead_para','headline','doc_type','section_name','type_of_material','rank','web_url']
    df = pd.DataFrame(columns=column_list)

    for article in data:
        # print(article)
        # Retrieve components
        pub_date = article['pub_date']

        abstract = article['abstract']
        snippet = article['snippet']
        lead_para = article['lead_paragraph']
        headline = article['headline']['main']

        doc_type = article['document_type']
        section_name = article['section_name']
        type_of_material = article.get('type_of_material', None) # will throw an error 

        keywords = article['keywords']
        rank = next((item['rank'] for item in keywords if item['name'] == 'organizations' and item['value'] == 'Apple Inc'), None) # next retrieves first matching rank, may not be necessary

        web_url = article['web_url']

        # Assign to new row in df
        df.loc[len(df)] = [pub_date,
                                    abstract,
                                    snippet,
                                    lead_para,
                                    headline,
                                    doc_type,
                                    section_name,
                                    type_of_material,
                                    rank,
                                    web_url]
    
    return df


# MAIN function below
def compile_company_df(base_dir, company):
    
    column_list = ['pub_date','abstract','snippet','lead_para','headline','doc_type','section_name','type_of_material','rank','web_url']
    df = pd.DataFrame(columns=column_list)

    # Run through directory files
    for year in range(2015, 2025):
        year_dir = base_dir / str(year) 

        for file in year_dir.rglob("*"):
            if file.is_file() and company in file.name:
                data = read_file(year_dir / file.name)
                temp_df = read_articles(data)
                df = pd.concat([df, temp_df], ignore_index=True)
    
    return df   

df = compile_company_df(base_dir, company)
# read_articles(data)
# read_file('../../data/raw/2015/organizations_Apple_Inc_mth01_pg0')
# data

# %% [markdown]
# #### Checking df
#
# Findings:
# <br><br>
# (1) Use abstract instead of snippet
# * Snippet and abstract are exactly the same in all except 6 cases + abstract is more complete
# * Snippet has 3 "" (empty string) values
# <br><br>
#
# (2) Consider either abstract OR lead para
# * Abstract and lead para frequently have some overlaps
# * Lead para is often longer/more detailed, but may not summarise the key point
# <br><br>
#
# (3) Null/empty string values
# * Lead para has 19 "" (empty string) values
# * Type of material has 1 null value
# <br><br>
#
# (4) No duplicates
# * Only repeats in headline/abstract occasionally, published on diff dates (regularly published column)
# <br><br>
#
# (Using Apple Inc as an example)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2143 entries, 0 to 2142
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pub_date          2143 non-null   object
#  1   abstract          2143 non-null   object
#  2   snippet           2143 non-null   object
#  3   lead_para         2143 non-null   object
#  4   headline          2143 non-null   object
#  5   doc_type          2143 non-null   object
#  6   section_name      2143 non-null   object
#  7   type_of_material  2142 non-null   object
#  8   rank              2143 non-null   object
#  9   web_url           2143 non-null   object
# dtypes: object(10)
# memory usage: 167.6+ KB

# %%
# Check if abstract == snippet
df[df.abstract != df.snippet].shape
# Out:
# (6, 10)

# %%
# Check if lead para == abstract
df[df.abstract != df.lead_para].shape
df[df.abstract != df.lead_para].head(10)
# Out:
#                     pub_date  \
# 2   2015-03-10T00:38:04+0000
# 3   2015-03-06T17:47:46+0000
# 7   2015-03-31T09:30:08+0000
# 8   2015-03-10T10:32:25+0000
# 9   2015-03-25T22:06:06+0000
# 10  2015-03-24T09:30:28+0000
# 11  2015-03-17T15:33:41+0000
# 12  2015-03-02T17:55:05+0000
# 13  2015-03-17T07:20:12+0000
# 14  2015-03-09T17:34:00+0000
#
#                                                                                                                                                                                                      abstract  \
# 2                                                 The Apple Watch is good looking for a smartwatch and not hard to use, according to initial impressions. But who knows if it is really a necessary purchase.
# 3                                                    Third-party apps and recent operating system updates are often the cause; starting the phone in Safe Mode can help narrow down the search for a culprit.
# 7                                                                                                                                 A portrait of a volatile boy wonder and his path to technological vanguard.
# 8                                     Initial impressions of the Apple Watch are that it is good-looking for a smart watch and not hard to use, but whether it is yet a necessary purchase remains unsettled.
# 9                                             “Becoming Steve Jobs,” a new biography by Brent Schlender and Rick Tetzeli, focuses on the period between Mr. Jobs’s first and second stints as Apple’s leader.
# 10  Brent Schlender and Rick Tetzeli, who wrote “Becoming Steve Jobs,” discuss the evolution of Steve Jobs and how they won Apple’s cooperation for the unauthorized biography of its former chief executive.
# 11           The service, which could be announced later this year, would offer a bundle of channels that is smaller and cheaper than a typical cable subscription, according to people briefed on the plans.
# 12                                                                                                       The Internal Revenue Service is not emailing you to request personal information. Not now. Not ever.
# 13                                                                                                                                            Genius alone didn’t bring Apple back. It took management chops.
# 14                                                                                                    The service will cost $14.99 a month, and will include current and past programming, as well as movies.
#
#                                                                                                                                                                                                       snippet  \
# 2                                                 The Apple Watch is good looking for a smartwatch and not hard to use, according to initial impressions. But who knows if it is really a necessary purchase.
# 3                                                    Third-party apps and recent operating system updates are often the cause; starting the phone in Safe Mode can help narrow down the search for a culprit.
# 7                                                                                                                                 A portrait of a volatile boy wonder and his path to technological vanguard.
# 8                                     Initial impressions of the Apple Watch are that it is good-looking for a smart watch and not hard to use, but whether it is yet a necessary purchase remains unsettled.
# 9                                             “Becoming Steve Jobs,” a new biography by Brent Schlender and Rick Tetzeli, focuses on the period between Mr. Jobs’s first and second stints as Apple’s leader.
# 10  Brent Schlender and Rick Tetzeli, who wrote “Becoming Steve Jobs,” discuss the evolution of Steve Jobs and how they won Apple’s cooperation for the unauthorized biography of its former chief executive.
# 11           The service, which could be announced later this year, would offer a bundle of channels that is smaller and cheaper than a typical cable subscription, according to people briefed on the plans.
# 12                                                                                                       The Internal Revenue Service is not emailing you to request personal information. Not now. Not ever.
# 13                                                                                                                                            Genius alone didn’t bring Apple back. It took management chops.
# 14                                                                                                    The service will cost $14.99 a month, and will include current and past programming, as well as movies.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      lead_para  \
# 2                                                                                                                                                                                                                                                                                                                                                                                                                               SAN FRANCISCO — When Apple unveiled its watch last fall, the company showed only demo models of the new device — polished prototypes of the hardware running nonworking loops of the software.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# 8                                         https://bits.blogs.nytimes.com/2015/03/10/daily-report-using-the-apple-watch/
# 9                 https://www.nytimes.com/2015/03/26/books/review-becoming-steve-jobs-focuses-on-another-apple-era.html
# 10                    https://bits.blogs.nytimes.com/2015/03/24/a-conversation-with-the-authors-of-becoming-steve-jobs/
# 11         https://www.nytimes.com/2015/03/18/business/media/apple-said-to-plan-limited-low-cost-streaming-service.html
# 12                                  https://www.nytimes.com/2015/03/05/technology/personaltech/the-tax-scam-cometh.html
# 13                           https://www.nytimes.com/2015/03/17/opinion/joe-nocera-the-hidden-talent-of-steve-jobs.html
# 14         https://www.nytimes.com/2015/03/10/business/media/hbo-streaming-to-start-in-april-on-apple-devices-only.html

# %%
df.iloc[176, 1:3].abstract
# Out:
# 'App Pins aims to do for smartphone apps what Pinterest’s service has done for photos, recipes and many other types of websites. In short, the service is a type of digital corkboard that lets visitors save, or “pin,” items they like or places they want to go.'

# %%
df.iloc[176, 1:3].snippet
# Out:
# 'App Pins aims to do for smartphone apps what Pinterest’s service has done for photos, recipes and many other types of websites. In short, the service is a type of digital corkboard that lets visitors save, or “pin,” items they like or places they ...'

# %%
#check for empty strings
(df == "").sum()
# Out:
# pub_date             0
# abstract             0
# snippet              3
# lead_para           19
# headline             0
# doc_type             0
# section_name         0
# type_of_material     0
# rank                 0
# web_url              0
# dtype: int64

# %%
df[df.snippet == ""]
# Out:
#                       pub_date  \
# 1568  2021-02-16T21:27:40+0000
# 1601  2021-05-03T11:31:09+0000
# 1617  2021-05-27T12:21:50+0000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                abstract  \
# 1568                                                                                                                                                                                                                                                                                     A North Dakota bill that an Apple executive had warned “threatens to destroy iPhone as you know it” died in a vote on Tuesday.
# 1601                                                                                  Apple and Epic Games, maker of the wildly popular game Fortnite, are set to square off on Monday in a trial that could decide how much control Apple can exert over the app economy. The trial is scheduled to open with testimony from Tim Sweeney, the chief of Epic, on why he believes Apple is a monopoly abusing its power.
# 1617  When Apple and Google collaborated last year on a smartphone-based system to track the spread of the coronavirus, the news was seen as a game changer. The software uses Bluetooth signals to detect app users who come into close contact. If a user later tests positive, the person can anonymously notify other app users whom the person may have crossed paths with in restaurants, on trains or elsewhere.
#
#      snippet  \
# 1568
# 1601
# 1617
#
#                                                                                                                                                                                                                                                                                                                                                                                                               lead_para  \
# 1568                                                                                                                                                                                                                                                                                     A North Dakota bill that an Apple executive had warned “threatens to destroy iPhone as you know it” died in a vote on Tuesday.
# 1601                                                                                  Apple and Epic Games, maker of the wildly popular game Fortnite, are set to square off on Monday in a trial that could decide how much control Apple can exert over the app economy. The trial is scheduled to open with testimony from Tim Sweeney, the chief of Epic, on why he believes Apple is a monopoly abusing its power.
# 1617  When Apple and Google collaborated last year on a smartphone-based system to track the spread of the coronavirus, the news was seen as a game changer. The software uses Bluetooth signals to detect app users who come into close contact. If a user later tests positive, the person can anonymously notify other app users whom the person may have crossed paths with in restaurants, on trains or elsewhere.
#
#                                                                                     headline  \
# 1568  North Dakota lawmakers vote down a bill that threatened Apple’s and Google’s revenues.
# 1601                                    Apple and Epic Games head to court over app revenue.
# 1617                  Virus alert apps powered by Apple and Google have had limited success.
#
#      doc_type  section_name type_of_material rank  \
# 1568  article  Business Day             News    2
# 1601  article  Business Day             News    5
# 1617  article  Business Day             News    5
#
#                                                                                                                      web_url
# 1568                                            https://www.nytimes.com/2021/02/16/business/north-dakota-app-store-bill.html
# 1601                    https://www.nytimes.com/2021/05/03/business/apple-and-epic-games-head-to-court-over-app-revenue.html
# 1617  https://www.nytimes.com/2021/05/27/business/virus-alert-apps-powered-by-apple-and-google-have-had-limited-success.html

# %%
# 19 lead_paras blank
df[df.lead_para == ""]
# Out:
#                       pub_date  \
# 8     2015-01-02T17:09:23+0000
# 26    2015-02-27T15:06:31+0000
# 29    2015-02-11T14:35:37+0000
# 67    2015-03-02T17:55:05+0000
# 100   2015-04-17T14:07:02+0000
# 108   2015-04-03T13:42:14+0000
# 116   2015-05-22T13:14:57+0000
# 153   2015-06-12T14:07:31+0000
# 167   2015-06-10T15:45:58+0000
# 188   2015-07-15T17:56:34+0000
# 204   2015-08-26T16:38:32+0000
# 207   2015-08-07T13:36:02+0000
# 229   2015-09-16T13:32:10+0000
# 245   2015-09-04T15:22:20+0000
# 252   2015-09-22T16:30:20+0000
# 305   2015-10-14T20:42:04+0000
# 510   2016-03-21T10:03:22+0000
# 1113  2018-11-12T17:13:15+0000
# 1766  2022-03-24T09:00:31+0000
#
#                                                                                                                                                                                                                    abstract  \
# 8                                                                                                   You can adjust your settings so that only certain people can see your images. Also, syncing files between Macs and PCs.
# 26                                                         Learn about the differences between Amazon Fire TV and Fire TV stick (besides price), and also discover how to transfer airline boarding passes between iPhones.
# 29                                                                                Tips on how to transfer photographs into iPhoto on your Mac, and advice for connecting to a virtual private network from a mobile device.
# 67                                                                                                                     The Internal Revenue Service is not emailing you to request personal information. Not now. Not ever.
# 100                                                                                                              Apps will allow users to peek at their balance and recent activity, but not to pay bills or make deposits.
# 108                                                                                                                     The inexpensive device links a standard audio cable from the music player to a computer’s USB jack.
# 116                                                                                                                       You can send the message to someone not in the original conversation by taking a couple of steps.
# 153                                                                                                                      Tips for mirroring your phone’s display on a Mac, and how to get desktop notifications from Gmail.
# 167                                                                                  Some independent booksellers gain a portion of e-book sales through partnerships with bigger e-bookstores like Kobo and Amazon Source.
# 188                                                                              How to rid the bookmarks menu of a utility you don’t use. Plus, browsing with Chrome on Windows 10 and learning MacBook trackpad gestures.
# 204                                                                                                                          Microsoft collects personal data on users of Windows 10, but privacy controls can be adjusted.
# 207                                                                                                                  Recovering discarded photos before they are gone for good, and shutting down misbehaving applications.
# 229                                                                                  If your computer did not come with a microphone, you can command Microsoft’s virtual assistant with an external or headset microphone.
# 245                                                                How to get your Windows 10 operating system to recognize a printer; plus, the Internet speed necessary for smooth high-definition streaming on Apple TV.
# 252                                                                                          Twitter’s apps make use of the spell-checking and auto-correction tools built into the operating system on your mobile device.
# 305                                                                    Upgrading from an older version of Windows can sometimes damage the device drivers, including the one for the sound card. But the fix can be simple.
# 510                                                        Times reporters provided live analysis from the event, where the tech company introduced a smaller iPhone, a smaller iPad Pro and new bands for the Apple Watch.
# 1113                                                                           What does it mean to be digital? Think back to a decade or two ago. It meant being on the web. Then it meant adopting new shiny IT. No more.
# 1766  More than 400 companies have withdrawn, at least temporarily, from Russia since it invaded Ukraine. Some have been there since the fall of communism — symbols of the enduring power of Western culture and commerce.
#
#                                                                                                                                                                                                                     snippet  \
# 8                                                                                                   You can adjust your settings so that only certain people can see your images. Also, syncing files between Macs and PCs.
# 26                                                         Learn about the differences between Amazon Fire TV and Fire TV stick (besides price), and also discover how to transfer airline boarding passes between iPhones.
# 29                                                                                Tips on how to transfer photographs into iPhoto on your Mac, and advice for connecting to a virtual private network from a mobile device.
# 67                                                                                                                     The Internal Revenue Service is not emailing you to request personal information. Not now. Not ever.
# 100                                                                                                              Apps will allow users to peek at their balance and recent activity, but not to pay bills or make deposits.
# 108                                                                                                                     The inexpensive device links a standard audio cable from the music player to a computer’s USB jack.
# 116                                                                                                                       You can send the message to someone not in the original conversation by taking a couple of steps.
# 153                                                                                                                      Tips for mirroring your phone’s display on a Mac, and how to get desktop notifications from Gmail.
# 167                                                                                  Some independent booksellers gain a portion of e-book sales through partnerships with bigger e-bookstores like Kobo and Amazon Source.
# 188                                                                              How to rid the bookmarks menu of a utility you don’t use. Plus, browsing with Chrome on Windows 10 and learning MacBook trackpad gestures.
# 204                                                                                                                          Microsoft collects personal data on users of Windows 10, but privacy controls can be adjusted.
# 207                                                                                                                  Recovering discarded photos before they are gone for good, and shutting down misbehaving applications.
# 229                                                                                  If your computer did not come with a microphone, you can command Microsoft’s virtual assistant with an external or headset microphone.
# 245                                                                How to get your Windows 10 operating system to recognize a printer; plus, the Internet speed necessary for smooth high-definition streaming on Apple TV.
# 252                                                                                          Twitter’s apps make use of the spell-checking and auto-correction tools built into the operating system on your mobile device.
# 305                                                                    Upgrading from an older version of Windows can sometimes damage the device drivers, including the one for the sound card. But the fix can be simple.
# 510                                                        Times reporters provided live analysis from the event, where the tech company introduced a smaller iPhone, a smaller iPad Pro and new bands for the Apple Watch.
# 1113                                                                           What does it mean to be digital? Think back to a decade or two ago. It meant being on the web. Then it meant adopting new shiny IT. No more.
# 1766  More than 400 companies have withdrawn, at least temporarily, from Russia since it invaded Ukraine. Some have been there since the fall of communism — symbols of the enduring power of Western culture and commerce.
#
#      lead_para  \
# 8
# 26
# 29
# 67
# 100
# 108
# 116
# 153
# 167
# 188
# 204
# 207
# 229
# 245
# 252
# 305
# 510
# 1113
# 1766
#
#                                                               headline  \
# 8                                      Sharing Flickr Photos Privately
# 26                     Choosing Between Amazon’s TV Streaming Hardware
# 29                                          Importing Images to iPhoto
# 67                                                  The Tax Con Cometh
# 100                    Banking on Apple Watch Will Be Limited, for Now
# 108        Converting Audio From a Cassette to MP3 Requires an Adapter
# 116                             Forwarding Text Messages on the iPhone
# 153                                Recording a Phone’s Screen on a Mac
# 167                                    Shop Locally, Download Globally
# 188                     Picking Pockets Off the Firefox Bookmarks List
# 204                                      Staying Private in Windows 10
# 207                   Digging for Trashed Pictures in Mac’s Photos App
# 229                                 How to Talk to Microsoft’s Cortana
# 245                          Coaxing a Printer to Work With Windows 10
# 252                                          Spell-Checking Your Tweet
# 305                                      Restoring Sound to Windows 10
# 510   A Smaller iPhone and Other Highlights From Apple’s Product Event
# 1113                Getting Digital Right: Posers, Players and Profits
# 1766                                               No Longer in Russia
#
#       doc_type  section_name type_of_material rank  \
# 8      article    Technology         Question    5
# 26     article    Technology         Question    4
# 29     article    Technology         Question   12
# 67     article    Technology         Question    4
# 100    article    Your Money             News    3
# 108    article    Technology         Question    3
# 116    article    Technology         Question    6
# 153    article    Technology         Question    1
# 167    article    Technology         Question    4
# 188    article    Technology         Question    7
# 204    article    Technology         Question    6
# 207    article    Technology         Question    1
# 229    article    Technology         Question    5
# 245    article    Technology         Question    2
# 252    article    Technology         Question    3
# 305    article    Technology         Question    7
# 510    article    Technology             News    5
# 1113  paidpost       T Brand             None    3
# 1766   article  Business Day             News    4
#
#                                                                                                                           web_url
# 8                                 https://www.nytimes.com/2015/01/02/technology/personaltech/sharing-flickr-photos-privately.html
# 26                 https://www.nytimes.com/2015/02/27/technology/personaltech/choosing-between-amazons-tv-streaming-hardware.html
# 29                                     https://www.nytimes.com/2015/02/12/technology/personaltech/importing-images-to-iphoto.html
# 67                                            https://www.nytimes.com/2015/03/05/technology/personaltech/the-tax-scam-cometh.html
# 100                             https://www.nytimes.com/2015/04/17/your-money/banking-on-apple-watch-will-be-limited-for-now.html
# 108   https://www.nytimes.com/2015/04/03/technology/personaltech/converting-audio-from-a-cassette-to-mp3-requires-an-adapter.html
# 116                                                   https://www.nytimes.com/2015/05/23/technology/personaltech/23askkextra.html
# 153                            https://www.nytimes.com/2015/06/13/technology/personaltech/recording-a-phones-screen-on-a-mac.html
# 167                                https://www.nytimes.com/2015/06/11/technology/personaltech/shop-locally-download-globally.html
# 188                https://www.nytimes.com/2015/07/16/technology/personaltech/picking-pockets-off-the-firefox-bookmarks-list.html
# 204                                 https://www.nytimes.com/2015/08/27/technology/personaltech/staying-private-in-windows-10.html
# 207               https://www.nytimes.com/2015/08/08/technology/personaltech/digging-for-trashed-pictures-in-macs-photos-app.html
# 229                             https://www.nytimes.com/2015/09/17/technology/personaltech/how-to-talk-to-microsofts-cortana.html
# 245                     https://www.nytimes.com/2015/09/05/technology/personaltech/coaxing-a-printer-to-work-with-windows-10.html
# 252                                     https://www.nytimes.com/2015/09/24/technology/personaltech/spell-checking-your-tweet.html
# 305                                 https://www.nytimes.com/2015/10/15/technology/personaltech/restoring-sound-to-windows-10.html
# 510                                                                         https://www.nytimes.com/live/apple-iphone-event-2016/
# 1113                                   https://www.nytimes.com/paidpost/pwc/getting-digital-right-posers-players-and-profits.html
# 1766                                                   https://www.nytimes.com/2022/03/24/business/companies-products-russia.html

# %%
# check for duplicates 
df.duplicated().sum()
df[['headline']].duplicated().sum() # 6 duplicates, but on different days, due to regular published column
df[df[['headline']].duplicated()]
# Out:
#         pub_date  \
# 227   2015-04-24
# 251   2015-05-08
# 289   2015-04-14
# 572   2016-02-19
# 939   2017-07-29
# 1817  2022-05-11
#
#                                                                                                                                                                                                   abstract  \
# 227          Get recommendations from New York Times reporters and editors, highlighting interesting stories from around the web. In this installment, great reads from John Branch, Dan Levin and others.
# 251   Get recommendations from New York Times reporters and editors, highlighting interesting stories from around the web. In this installment, great reads from John Branch, Lynda Richardson and others.
# 289     Get recommendations from New York Times reporters and editors, highlighting interesting stories from around the web. In this installment, great reads from Stacy Cowley, Quentin Hardy and others.
# 572                                                                                                                                 Get recommendations from New York Times reporters and editors, highlig
# 939                                                         The world’s most valuable company appears to have pulled down the apps amid China’s deepening crackdown on tools that evade internet controls.
# 1817                                                                                                                                                   Here’s what you need to know at the end of the day.
#
#                                                                                                                                                                                    lead_para  \
# 227                Get recommendations from New York Times reporters and editors, highlighting great stories from around the web. What We’re Reading emails are sent twice a week. Sign up »
# 251                Get recommendations from New York Times reporters and editors, highlighting great stories from around the web. What We’re Reading emails are sent twice a week. Sign up »
# 289                Get recommendations from New York Times reporters and editors, highlighting great stories from around the web. What We’re Reading emails are sent twice a week. Sign up »
# 572                Get recommendations from New York Times reporters and editors, highlighting great stories from around the web. What We’re Reading emails are sent twice a week. Sign up »
# 939   HONG KONG — China appears to have received help on Saturday from an unlikely source in its fight against tools that help users evade its Great Firewall of internet censorship: Apple.
# 1817                                                                                                                        (Want to get this newsletter in your inbox? Here’s the sign-up.)
#
#                                                                            headline  \
# 227                                                              What We’re Reading
# 251                                                              What We’re Reading
# 289                                                              What We’re Reading
# 572                                                              What We’re Reading
# 939   Apple Removes Apps From China Store That Help Internet Users Evade Censorship
# 1817                                                Your Wednesday Evening Briefing
#
#      doc_type section_name type_of_material rank  \
# 227   article        Blogs             News   21
# 251   article        Blogs             News   15
# 289   article        Blogs             News   13
# 572   article        Blogs             News   19
# 939   article   Technology             News    2
# 1817  article     Briefing             News    5
#
#                                                                               web_url  \
# 227                   https://news.blogs.nytimes.com/2015/04/24/what-were-reading-49/
# 251                   https://news.blogs.nytimes.com/2015/05/08/what-were-reading-53/
# 289                   https://news.blogs.nytimes.com/2015/04/14/what-were-reading-46/
# 572                  https://news.blogs.nytimes.com/2016/02/19/what-were-reading-129/
# 939          https://www.nytimes.com/2017/07/29/technology/china-apple-censorhip.html
# 1817  https://www.nytimes.com/2022/05/11/briefing/roe-vote-consumer-prices-ipods.html
#
#       NLTK_sentiment sentiment_label  vader_sent headline_label  \
# 227          0.38915        Positive     0.38915       POSITIVE
# 251          0.38915        Positive     0.38915       POSITIVE
# 289          0.42955        Positive     0.42955       POSITIVE
# 572          0.00000         Neutral     0.00000       POSITIVE
# 939          0.46375        Positive     0.46375       NEGATIVE
# 1817         0.00000         Neutral     0.00000       POSITIVE
#
#       headline_score abstract_label  abstract_score transf_sent
# 227         0.997283       POSITIVE        0.999783    POSITIVE
# 251         0.997283       POSITIVE        0.999802    POSITIVE
# 289         0.997283       POSITIVE        0.999807    POSITIVE
# 572         0.997283       POSITIVE        0.889406    POSITIVE
# 939         0.995543       NEGATIVE        0.998216    NEGATIVE
# 1817        0.949314       NEGATIVE        0.939224    POSITIVE

# %%
# Check headlines
pd.set_option('display.max_colwidth', None)
print(df['headline'])
# Out:
# 0                                     Apple’s Near-Death Experience Saved It
# 1                                          Use the iPhone’s iOS 8 Like a Pro
# 2                       Apple Watch Displays Your Digital World, at a Glance
# 3                                       Troubleshooting Android in Safe Mode
# 4                               Suddenly, Plenty of Options for Cord Cutters
#                                         ...
# 2138    On These Apps, the Dark Promise of Mothers Sexually Abusing Children
# 2139                                The Apple of One Business Reporter’s Eye
# 2140             How to Clean Up Your Phone’s Photo Library to Free Up Space
# 2141                                  Your Driving App Is Leading You Astray
# 2142        Apple Settles E.U. Case by Opening Its Payment Service to Rivals
# Name: headline, Length: 2143, dtype: object

# %%
# Check lead paras
df['lead_para'].head(10)
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                 James B. Stewart, on CNBC, discusses why Apple became twice as big as Microsoft. One reason: Apple’s willingness to “destroy” its own products in the interest of innovation.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                        You probably didn’t know about these five features hidden in the iPhone’s iOS 8 operating system. Use them, and you’ll be using your phone like a pro.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                SAN FRANCISCO — When Apple unveiled its watch last fall, the company showed only demo models of the new device — polished prototypes of the hardware running nonworking loops of the software.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Q. My Android phone just started freezing and crashing a few days ago. What would cause it to do so?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Here are some prominent services offering live TV, à la carte networks and other on-demand streaming options in the United States.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Egypt and More — Pictures of the Day
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Apple held an event in San Francisco on Monday to talk about its latest apps and features, including a partnership with HBO and new medical research software
# 7                                                                                                                                                                                                                                                                                                                                                         In early 2009, Tim Cook presented Steve Jobs, his cancer-stricken mentor and friend, with a surprise offer: Cook wanted to donate a portion of his own liver to his ailing boss, who was stuck in dangerous limbo on California’s waiting list for liver transplants.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                On Monday, Apple allowed a closer look at its much anticipated watch. Farhad Manjoo gives his impressions of the timepiece on three fronts: the hardware, the interface and the watch’s uses.
# 9    The main point of the new business-oriented biography “Becoming Steve Jobs,” by Brent Schlender and Rick Tetzeli is that Steve Jobs has been misrepresented. Blame Walter Isaacson’s “Steve Jobs” (2011), as the authors do, for the public perception that Mr. Jobs never outgrew the managerial style of the scheming, screaming, cheating, smelly hothead he may — may — have been in his early years. Instead, Mr. Schlender and Mr. Tetzeli say in their new book, Mr. Jobs developed a wise, mature, deliberate executive style for which he is seldom given credit, one that helped lead Apple to glorious heights.
# Name: lead_para, dtype: object

# %%
# Check abstract
df['abstract'].head(10)
# Out:
# 0    James B. Stewart, on CNBC, discusses why Apple became twice as big as Microsoft. One reason: Apple’s willingness to “destroy” its own products in the interest of innovation.
# 1                           You probably didn’t know about these five features hidden in the iPhone’s iOS 8 operating system. Use them, and you’ll be using your phone like a pro.
# 2                      The Apple Watch is good looking for a smartwatch and not hard to use, according to initial impressions. But who knows if it is really a necessary purchase.
# 3                         Third-party apps and recent operating system updates are often the cause; starting the phone in Safe Mode can help narrow down the search for a culprit.
# 4                                               Here are some prominent services offering live TV, à la carte networks and other on-demand streaming options in the United States.
# 5                                                                                                                                             Egypt and More — Pictures of the Day
# 6                    Apple held an event in San Francisco on Monday to talk about its latest apps and features, including a partnership with HBO and new medical research software
# 7                                                                                                      A portrait of a volatile boy wonder and his path to technological vanguard.
# 8          Initial impressions of the Apple Watch are that it is good-looking for a smart watch and not hard to use, but whether it is yet a necessary purchase remains unsettled.
# 9                  “Becoming Steve Jobs,” a new biography by Brent Schlender and Rick Tetzeli, focuses on the period between Mr. Jobs’s first and second stints as Apple’s leader.
# Name: abstract, dtype: object

# %% [markdown]
# #### Data Cleaning
#
# 1. Reformat date to datetime
# 2. Remove snippet
# 3. Remove rows with null/empty string values

# %%
import numpy as np 

# Reformat the date
df['pub_date'] = pd.to_datetime(df['pub_date']) 
df['pub_date'] = df['pub_date'].dt.date

# Remove snippet
df.drop(labels='snippet', inplace=True, axis=1)

# Remove null/empty string rows
df.replace('', np.nan, inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#      pub_date  \
# 0  2015-01-30
# 1  2015-01-14
# 2  2015-03-10
# 3  2015-03-06
# 4  2015-03-18
#
#                                                                                                                                                                         abstract  \
# 0  James B. Stewart, on CNBC, discusses why Apple became twice as big as Microsoft. One reason: Apple’s willingness to “destroy” its own products in the interest of innovation.
# 1                         You probably didn’t know about these five features hidden in the iPhone’s iOS 8 operating system. Use them, and you’ll be using your phone like a pro.
# 2                    The Apple Watch is good looking for a smartwatch and not hard to use, according to initial impressions. But who knows if it is really a necessary purchase.
# 3                       Third-party apps and recent operating system updates are often the cause; starting the phone in Safe Mode can help narrow down the search for a culprit.
# 4                                             Here are some prominent services offering live TV, à la carte networks and other on-demand streaming options in the United States.
#
#                                                                                                                                                                                         lead_para  \
# 0                   James B. Stewart, on CNBC, discusses why Apple became twice as big as Microsoft. One reason: Apple’s willingness to “destroy” its own products in the interest of innovation.
# 1                                          You probably didn’t know about these five features hidden in the iPhone’s iOS 8 operating system. Use them, and you’ll be using your phone like a pro.
# 2  SAN FRANCISCO — When Apple unveiled its watch last fall, the company showed only demo models of the new device — polished prototypes of the hardware running nonworking loops of the software.
# 3                                                                                            Q. My Android phone just started freezing and crashing a few days ago. What would cause it to do so?
# 4                                                              Here are some prominent services offering live TV, à la carte networks and other on-demand streaming options in the United States.
#
#                                                headline    doc_type  \
# 0                Apple’s Near-Death Experience Saved It  multimedia
# 1                     Use the iPhone’s iOS 8 Like a Pro  multimedia
# 2  Apple Watch Displays Your Digital World, at a Glance     article
# 3                  Troubleshooting Android in Safe Mode     article
# 4          Suddenly, Plenty of Options for Cord Cutters  multimedia
#
#    section_name     type_of_material rank  \
# 0  Business Day                Video    1
# 1    Technology                Video    5
# 2    Technology                 News    5
# 3    Technology             Question    3
# 4  Business Day  Interactive Feature    3
#
#                                                                                                                web_url
# 0                    https://www.nytimes.com/video/business/100000003482723/apples-near-death-experience-saved-it.html
# 1           https://www.nytimes.com/video/technology/personaltech/100000003448481/use-the-iphones-ios8-like-a-pro.html
# 2  https://www.nytimes.com/2015/03/10/technology/personaltech/apple-watch-displays-your-digital-world-at-a-glance.html
# 3                 https://www.nytimes.com/2015/03/06/technology/personaltech/troubleshooting-android-in-safe-mode.html
# 4                         https://www.nytimes.com/interactive/2015/business/media/streaming-tv-cord-cutting-guide.html

# %%
# save data to csv
file_name = 'Apple_Inc_text_data'
df.to_csv('../../data/cleaned/{}'.format(file_name), index=False)

# check = pd.read_csv('../../data/cleaned/{}'.format(file_name))
# check

# %% [markdown]
# ### Misc Testing Code [UNUSED]

# %% [markdown]
# ##### Processing data (testing 1 file)

# %%
# Read data from raw files
# testing with one file

import json

# Load content from json
with open('../../data/raw/2015/organizations_Apple_Inc_mth01_pg0', 'r') as file:
    data = json.load(file)

# Print data
print(len(data))
# Out:
# 3

# %%
data["response"]['docs'][0]
# Out:
# {'abstract': 'It’s time to take note of what lies at the top of the fashion agenda for 2015.',
#  'web_url': 'https://runway.blogs.nytimes.com/2015/01/05/what-to-watch-for-in-2015-galliano-and-gucci-elections-and-apple/',
#  'snippet': 'It’s time to take note of what lies at the top of the fashion agenda for 2015.',
#  'lead_paragraph': 'It is officially the first full week of the new year, and you know what that means: time to take note of what to watch for in 2015. I think it’s going to be a doozy. Why? Well, here’s what I have at the top of my agenda:',
#  'source': 'The New York Times',
#  'multimedia': [{'rank': 0,
#    'subtype': 'wide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-thumbWide.jpg',
#    'height': 126,
#    'width': 190,
#    'legacy': {'widewidth': 190,
#     'wideheight': 126,
#     'wide': 'images/2015/01/05/fashion/05runway/05runway-thumbWide.jpg'},
#    'subType': 'wide',
#    'crop_name': 'thumbWide'},
#   {'rank': 0,
#    'subtype': 'videoThumb',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoThumb.jpg',
#    'height': 50,
#    'width': 75,
#    'legacy': {},
#    'subType': 'videoThumb',
#    'crop_name': 'videoThumb'},
#   {'rank': 0,
#    'subtype': 'videoLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoLarge.jpg',
#    'height': 507,
#    'width': 768,
#    'legacy': {},
#    'subType': 'videoLarge',
#    'crop_name': 'videoLarge'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo210',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-mediumThreeByTwo210.jpg',
#    'height': 140,
#    'width': 210,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo210',
#    'crop_name': 'mediumThreeByTwo210'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-mediumThreeByTwo225.jpg',
#    'height': 150,
#    'width': 225,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo225',
#    'crop_name': 'mediumThreeByTwo225'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo440',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-mediumThreeByTwo440.jpg',
#    'height': 293,
#    'width': 440,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo440',
#    'crop_name': 'mediumThreeByTwo440'},
#   {'rank': 0,
#    'subtype': 'facebookJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-facebookJumbo.jpg',
#    'height': 550,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'facebookJumbo',
#    'crop_name': 'facebookJumbo'},
#   {'rank': 0,
#    'subtype': 'videoFifteenBySeven1305',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoFifteenBySeven1305.jpg',
#    'height': 609,
#    'width': 1305,
#    'legacy': {},
#    'subType': 'videoFifteenBySeven1305',
#    'crop_name': 'videoFifteenBySeven1305'},
#   {'rank': 0,
#    'subtype': 'miniMoth',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-miniMoth.jpg',
#    'height': 70,
#    'width': 151,
#    'legacy': {},
#    'subType': 'miniMoth',
#    'crop_name': 'miniMoth'},
#   {'rank': 0,
#    'subtype': 'windowsTile336H',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-windowsTile336H.jpg',
#    'height': 336,
#    'width': 694,
#    'legacy': {},
#    'subType': 'windowsTile336H',
#    'crop_name': 'windowsTile336H'},
#   {'rank': 0,
#    'subtype': 'xlarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-articleLarge.jpg',
#    'height': 782,
#    'width': 600,
#    'legacy': {'xlarge': 'images/2015/01/05/fashion/05runway/05runway-articleLarge.jpg',
#     'xlargewidth': 600,
#     'xlargeheight': 782},
#    'subType': 'xlarge',
#    'crop_name': 'articleLarge'},
#   {'rank': 0,
#    'subtype': 'blog480',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-blog480.jpg',
#    'height': 626,
#    'width': 480,
#    'legacy': {},
#    'subType': 'blog480',
#    'crop_name': 'blog480'},
#   {'rank': 0,
#    'subtype': 'blog427',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-blog427.jpg',
#    'height': 557,
#    'width': 427,
#    'legacy': {},
#    'subType': 'blog427',
#    'crop_name': 'blog427'},
#   {'rank': 0,
#    'subtype': 'tmagArticle',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-tmagArticle.jpg',
#    'height': 772,
#    'width': 592,
#    'legacy': {},
#    'subType': 'tmagArticle',
#    'crop_name': 'tmagArticle'},
#   {'rank': 0,
#    'subtype': 'jumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-jumbo.jpg',
#    'height': 1024,
#    'width': 786,
#    'legacy': {},
#    'subType': 'jumbo',
#    'crop_name': 'jumbo'},
#   {'rank': 0,
#    'subtype': 'blog225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-blog225.jpg',
#    'height': 293,
#    'width': 225,
#    'legacy': {},
#    'subType': 'blog225',
#    'crop_name': 'blog225'},
#   {'rank': 0,
#    'subtype': 'master675',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-master675.jpg',
#    'height': 880,
#    'width': 675,
#    'legacy': {},
#    'subType': 'master675',
#    'crop_name': 'master675'},
#   {'rank': 0,
#    'subtype': 'master180',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-master180.jpg',
#    'height': 235,
#    'width': 180,
#    'legacy': {},
#    'subType': 'master180',
#    'crop_name': 'master180'},
#   {'rank': 0,
#    'subtype': 'popup',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-popup.jpg',
#    'height': 500,
#    'width': 384,
#    'legacy': {},
#    'subType': 'popup',
#    'crop_name': 'popup'},
#   {'rank': 0,
#    'subtype': 'blog533',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-blog533.jpg',
#    'height': 695,
#    'width': 533,
#    'legacy': {},
#    'subType': 'blog533',
#    'crop_name': 'blog533'},
#   {'rank': 0,
#    'subtype': 'tmagSF',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-tmagSF.jpg',
#    'height': 472,
#    'width': 362,
#    'legacy': {},
#    'subType': 'tmagSF',
#    'crop_name': 'tmagSF'},
#   {'rank': 0,
#    'subtype': 'slide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-slide.jpg',
#    'height': 500,
#    'width': 384,
#    'legacy': {},
#    'subType': 'slide',
#    'crop_name': 'slide'},
#   {'rank': 0,
#    'subtype': 'superJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-superJumbo.jpg',
#    'height': 2048,
#    'width': 1571,
#    'legacy': {},
#    'subType': 'superJumbo',
#    'crop_name': 'superJumbo'},
#   {'rank': 0,
#    'subtype': 'master1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-master1050.jpg',
#    'height': 1369,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'master1050',
#    'crop_name': 'master1050'},
#   {'rank': 0,
#    'subtype': 'master495',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-master495.jpg',
#    'height': 645,
#    'width': 495,
#    'legacy': {},
#    'subType': 'master495',
#    'crop_name': 'master495'},
#   {'rank': 0,
#    'subtype': 'master315',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-master315.jpg',
#    'height': 411,
#    'width': 315,
#    'legacy': {},
#    'subType': 'master315',
#    'crop_name': 'master315'},
#   {'rank': 0,
#    'subtype': 'square320',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-square320.jpg',
#    'height': 320,
#    'width': 320,
#    'legacy': {},
#    'subType': 'square320',
#    'crop_name': 'square320'},
#   {'rank': 0,
#    'subtype': 'filmstrip',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-filmstrip.jpg',
#    'height': 190,
#    'width': 190,
#    'legacy': {},
#    'subType': 'filmstrip',
#    'crop_name': 'filmstrip'},
#   {'rank': 0,
#    'subtype': 'square640',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-square640.jpg',
#    'height': 640,
#    'width': 640,
#    'legacy': {},
#    'subType': 'square640',
#    'crop_name': 'square640'},
#   {'rank': 0,
#    'subtype': 'moth',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-moth.jpg',
#    'height': 151,
#    'width': 151,
#    'legacy': {},
#    'subType': 'moth',
#    'crop_name': 'moth'},
#   {'rank': 0,
#    'subtype': 'mediumSquare149',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-mediumSquare149.jpg',
#    'height': 149,
#    'width': 149,
#    'legacy': {},
#    'subType': 'mediumSquare149',
#    'crop_name': 'mediumSquare149'},
#   {'rank': 0,
#    'subtype': 'articleInline',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-articleInline.jpg',
#    'height': 248,
#    'width': 190,
#    'legacy': {},
#    'subType': 'articleInline',
#    'crop_name': 'articleInline'},
#   {'rank': 0,
#    'subtype': 'hpSmall',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-hpSmall.jpg',
#    'height': 213,
#    'width': 163,
#    'legacy': {},
#    'subType': 'hpSmall',
#    'crop_name': 'hpSmall'},
#   {'rank': 0,
#    'subtype': 'blogSmallInline',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-blogSmallInline.jpg',
#    'height': 197,
#    'width': 151,
#    'legacy': {},
#    'subType': 'blogSmallInline',
#    'crop_name': 'blogSmallInline'},
#   {'rank': 0,
#    'subtype': 'mediumFlexible177',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-mediumFlexible177.jpg',
#    'height': 231,
#    'width': 177,
#    'legacy': {},
#    'subType': 'mediumFlexible177',
#    'crop_name': 'mediumFlexible177'},
#   {'rank': 0,
#    'subtype': 'sfSpan',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-sfSpan.jpg',
#    'height': 263,
#    'width': 395,
#    'legacy': {},
#    'subType': 'sfSpan',
#    'crop_name': 'sfSpan'},
#   {'rank': 0,
#    'subtype': 'largeHorizontal375',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-largeHorizontal375.jpg',
#    'height': 250,
#    'width': 375,
#    'legacy': {},
#    'subType': 'largeHorizontal375',
#    'crop_name': 'largeHorizontal375'},
#   {'rank': 0,
#    'subtype': 'hpLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-hpLarge.jpg',
#    'height': 287,
#    'width': 511,
#    'legacy': {},
#    'subType': 'hpLarge',
#    'crop_name': 'hpLarge'},
#   {'rank': 0,
#    'subtype': 'largeWidescreen573',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-largeWidescreen573.jpg',
#    'height': 322,
#    'width': 573,
#    'legacy': {},
#    'subType': 'largeWidescreen573',
#    'crop_name': 'largeWidescreen573'},
#   {'rank': 0,
#    'subtype': 'largeWidescreen1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-largeWidescreen1050.jpg',
#    'height': 590,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'largeWidescreen1050',
#    'crop_name': 'largeWidescreen1050'},
#   {'rank': 0,
#    'subtype': 'videoSmall',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSmall.jpg',
#    'height': 281,
#    'width': 500,
#    'legacy': {},
#    'subType': 'videoSmall',
#    'crop_name': 'videoSmall'},
#   {'rank': 0,
#    'subtype': 'videoHpMedium',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoHpMedium.jpg',
#    'height': 211,
#    'width': 375,
#    'legacy': {},
#    'subType': 'videoHpMedium',
#    'crop_name': 'videoHpMedium'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine600',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine600.jpg',
#    'height': 338,
#    'width': 600,
#    'legacy': {},
#    'subType': 'videoSixteenByNine600',
#    'crop_name': 'videoSixteenByNine600'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine540',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine540.jpg',
#    'height': 304,
#    'width': 540,
#    'legacy': {},
#    'subType': 'videoSixteenByNine540',
#    'crop_name': 'videoSixteenByNine540'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine495',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine495.jpg',
#    'height': 278,
#    'width': 495,
#    'legacy': {},
#    'subType': 'videoSixteenByNine495',
#    'crop_name': 'videoSixteenByNine495'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine390',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine390.jpg',
#    'height': 219,
#    'width': 390,
#    'legacy': {},
#    'subType': 'videoSixteenByNine390',
#    'crop_name': 'videoSixteenByNine390'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine480',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine480.jpg',
#    'height': 270,
#    'width': 480,
#    'legacy': {},
#    'subType': 'videoSixteenByNine480',
#    'crop_name': 'videoSixteenByNine480'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine310',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine310.jpg',
#    'height': 174,
#    'width': 310,
#    'legacy': {},
#    'subType': 'videoSixteenByNine310',
#    'crop_name': 'videoSixteenByNine310'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine225.jpg',
#    'height': 126,
#    'width': 225,
#    'legacy': {},
#    'subType': 'videoSixteenByNine225',
#    'crop_name': 'videoSixteenByNine225'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine96',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine96.jpg',
#    'height': 54,
#    'width': 96,
#    'legacy': {},
#    'subType': 'videoSixteenByNine96',
#    'crop_name': 'videoSixteenByNine96'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine768',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine768.jpg',
#    'height': 432,
#    'width': 768,
#    'legacy': {},
#    'subType': 'videoSixteenByNine768',
#    'crop_name': 'videoSixteenByNine768'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine150',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine150.jpg',
#    'height': 84,
#    'width': 150,
#    'legacy': {},
#    'subType': 'videoSixteenByNine150',
#    'crop_name': 'videoSixteenByNine150'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-videoSixteenByNine1050.jpg',
#    'height': 591,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'videoSixteenByNine1050',
#    'crop_name': 'videoSixteenByNine1050'},
#   {'rank': 0,
#    'subtype': 'thumbnail',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-thumbStandard.jpg',
#    'height': 75,
#    'width': 75,
#    'legacy': {'thumbnail': 'images/2015/01/05/fashion/05runway/05runway-thumbStandard.jpg',
#     'thumbnailwidth': 75,
#     'thumbnailheight': 75},
#    'subType': 'thumbnail',
#    'crop_name': 'thumbStandard'},
#   {'rank': 0,
#    'subtype': 'thumbLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-thumbLarge.jpg',
#    'height': 150,
#    'width': 150,
#    'legacy': {},
#    'subType': 'thumbLarge',
#    'crop_name': 'thumbLarge'},
#   {'rank': 0,
#    'subtype': 'blogSmallThumb',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2015/01/05/fashion/05runway/05runway-blogSmallThumb.jpg',
#    'height': 50,
#    'width': 50,
#    'legacy': {},
#    'subType': 'blogSmallThumb',
#    'crop_name': 'blogSmallThumb'}],
#  'headline': {'main': 'What to Watch For in 2015: Galliano and Gucci, Elections and Apple',
#   'kicker': 'On the Runway',
#   'content_kicker': None,
#   'print_headline': None,
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'name': 'subject',
#    'value': 'Fashion and Apparel',
#    'rank': 1,
#    'major': 'N'},
#   {'name': 'subject',
#    'value': 'Golden Globes (Awards)',
#    'rank': 2,
#    'major': 'N'},
#   {'name': 'subject', 'value': 'Wearable Computing', 'rank': 3, 'major': 'N'},
#   {'name': 'persons', 'value': 'Altuzarra, Joseph', 'rank': 4, 'major': 'N'},
#   {'name': 'persons', 'value': 'Copping, Peter', 'rank': 5, 'major': 'N'},
#   {'name': 'persons', 'value': 'de la Renta, Oscar', 'rank': 6, 'major': 'N'},
#   {'name': 'persons', 'value': 'Dior, Christian', 'rank': 7, 'major': 'N'},
#   {'name': 'persons', 'value': 'Fey, Tina', 'rank': 8, 'major': 'N'},
#   {'name': 'persons', 'value': 'Galliano, John', 'rank': 9, 'major': 'N'},
#   {'name': 'persons', 'value': 'Giannini, Frida', 'rank': 10, 'major': 'N'},
#   {'name': 'persons', 'value': 'Henry, Guillaume', 'rank': 11, 'major': 'N'},
#   {'name': 'persons', 'value': 'Kane, Christopher', 'rank': 12, 'major': 'N'},
#   {'name': 'persons', 'value': 'Krzanich, Brian M', 'rank': 13, 'major': 'N'},
#   {'name': 'persons', 'value': 'Lawrence, Jennifer', 'rank': 14, 'major': 'N'},
#   {'name': 'persons', 'value': 'Obama, Michelle', 'rank': 15, 'major': 'N'},
#   {'name': 'persons', 'value': 'Slimane, Hedi', 'rank': 16, 'major': 'N'},
#   {'name': 'persons', 'value': 'Tisci, Riccardo', 'rank': 17, 'major': 'N'},
#   {'name': 'persons',
#    'value': 'Vanhee-Cybulski, Nadege',
#    'rank': 18,
#    'major': 'N'},
#   {'name': 'persons', 'value': 'Witherspoon, Reese', 'rank': 19, 'major': 'N'},
#   {'name': 'organizations', 'value': 'Apple Inc', 'rank': 20, 'major': 'N'},
#   {'name': 'organizations', 'value': 'Givenchy', 'rank': 21, 'major': 'N'},
#   {'name': 'organizations', 'value': 'Gucci', 'rank': 22, 'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Maison Martin Margiela',
#    'rank': 23,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Nina Ricci (Fashion Label)',
#    'rank': 24,
#    'major': 'N'}],
#  'pub_date': '2015-01-05T14:03:03+0000',
#  'document_type': 'article',
#  'news_desk': 'Styles',
#  'section_name': 'Fashion & Style',
#  'byline': {'original': 'By Vanessa Friedman',
#   'person': [{'firstname': 'Vanessa',
#     'middlename': None,
#     'lastname': 'Friedman',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 1}],
#   'organization': None},
#  'type_of_material': 'News',
#  '_id': 'nyt://article/03ba6def-bbe8-5ef6-8711-44617f3e9c00',
#  'word_count': 753,
#  'uri': 'nyt://article/03ba6def-bbe8-5ef6-8711-44617f3e9c00'}

# %%
# check length 
len(data['response']['docs'])
# Out:
# 10

# %%
# Need to extract abstract, web_url, snippet, lead_paragraph, pub_date, document_type, section_name, type_of_material, rank (?)
article = data['response']['docs'][0]

# Testing retrieval of components
pub_date = article['pub_date']

abstract = article['abstract']
snippet = article['snippet']
lead_para = article['lead_paragraph']
headline = article['headline']['main']

doc_type = article['document_type']
section_name = article['section_name']
type_of_material = article['type_of_material']

# Find the rank of Apple Inc keyword in article: gauge of relevance 
keywords = article['keywords']
rank = next((item['rank'] for item in keywords if item['name'] == 'organizations' and item['value'] == 'Apple Inc'), None) # next retrieves first matching rank, may not be necessary

web_url = article['web_url']

# %%
pub_date
# Out:
# '2015-01-05T14:03:03+0000'

# %% [markdown]
# ##### Renaming files

# %%
import os
from pathlib import Path

base_dir = Path('../../data/raw')

# Loop through years
for year in range(2015, 2025):
    year_dir = base_dir / str(year)  # Construct path for each year

    # Traverse all files in the year directory
    for file in year_dir.rglob("*"):  # finds all files and subdirectories
        if file.is_file() and " " in file.name:
            new_name = file.name.replace(" ", "_")  
            new_path = file.with_name(new_name)  # Create new path
            file.rename(new_path)  # Rename the file
            print(f"Renamed: {file} -> {new_path}")  # Optional log output
# Out:
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth09_pg1 -> ../../data/raw/2015/organizations_Apple_Inc_mth09_pg1
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth08_pg1 -> ../../data/raw/2015/organizations_Apple_Inc_mth08_pg1
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth09_pg0 -> ../../data/raw/2015/organizations_Apple_Inc_mth09_pg0
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth08_pg0 -> ../../data/raw/2015/organizations_Apple_Inc_mth08_pg0
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth01_pg2 -> ../../data/raw/2015/organizations_Apple_Inc_mth01_pg2
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth03_pg3 -> ../../data/raw/2015/organizations_Apple_Inc_mth03_pg3
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth03_pg2 -> ../../data/raw/2015/organizations_Apple_Inc_mth03_pg2
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth04_pg3 -> ../../data/raw/2015/organizations_Apple_Inc_mth04_pg3
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth10_pg3 -> ../../data/raw/2015/organizations_Apple_Inc_mth10_pg3
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth06_pg2 -> ../../data/raw/2015/organizations_Apple_Inc_mth06_pg2
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth12_pg2 -> ../../data/raw/2015/organizations_Apple_Inc_mth12_pg2
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth04_pg2 -> ../../data/raw/2015/organizations_Apple_Inc_mth04_pg2
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth10_pg2 -> ../../data/raw/2015/organizations_Apple_Inc_mth10_pg2
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth06_pg3 -> ../../data/raw/2015/organizations_Apple_Inc_mth06_pg3
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth05_pg2 -> ../../data/raw/2015/organizations_Apple_Inc_mth05_pg2
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth09_pg5 -> ../../data/raw/2015/organizations_Apple_Inc_mth09_pg5
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth09_pg2 -> ../../data/raw/2015/organizations_Apple_Inc_mth09_pg2
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth09_pg3 -> ../../data/raw/2015/organizations_Apple_Inc_mth09_pg3
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth09_pg4 -> ../../data/raw/2015/organizations_Apple_Inc_mth09_pg4
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth03_pg0 -> ../../data/raw/2015/organizations_Apple_Inc_mth03_pg0
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth01_pg1 -> ../../data/raw/2015/organizations_Apple_Inc_mth01_pg1
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth02_pg0 -> ../../data/raw/2015/organizations_Apple_Inc_mth02_pg0
# Renamed: ../../data/raw/2015/organizations_Apple Inc_mth03_pg1 -> ../../data/raw/2015/organizations_Apple_Inc_mth03_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth09_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth09_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth08_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth08_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth09_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth09_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth08_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth08_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth01_pg2 -> ../../data/raw/2019/organizations_Apple_Inc_mth01_pg2
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth01_pg3 -> ../../data/raw/2019/organizations_Apple_Inc_mth01_pg3
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth06_pg2 -> ../../data/raw/2019/organizations_Apple_Inc_mth06_pg2
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth04_pg2 -> ../../data/raw/2019/organizations_Apple_Inc_mth04_pg2
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth11_pg2 -> ../../data/raw/2019/organizations_Apple_Inc_mth11_pg2
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth09_pg2 -> ../../data/raw/2019/organizations_Apple_Inc_mth09_pg2
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth03_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth03_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth01_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth01_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth02_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth02_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth03_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth03_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth02_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth02_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth01_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth01_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth11_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth11_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth05_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth05_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth06_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth06_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth12_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth12_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth07_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth07_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth04_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth04_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth10_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth10_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth06_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth06_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth12_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth12_pg0
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth11_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth11_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth05_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth05_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth04_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth04_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth10_pg1 -> ../../data/raw/2019/organizations_Apple_Inc_mth10_pg1
# Renamed: ../../data/raw/2019/organizations_Apple Inc_mth07_pg0 -> ../../data/raw/2019/organizations_Apple_Inc_mth07_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth09_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth09_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth08_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth08_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth09_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth09_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth08_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth08_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth01_pg2 -> ../../data/raw/2020/organizations_Apple_Inc_mth01_pg2
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth07_pg2 -> ../../data/raw/2020/organizations_Apple_Inc_mth07_pg2
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth10_pg2 -> ../../data/raw/2020/organizations_Apple_Inc_mth10_pg2
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth07_pg3 -> ../../data/raw/2020/organizations_Apple_Inc_mth07_pg3
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth03_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth03_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth01_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth01_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth02_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth02_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth02_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth02_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth01_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth01_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth11_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth11_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth05_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth05_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth06_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth06_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth12_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth12_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth07_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth07_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth04_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth04_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth10_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth10_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth06_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth06_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth12_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth12_pg0
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth04_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth04_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth10_pg1 -> ../../data/raw/2020/organizations_Apple_Inc_mth10_pg1
# Renamed: ../../data/raw/2020/organizations_Apple Inc_mth07_pg0 -> ../../data/raw/2020/organizations_Apple_Inc_mth07_pg0
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth09_pg1 -> ../../data/raw/2021/organizations_Apple_Inc_mth09_pg1
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth08_pg1 -> ../../data/raw/2021/organizations_Apple_Inc_mth08_pg1
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth09_pg0 -> ../../data/raw/2021/organizations_Apple_Inc_mth09_pg0
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth08_pg0 -> ../../data/raw/2021/organizations_Apple_Inc_mth08_pg0
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth06_pg2 -> ../../data/raw/2021/organizations_Apple_Inc_mth06_pg2
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth09_pg2 -> ../../data/raw/2021/organizations_Apple_Inc_mth09_pg2
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth09_pg3 -> ../../data/raw/2021/organizations_Apple_Inc_mth09_pg3
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth03_pg0 -> ../../data/raw/2021/organizations_Apple_Inc_mth03_pg0
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth02_pg0 -> ../../data/raw/2021/organizations_Apple_Inc_mth02_pg0
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth01_pg0 -> ../../data/raw/2021/organizations_Apple_Inc_mth01_pg0
# Renamed: ../../data/raw/2021/organizations_Apple Inc_mth11_pg0 -> ../../data/raw/2021/organizations_Apple_Inc_mth11_pg0
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth07_pg1 -> ../../data/raw/2022/organizations_Apple_Inc_mth07_pg1
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth04_pg0 -> ../../data/raw/2022/organizations_Apple_Inc_mth04_pg0
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth10_pg0 -> ../../data/raw/2022/organizations_Apple_Inc_mth10_pg0
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth06_pg0 -> ../../data/raw/2022/organizations_Apple_Inc_mth06_pg0
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth12_pg0 -> ../../data/raw/2022/organizations_Apple_Inc_mth12_pg0
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth11_pg1 -> ../../data/raw/2022/organizations_Apple_Inc_mth11_pg1
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth05_pg1 -> ../../data/raw/2022/organizations_Apple_Inc_mth05_pg1
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth04_pg1 -> ../../data/raw/2022/organizations_Apple_Inc_mth04_pg1
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth10_pg1 -> ../../data/raw/2022/organizations_Apple_Inc_mth10_pg1
# Renamed: ../../data/raw/2022/organizations_Apple Inc_mth07_pg0 -> ../../data/raw/2022/organizations_Apple_Inc_mth07_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth09_pg1 -> ../../data/raw/2023/organizations_Apple_Inc_mth09_pg1
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth09_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth09_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth08_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth08_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth03_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth03_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth02_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth02_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth01_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth01_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth11_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth11_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth05_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth05_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth06_pg1 -> ../../data/raw/2023/organizations_Apple_Inc_mth06_pg1
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth04_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth04_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth10_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth10_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth06_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth06_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth12_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth12_pg0
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth11_pg1 -> ../../data/raw/2023/organizations_Apple_Inc_mth11_pg1
# Renamed: ../../data/raw/2023/organizations_Apple Inc_mth07_pg0 -> ../../data/raw/2023/organizations_Apple_Inc_mth07_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth09_pg1 -> ../../data/raw/2024/organizations_Apple_Inc_mth09_pg1
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth08_pg1 -> ../../data/raw/2024/organizations_Apple_Inc_mth08_pg1
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth09_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth09_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth08_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth08_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth03_pg2 -> ../../data/raw/2024/organizations_Apple_Inc_mth03_pg2
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth03_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth03_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth01_pg1 -> ../../data/raw/2024/organizations_Apple_Inc_mth01_pg1
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth02_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth02_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth03_pg1 -> ../../data/raw/2024/organizations_Apple_Inc_mth03_pg1
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth02_pg1 -> ../../data/raw/2024/organizations_Apple_Inc_mth02_pg1
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth01_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth01_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth11_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth11_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth05_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth05_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth06_pg1 -> ../../data/raw/2024/organizations_Apple_Inc_mth06_pg1
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth04_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth04_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth10_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth10_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth06_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth06_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth12_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth12_pg0
# Renamed: ../../data/raw/2024/organizations_Apple Inc_mth07_pg0 -> ../../data/raw/2024/organizations_Apple_Inc_mth07_pg0
