# %% [markdown]
# # Evaluating Gemini on Financial Headlines

# %%
#install dependencies
# !pip install pandas numpy google-genai scikit-learn seaborn matplotlib

# %% [markdown]
# ## Load news data

# %%
#>=50% of annotators agreed on the financial sentiment 
from pathlib import Path
import pandas as pd

file_path = r'C:/Users/Tammy/Documents/GitHub/multimodal_stockprice_prediction/data/clean/text/Apple_Inc_text_data.csv'
# Load the CSV file with the specified encoding and column names
df = pd.read_csv(file_path,encoding='utf-8')

import re
# Cleaning function
def clean_text(text):
    # Remove non-ASCII characters
    text = re.sub(r'[^\x00-\x7F]+', '', text)

    # Convert to lowercase
    text = text.lower()

    # Remove punctuation and special characters (except spaces)
    text = re.sub(r'[^\w\s]', '', text)

    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
# Check the first few rows of the data
df.head()
# Out:
#                    pub_date  \
# 0  2015-04-07T09:17:59+0000
# 1  2015-04-14T20:46:01+0000
# 2  2015-04-13T22:00:31+0000
# 3  2015-04-22T19:42:26+0000
# 4  2015-04-01T10:21:53+0000
#
#                                             abstract  \
# 0  Want to work at Amazon, Apple or McKinsey? Som...
# 1  Get recommendations from New York Times report...
# 2  The business unit will partner with companies ...
# 3  With superstars first in line, Apple appears t...
# 4  In an industry that avoids controversy, the he...
#
#                                            lead_para  \
# 0  With some 13,000 graduate schools of business ...
# 1  Get recommendations from New York Times report...
# 2  IBM is taking its Watson artificial-intelligen...
# 3  Two weeks ago, Pharrell Williams posted an Ins...
# 4  The technology industry’s leaders have found t...
#
#                                             headline doc_type section_name  \
# 0  M.B.A. Programs That Get You Where You Want to Go  article    Education
# 1                                 What We’re Reading  article        Blogs
# 2  IBM Creates Watson Health to Analyze Medical Data  article   Technology
# 3  What’s That on Beyoncé’s Wrist? Let Me Guess ....  article        Style
# 4  Daily Report: Tech Leaders Come Together to Op...  article   Technology
#
#   type_of_material  rank                                            web_url
# 0             News     7  https://www.nytimes.com/2015/04/12/education/e...
# 1             News    13  https://news.blogs.nytimes.com/2015/04/14/what...
# 2             News     8  https://bits.blogs.nytimes.com/2015/04/13/ibm-...
# 3             News     1  https://www.nytimes.com/2015/04/23/style/whats...
# 4             News     3  https://bits.blogs.nytimes.com/2015/04/01/dail...

# %%
#reformat date
# format datetime again
df['pub_date'] = pd.to_datetime(df['pub_date']) 
df['pub_date'] = df['pub_date'].dt.date

# %%
#cleaning
df['headline'] = df['headline'].apply(clean_text) # change this line for abstract

# %%
# Select only the 'pub_date' and 'headline' columns
df_new = df[['pub_date', 'headline']] #change this line for abstract
  
# Check the new DataFrame
df_new.head()
# Out:
#      pub_date                                           headline
# 0  2015-04-07     mba programs that get you where you want to go
# 1  2015-04-14                                  what were reading
# 2  2015-04-13  ibm creates watson health to analyze medical data
# 3  2015-04-22  whats that on beyoncs wrist let me guess an ap...
# 4  2015-04-01  daily report tech leaders come together to opp...

# %% [markdown]
# ## Setting up Gemini

# %%
#set up gemini to process textual templates
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()
# Load environment variables from the .env file
API_KEY = os.getenv("API_KEY")
client = genai.Client(api_key=API_KEY)#insert api key

# %%
system_instruction = (
    "You are a financial analyst and an expert in detecting sentiment in financial news."
)

# %% [markdown]
# ## Function to call Gemini API

# %%
from google.genai import types
import json
# Function to get sentiment based on model output
def gemini_predict(prompt):
    try:
        # Generate content from the model
        response = client.models.generate_content(
            model='gemini-2.0-flash-lite', 
            contents=prompt,
            config=types.GenerateContentConfig(
            system_instruction=system_instruction,
            max_output_tokens=60,  # Label only
            temperature=0.5,      # More flexibility
            top_k=5,              # Limit to top 5 choices
            top_p=0.7,            # Consider tokens covering 70% probability mass
            response_mime_type='application/json',
            stop_sequences=['}']   # No stop sequence to avoid premature stops
            )
        )
        
        response_text = response.text.strip()
        
        # Attempt to fix incomplete JSON by appending a missing closing brace
        if not response_text.endswith('}'):
            response_text += '}'
        
        # Attempt to parse JSON
        try:
            response_json = json.loads(response_text)  # Parse JSON
            sentiment = response_json.get("Sentiment", "").strip()
            
            if sentiment not in ['Positive', 'Negative', 'Neutral']:
                sentiment = 'Neutral'
            
            return sentiment
        
        except json.JSONDecodeError:
            print(f"JSON Parsing Error. Response: {response_text}")
            return 'Error'
    
    except Exception as e:
        print(f"API Error: {e}")
        return 'Error'

# %% [markdown]
# ## Experiment with few-shot prompting

# %%
def find_sentiment_few_shot(text):
    prompt = f"""
    Classify the sentiment of the financial headline as 'Positive', 'Negative', or 'Neutral'. 
    Use 'Neutral' only if truly unclear. Be decisive—choose 'Positive' or 'Negative' whenever possible.

    Return the result in JSON format:

    Example:
    {{ "Sentiment": "Positive" }}

    Example 1:
    Headline: "Tech companies report record profits amid market optimism."
    Sentiment: Positive

    Example 2:
    Headline: "Stock futures drop after disappointing earnings."
    Sentiment: Negative

    Example 3:
    Headline: "Economic outlook remains uncertain amid policy changes."
    Sentiment: Neutral

    Example 4:
    Headline: "Tech companies report record profits amid market optimism."
    Sentiment: Positive

    Example 5:
    Headline: "Major banks face regulatory hurdles, impacting earnings outlook."
    Sentiment: Negative

    Headline: "{text}"
    Response (in JSON format):
    {{ "Sentiment":"""
    
    sentiment = gemini_predict(prompt)
    return sentiment

# %%
def apply_without_delay(df, sentiment_column):
    sentiment_list = []
    
    for idx, headline in enumerate(df[sentiment_column]):
        print(f"Processing {idx + 1}/{len(df)}: {headline}")  # Progress indicator
        
        sentiment = find_sentiment_few_shot(headline).lower()  # Gemini prediction in lowercase
        sentiment_list.append(sentiment)
    
    # Add Gemini's predictions while keeping original labels intact
    df['gemini_sentiment'] = sentiment_list
    return df

# %%
df_new =  apply_without_delay(df_new, 'headline')
print(df_new[['pub_date', 'headline', 'gemini_sentiment']])
# Out:
# Processing 1/2143: mba programs that get you where you want to go
# Processing 2/2143: what were reading
# Processing 3/2143: ibm creates watson health to analyze medical data
# Processing 4/2143: whats that on beyoncs wrist let me guess an apple watch
# Processing 5/2143: daily report tech leaders come together to oppose indiana law
# Processing 6/2143: dear diary my week wearing an apple watch
# Processing 7/2143: diagnosing a syncing problem with itunes
# Processing 8/2143: blackrocks chief laurence fink urges other ceos to stop being so nice to investors
# Processing 9/2143: apple watch review bliss but only after a steep learning curve
# Processing 10/2143: remotely controlling the dvr
# Processing 11/2143: apple ibm and japan post see profit in the oldage market
# Processing 12/2143: onetap giving extra steps mire mobile donations
# Processing 13/2143: apple tv remote expected to add touch pad in redesign
# Processing 14/2143: what were reading
# Processing 15/2143: apple acquires coherent navigation a gps startup
# Processing 16/2143: two apple designers step up as jony ive becomes chief design officer
# Processing 17/2143: how to use siri google now and cortana voice commands
# Processing 18/2143: appeals court upholds apples patent victory over samsung
# Processing 19/2143: apple watch a test run for travelers
# Processing 20/2143: podcast inside the timess apple watch news app
# Processing 21/2143: apple executive seeks a touch of chic at retail stores
# Processing 22/2143: fbi chief says texas gunman used encryption to text overseas terrorist
# Processing 23/2143: steve jobs flops at box office and silicon valley cheers
# Processing 24/2143: apple pushes against british talk of softening encryption
# Processing 25/2143: digging deeper for missing mac mail messages
# Processing 26/2143: below the line scoring steve jobs
# Processing 27/2143: apple gains exclusive streaming deal with taylor swift
# Processing 28/2143: dividing the screen in mac os x
# Processing 29/2143: with taps on the wrist apple watch points to the future
# Processing 30/2143: boston consultings most innovative companies lessons from a decade of ranking
# Processing 31/2143: choosing an ipad pro keyboard
# Processing 32/2143: apple pay is set to arrive in china
# Processing 33/2143: apple settles tax dispute with italian authorities
# Processing 34/2143: apple names periscope the top iphone app of 2015
# Processing 35/2143: daily report twitter hires a new executive in charge of diversity
# Processing 36/2143: breaking up with apple music
# Processing 37/2143: a protest app rises to the top in taiwan
# Processing 38/2143: why do i have to call this app julie
# Processing 39/2143: samsung to pay apple 548 million in patent dispute
# Processing 40/2143: apple makes shifts in senior management
# Processing 41/2143: apples neardeath experience saved it
# Processing 42/2143: use the iphones ios 8 like a pro
# Processing 43/2143: apple wont always rule just look at ibm
# Processing 44/2143: apple earnings automaker results and new products from tesla
# Processing 45/2143: working with old office files on a new mac os
# Processing 46/2143: the apple watch arrives in stores just not its own
# Processing 47/2143: hbo now makes game of thrones easier to see if not follow
# Processing 48/2143: apple watch has landed heres what you need to know
# Processing 49/2143: google joins its us peers under europes scrutiny
# Processing 50/2143: apples earnings surge as iphone sales jump and china business rises
# Processing 51/2143: what were reading
# Processing 52/2143: carine roitfeld uniqlo nyfws new homes and ryan gothling
# Processing 53/2143: downloading mac app updated automatically
# Processing 54/2143: working together in antarctica
# Processing 55/2143: amazon to stop funneling european sales through lowtax haven
# Processing 56/2143: forwarding text messages on the iphone
# Processing 57/2143: daily report after conquering the world androids course is uncertain
# Processing 58/2143: is your child your excuse to buy an apple watch
# Processing 59/2143: snapping the windows screen
# Processing 60/2143: google and apple adjust strategies on mobile payments
# Processing 61/2143: steve jobs a cottage industry of movies and books
# Processing 62/2143: the apple watch more than just a bracelet
# Processing 63/2143: with a tap of taylor swifts fingers apple retreated
# Processing 64/2143: apples conference gms annual meeting and a trade vote in europe
# Processing 65/2143: apple to unveil tool kit for watch app developers
# Processing 66/2143: zane lowe the dj scratching out beats 1 for apple
# Processing 67/2143: daily report apple unveils music service and software upgrades
# Processing 68/2143: daily report apple can afford some mistakes just not on products
# Processing 69/2143: apple music and labels investigated in 2 states
# Processing 70/2143: shop locally download globally
# Processing 71/2143: video feature apple watch apps that are available now
# Processing 72/2143: daily report taylor swift the most powerful person in the music industry
# Processing 73/2143: apple and google create a buzz at frankfurt motor show
# Processing 74/2143: siri apple music and other iphone questions
# Processing 75/2143: handson experience with apples new devices
# Processing 76/2143: charter and time warner vote and chinese tech meeting in seattle
# Processing 77/2143: a grab bag of software for the apple watch upgrade
# Processing 78/2143: narendra modi indian premier courts silicon valley to try to ease nations poverty
# Processing 79/2143: an apple kind of week
# Processing 80/2143: steve jobs receives warm reception at telluride film festival
# Processing 81/2143: iphone 6ss handsfree siri is an omen of the future
# Processing 82/2143: apple presses ahead with efforts to create car though big issues remain
# Processing 83/2143: when phone encryption blocks justice
# Processing 84/2143: apple music attracts 11 million users in trial period executive says
# Processing 85/2143: protecting your mac from malware and viruses
# Processing 86/2143: stopping the iphone step counter
# Processing 87/2143: daily report what a hiccup in startup land might look like
# Processing 88/2143: facebook tests a digital assistant for its messaging app
# Processing 89/2143: the cost of cable is preposterous readers sound off on settop boxes
# Processing 90/2143: the appeal of free 75 million users download windows 10 in first month
# Processing 91/2143: staying private in windows 10
# Processing 92/2143: a stock market rout in a month that hedge funds would sooner forget
# Processing 93/2143: nasdaq changed in its climb to 5000
# Processing 94/2143: apple and beats developing streaming music service to rival spotify
# Processing 95/2143: european union moves to limit special tax deals
# Processing 96/2143: digital dog collar
# Processing 97/2143: silicon valley leaders new to social issues come together over indiana law
# Processing 98/2143: introducing the apple watch
# Processing 99/2143: what begat what
# Processing 100/2143: in chase of apple smartphone makers shift strategies
# Processing 101/2143: what the world says about the apple watch
# Processing 102/2143: device syncing call from computers and text from tablets
# Processing 103/2143: apple backslides on workhour limits
# Processing 104/2143: apples new job selling a smartwatch to an uninterested public
# Processing 105/2143: samsung buys looppay a competitor to apples mobile wallet
# Processing 106/2143: new data shows apples explosive growth in china
# Processing 107/2143: choosing between amazons tv streaming hardware
# Processing 108/2143: filing away gmail messages
# Processing 109/2143: securing a hotmail account
# Processing 110/2143: importing images to iphoto
# Processing 111/2143: apple to open giant data center in arizona
# Processing 112/2143: apple loses patent case to small texas company
# Processing 113/2143: amazon to stop selling apple tv and chromecast
# Processing 114/2143: lease a smartphone or buy it the pros and cons
# Processing 115/2143: restoring sound to windows 10
# Processing 116/2143: iphonedemand drives apple profit but outlook is muted
# Processing 117/2143: volkswagen hit by emissions scandal posts its first loss in years
# Processing 118/2143: is america great only in movies
# Processing 119/2143: the fashion news to know this week
# Processing 120/2143: tech giants top best global brands list
# Processing 121/2143: lending kindle books
# Processing 122/2143: chinese hackers breached looppay whose tech is central to samsung pay
# Processing 123/2143: microsofts rulebreaking vision of a future with countless devices
# Processing 124/2143: putting mobile ad blockers to the test
# Processing 125/2143: obama wont seek access to encrypted user data
# Processing 126/2143: a view emerges of business technologys future as the personalization of the machine
# Processing 127/2143: apple watch success will hinge on apps
# Processing 128/2143: apples entry will help an antiquated dow catch up
# Processing 129/2143: apple opens up to praise new book on steve jobs and criticize an old one
# Processing 130/2143: jobs data in europe and us and car sales
# Processing 131/2143: apple watch demonstration questions for hsbc and greeces bailout
# Processing 132/2143: new york times develops an apple watch app
# Processing 133/2143: daily report jay z enters streaming music with artistowned service
# Processing 134/2143: outdated encryption keys leave phones vulnerable to hackers
# Processing 135/2143: at geneva auto show worry about silicon valley
# Processing 136/2143: pointing fingers in apple pay fraud
# Processing 137/2143: traveling with an iphone
# Processing 138/2143: apple building solar farm to power california operations
# Processing 139/2143: deleting files from microsofts onedrive
# Processing 140/2143: google and apple fight for the car dashboard
# Processing 141/2143: silicon valley shuttle drivers vote to join union
# Processing 142/2143: daily report automakers close to widely adopting dashboard tech from google and apple
# Processing 143/2143: tax reform is the cry until details are offered
# Processing 144/2143: aiming to ease app discovery apple pairs with pinterest
# Processing 145/2143: apple grabs 93 of the handset industrys profit report says
# Processing 146/2143: apple is forming an auto team
# Processing 147/2143: when is a lease not a lease when its an iphone
# Processing 148/2143: the complicated world of luxury watches
# Processing 149/2143: apple says iphone preorders are beating last years pace
# Processing 150/2143: how to talk to microsofts cortana
# Processing 151/2143: find out what apples new iphones and ios can do
# Processing 152/2143: apple improves the watch slightly
# Processing 153/2143: daily report its all apple all week
# Processing 154/2143: morning agenda yahoo rethinks alibaba spinoff
# Processing 155/2143: rand paul campaign makes pixelated pitch through an app
# Processing 156/2143: apple unveils new products and stephen colbert returns to late night
# Processing 157/2143: ian rogers apple music executive is leaving company
# Processing 158/2143: digging for trashed pictures in macs photos app
# Processing 159/2143: new dr dre album serves as a test for apple music
# Processing 160/2143: conquering androids stagefright bug
# Processing 161/2143: farhad and mikes week in tech facebook assistant
# Processing 162/2143: in a shift rite aid to accept apple and google mobile payments
# Processing 163/2143: doubt starts chipping away at the markets mindset
# Processing 164/2143: advisers work to calm fearful investors
# Processing 165/2143: apple stock reacts after tim cook email praises china sales
# Processing 166/2143: reviewing olio the latest entrant in the smartwatch sweepstakes
# Processing 167/2143: apple music is unveiled along with operating system upgrades
# Processing 168/2143: how to get windows 10
# Processing 169/2143: apple recalls beats pill xl speakers
# Processing 170/2143: turning the watch strap into a statement
# Processing 171/2143: earth as art from near inside a stone and far the space station
# Processing 172/2143: what apples tim cook overlooked in his defense of privacy
# Processing 173/2143: ruling that apple led ebook pricing conspiracy isupheld
# Processing 174/2143: highlights from apples developers conference
# Processing 175/2143: digital vintage
# Processing 176/2143: burberry creates a channel for apple music
# Processing 177/2143: big tech has become way too powerful
# Processing 178/2143: this week sizing up smartphone plans
# Processing 179/2143: mac user groups fade in number and influence but devotees press on
# Processing 180/2143: morning agenda more signs of a sharper slowdown in china
# Processing 181/2143: apple plus herms smartwatch dream team or weird mashup
# Processing 182/2143: daily report china asserts tech presence apple shows off new products
# Processing 183/2143: the fashion news to know today
# Processing 184/2143: daily report a new iphone for the slow upgrade crowd
# Processing 185/2143: coaxing a printer to work with windows 10
# Processing 186/2143: taking stock of a hard drives files
# Processing 187/2143: greeces debt payments apple earnings and credit suisse results
# Processing 188/2143: daily report apple music goes boldly where others have gone before
# Processing 189/2143: daily report sales of apple watch suggest a familiar path to success
# Processing 190/2143: with carplay apple looks to upend tradition
# Processing 191/2143: apple profit up 38 but iphone sales disappoint wall street
# Processing 192/2143: when this man is irked he might just file a suit
# Processing 193/2143: keeping dictation on a mac private
# Processing 194/2143: in apple watch debut signs of a familiar path to success
# Processing 195/2143: picking pockets off the firefox bookmarks list
# Processing 196/2143: video feature the apple collector
# Processing 197/2143: why im breaking up with the apple watch
# Processing 198/2143: daily report all eyes on apple
# Processing 199/2143: apple signs thousands of independent labels in royalty deal
# Processing 200/2143: seeking genuine discovery on music streaming services
# Processing 201/2143: apple music streaming service terms dismay indie record companies
# Processing 202/2143: can the swiss watchmaker survive the digital age
# Processing 203/2143: spotify wants listeners to break down music barriers
# Processing 204/2143: daily report apple to announce developer tools for watch plus music streaming plan
# Processing 205/2143: apple music makes debut with dj carrying the flag
# Processing 206/2143: apple earnings united states economic data and oil results
# Processing 207/2143: business technology starts to get personal
# Processing 208/2143: daily report amazon and the clash of the titans
# Processing 209/2143: mike and jims week in tech googles new version of android
# Processing 210/2143: the new apple tv invigorates the settop box
# Processing 211/2143: the mysterious case of apple and the elusive angela ahrendts
# Processing 212/2143: aaron sorkins steve jobs con
# Processing 213/2143: apple music has 65 million paying subscribers
# Processing 214/2143: using apple pay at starbucks kfc and chilis
# Processing 215/2143: aaron sorkin thinks were all too mean
# Processing 216/2143: amazons streaming music aims for more casual listeners
# Processing 217/2143: weighing benefits of windows 10 upgrade
# Processing 218/2143: becoming steve jobs by brent schlender and rick tetzeli
# Processing 219/2143: daily report using the apple watch
# Processing 220/2143: review becoming steve jobs focuses on another apple era
# Processing 221/2143: a conversation with the authors of becoming steve jobs
# Processing 222/2143: apple said to plan limited lowcost streaming service
# Processing 223/2143: the tax con cometh
# Processing 224/2143: the hidden talent of steve jobs
# Processing 225/2143: hbos streaming service will start in april initially on apple devices only
# Processing 226/2143: daily report the apple watch is nearly ready but is the public
# Processing 227/2143: in boon to its stock apple will replace att in dow index
# Processing 228/2143: apple watch displays your digital world at a glance
# Processing 229/2143: troubleshooting android in safe mode
# Processing 230/2143: suddenly plenty of options for cord cutters
# Processing 231/2143: pictures of the day egypt and elsewhere
# Processing 232/2143: key moments from apples event
# Processing 233/2143: in steve jobs tolerating techs unpleasant visionaries
# Processing 234/2143: morning agenda activist investors and billiondollar bets
# Processing 235/2143: as hopstop nears end of the line transfer to citymapper
# Processing 236/2143: daily report tech tussles take center stage in earnings
# Processing 237/2143: apps to organize and quell the political onslaught
# Processing 238/2143: daily report twitters fourthquarter forecast spooks investors
# Processing 239/2143: the patent troll smokescreen
# Processing 240/2143: publishers straddle the applegoogle appweb divide
# Processing 241/2143: apple is said to deactivate its news app in china
# Processing 242/2143: daily report apple twitter next up for tech earnings
# Processing 243/2143: apple plans peertopeer payment service
# Processing 244/2143: morning agenda the economic cost of terrorism
# Processing 245/2143: volkswagen hires expert in selfdriving cars from apple
# Processing 246/2143: facebooks notify app funnels custom updates onto phone screens
# Processing 247/2143: moving an itunes library with an external hard drive
# Processing 248/2143: morning agenda square sticks to its script
# Processing 249/2143: with a mobile website like an app flipkart takes a swipe at apple
# Processing 250/2143: video feature playing to the strengths of the new apple tv
# Processing 251/2143: backing up icloud contacts
# Processing 252/2143: apple apologizes to black students ejected from store in australia
# Processing 253/2143: music publishing deal driven by shift from sales to streaming
# Processing 254/2143: addicted to your smartphone the company that made it would like you to think so
# Processing 255/2143: apple music is strong on design weak on social networking
# Processing 256/2143: letting our emojis get in the way
# Processing 257/2143: daily report apples amazing quarter isnt good enough for wall street
# Processing 258/2143: apple waits as app developers study whos buying its watch
# Processing 259/2143: apple music spotify and a guide to music streaming services
# Processing 260/2143: in report on data collection practices whatsapp and att fail the test
# Processing 261/2143: taylor swift scuffle aside apples new music service is expected to thrive
# Processing 262/2143: apple takes on a market full of streaming services
# Processing 263/2143: recording a phones screen on a mac
# Processing 264/2143: square unveils mobile walletfriendly credit card reader
# Processing 265/2143: in return to twitter jack dorsey aims to follow path of steve jobs
# Processing 266/2143: affairs of the wrist the apple watch comes between them
# Processing 267/2143: taylor swift criticism spurs apple to change royalties policy
# Processing 268/2143: adjusting to apples new photo software
# Processing 269/2143: updating the macs software
# Processing 270/2143: apple iphone 6s breaks firstweekend sales record
# Processing 271/2143: decoding steve jobs in life and on film
# Processing 272/2143: apple and other tech companies tangle with us over data access
# Processing 273/2143: mike and quentins week in tech amazons offline game changer
# Processing 274/2143: daily report what stood out from apples product event
# Processing 275/2143: test driving apples ios 9
# Processing 276/2143: spellchecking your tweet
# Processing 277/2143: new apple tv is said to focus on games challenging traditional consoles
# Processing 278/2143: tim cook apples chief speaks on civic duty
# Processing 279/2143: farhad and mikes week in tech android pay and apple products
# Processing 280/2143: big business and antigay laws
# Processing 281/2143: converting audio from a cassette to mp3 requires an adapter
# Processing 282/2143: daily report apple watch bliss comes with steep learning curve
# Processing 283/2143: what were reading
# Processing 284/2143: how europe is going after apple google and other us tech giants
# Processing 285/2143: can the apple watch free us from phones
# Processing 286/2143: samsungs patent loss to apple is appealed to supreme court
# Processing 287/2143: a holiday wish list as in i wish i never got this
# Processing 288/2143: should you update to apple os x el capitan
# Processing 289/2143: importing photos to picasa in os x 1011
# Processing 290/2143: farhad and mike ruminate on the peaks and abysses of 2015
# Processing 291/2143: the trend i skipped this year
# Processing 292/2143: apple delays release of new apple watch software
# Processing 293/2143: enabling of ad blocking in apples ios 9 prompts backlash
# Processing 294/2143: review different thinking about steve jobs the man behind apple
# Processing 295/2143: with a revamped apple tv company hopes to camp in your home
# Processing 296/2143: answers to questions about apples new products
# Processing 297/2143: apple unveils iphone 6s and breaks own taboos with other offerings
# Processing 298/2143: apples iphone keeps going its own way
# Processing 299/2143: testing iphone 6ss 3d touch and live photos features
# Processing 300/2143: swiss watchmakers have one eye on apple
# Processing 301/2143: a lull after apples event
# Processing 302/2143: how and why apple overtook microsoft
# Processing 303/2143: daily report tech giants said to offer bigger settlement in antitrust case on hiring
# Processing 304/2143: daily report how apple surpassed microsoft
# Processing 305/2143: bigger settlement said to be reached in silicon valley antitrust case
# Processing 306/2143: iphone sales in china bolster apple earnings
# Processing 307/2143: new york attorney general seeks expanded reports on data breaches
# Processing 308/2143: cleaning up the macs printers list
# Processing 309/2143: in a world of phones gadgets must adapt
# Processing 310/2143: looking for the most recent facebook posts
# Processing 311/2143: apple and ericsson sue each other over mobile patents
# Processing 312/2143: what to watch for in 2015 galliano and gucci elections and apple
# Processing 313/2143: new rules in china upset western tech companies
# Processing 314/2143: apple acquires semetric a data analysis company
# Processing 315/2143: apples cut from app sales reached 45 billion in 2014
# Processing 316/2143: daily report iphone sales in china bolster apple earnings
# Processing 317/2143: what happens if apple drops google from its browser
# Processing 318/2143: video feature getting the most out of apple ios 8
# Processing 319/2143: avoiding botnets with a mac
# Processing 320/2143: sharing flickr photos privately
# Processing 321/2143: sec has yet to set rule on tricky ratio of ceos pay to workers
# Processing 322/2143: laurene powell jobs commits 50 million to create new high schools
# Processing 323/2143: apple confirms discovery of malicious code in some app store products
# Processing 324/2143: what you need to know about ios 9
# Processing 325/2143: app smart take advantage of ios 9
# Processing 326/2143: techfix iphone 6s buyers guide
# Processing 327/2143: app smart best apps for apple watch
# Processing 328/2143: the future of touch beyond apple watch
# Processing 329/2143: tech giants urge obama to reject policies that weaken encryption
# Processing 330/2143: a murky road ahead for android despite market dominance
# Processing 331/2143: bill gates andy grove and steve jobs the strategies they shared
# Processing 332/2143: hiding smartphone photo location information
# Processing 333/2143: european union delays action on apple amazon and starbucks tax inquiries
# Processing 334/2143: windshield devices bring distracted driving debate to eye level
# Processing 335/2143: daily report as mobile payments rise apple and google prepare their moves
# Processing 336/2143: antitrust and other inquiries in europe target us tech giants
# Processing 337/2143: auctioning the relics of technology pioneers
# Processing 338/2143: will the apple watch make us happier
# Processing 339/2143: banking on apple watch will be limited for now
# Processing 340/2143: has american business lost its mojo
# Processing 341/2143: apple watch availability is clarified
# Processing 342/2143: changing tactics apple promotes watch as a luxury item
# Processing 343/2143: daily report regulators in europe take aim at american tech giants
# Processing 344/2143: ahead of watch release apple to allow customers to try it on
# Processing 345/2143: europes google problem
# Processing 346/2143: iphone sales drop and apples 13year surge ebbs
# Processing 347/2143: fbi director suggests bill for iphone hacking topped 13 million
# Processing 348/2143: morning agenda new limits on bankers pay
# Processing 349/2143: moving cdripped music from the computer to the ipad
# Processing 350/2143: farhad and mikes week in tech the unstoppable facebook
# Processing 351/2143: why apples stand against the fbi hurts its own customers
# Processing 352/2143: apple to testify again and vw due date nears
# Processing 353/2143: samsung profits are up thanks to its galaxy 7 smartphone
# Processing 354/2143: a new windows pc for an old itunes library
# Processing 355/2143: different issues for next wave of tech earnings reports
# Processing 356/2143: sometimes in tech glitz trumps reason
# Processing 357/2143: getting up close with the ios camera
# Processing 358/2143: the clash of privacy legislation and software
# Processing 359/2143: police and tech giants wrangle over encryption on capitol hill
# Processing 360/2143: morning agenda swift reports a new attack
# Processing 361/2143: fitbit strives to escape the shadow of apple
# Processing 362/2143: sharing itunes store purchases
# Processing 363/2143: china quietly targets us tech companies in security reviews
# Processing 364/2143: europe seeks greater control over digital services
# Processing 365/2143: 15yearolds 200 vintage apple computers are now a mac museum
# Processing 366/2143: tips and myths about extending smartphone battery life
# Processing 367/2143: bill gates weighs in on apples clash with the fbi
# Processing 368/2143: what were reading
# Processing 369/2143: making the mac ignore those phone calls
# Processing 370/2143: silencing noisy web pages
# Processing 371/2143: fbi chief presses congress to act on data privacy
# Processing 372/2143: wristworthy new smartwatches
# Processing 373/2143: justice depts latest legal filing in apple case
# Processing 374/2143: apples motion opposing the iphone order
# Processing 375/2143: is apple right in defying the fbi
# Processing 376/2143: judge in apple case seen as unfazed by stress even a plane crash
# Processing 377/2143: defense secretary takes position against a data back door
# Processing 378/2143: farhad and joe examine silicon valleys pull in washington
# Processing 379/2143: competing interests on encryption divide top obama officials
# Processing 380/2143: apple vs the fbi how the case could play out
# Processing 381/2143: apples engineers if defiant would be in sync with ethics code
# Processing 382/2143: american tech giants face fight in europe over encrypted data
# Processing 383/2143: whatsapp encryption said to stymie wiretap order
# Processing 384/2143: apple policy on bugs may explain why hackers would help fbi
# Processing 385/2143: a ruling in apples favor
# Processing 386/2143: theres more than one way to scan on a mac
# Processing 387/2143: daily report tech executives meeting trump are in a tough spot
# Processing 388/2143: an iphones journey from the factory floor to the retail store
# Processing 389/2143: forget att the real monopolies are google and facebook
# Processing 390/2143: mario nintendos mustachioed gaming legend arrives on iphones
# Processing 391/2143: apple and nokia battle over cellphone patents
# Processing 392/2143: text messaging takes more apps into a chattier realm
# Processing 393/2143: when trump meets tech leaders jobs will be on the agenda
# Processing 394/2143: how to defend yourself against apples calendar spam
# Processing 395/2143: choosing a childs first smartphone
# Processing 396/2143: the builtin accessibility features of ios
# Processing 397/2143: rail crossing warnings are sought for mapping apps
# Processing 398/2143: daily report apple hurls the patent troll insult at nokia
# Processing 399/2143: apple music platform promoter both
# Processing 400/2143: how china built iphone city with billions in perks for apples partner
# Processing 401/2143: supreme court gives samsung a reprieve in apple patent case
# Processing 402/2143: apple says sales of iphones have slowed
# Processing 403/2143: alphabet close to overtaking apple as most valuable company
# Processing 404/2143: making music on an android tablet
# Processing 405/2143: trump calls for boycott of apple
# Processing 406/2143: un rights chief says unlocking gunmans iphone could open pandoras box
# Processing 407/2143: a smaller iphone and other highlights from apples product event
# Processing 408/2143: for apple potential flaw may be a wakeup call
# Processing 409/2143: apple encryption engineers if ordered to unlock iphone might resist
# Processing 410/2143: fbi clash with apple loosed a torrent of possible ways to hack an iphone
# Processing 411/2143: stepbystep fitness history on an iphone
# Processing 412/2143: breaking down apples iphone fight with the us government
# Processing 413/2143: filing to drop case against apple
# Processing 414/2143: fbi director discusses apple dispute
# Processing 415/2143: fbi used hacking software decade before iphone fight
# Processing 416/2143: moving pdfs to a pc from an ipad
# Processing 417/2143: farhad and mikes week in tech to be or not to be an uber employee
# Processing 418/2143: morning agenda comcast in talks to buy dreamworks animation
# Processing 419/2143: technology and banking sectors brace for earnings reports
# Processing 420/2143: apple services shut down in china in startling aboutface
# Processing 421/2143: fbi says it needs hackers to keep up with tech companies
# Processing 422/2143: fbi may have put down sword but privacy debate goes on
# Processing 423/2143: carl icahn says he has sold his stake in apple over china concerns
# Processing 424/2143: removing quicktime for windows in a hurry
# Processing 425/2143: rethinking apples recipe for success
# Processing 426/2143: an ipad misplaced at the airport takes its own vacation
# Processing 427/2143: locating a lost windows device
# Processing 428/2143: apple shifts from genius bars to genius groves hoping patrons linger
# Processing 429/2143: apple set to move to its spaceship should try more moonshots
# Processing 430/2143: podcasts surge but producers fear apple isnt listening
# Processing 431/2143: farhad and mikes week in tech the technology we love to hate
# Processing 432/2143: morning agenda north korea linked to attacks on banks
# Processing 433/2143: fixing a login keychain password error in osx
# Processing 434/2143: apples 1 billion investment may ease ties with china
# Processing 435/2143: apple faces an artificial intelligence challenge
# Processing 436/2143: apple iphone is targeted in beijing patent case
# Processing 437/2143: thirdparty keyboards give mobile users more options
# Processing 438/2143: two conferences next week each facing headwinds
# Processing 439/2143: what you need to know about apples software upgrades
# Processing 440/2143: apple starts to woo its app developers
# Processing 441/2143: the week ahead apple to woo developers and fed to hold monthly meeting
# Processing 442/2143: microsoft and apple making headlines
# Processing 443/2143: can apple think outside the device
# Processing 444/2143: put yourself in the soccer game no shin guards needed
# Processing 445/2143: daily report highlight of the apple hype wireless earbuds
# Processing 446/2143: how companies like apple dodge taxes and their own investors
# Processing 447/2143: ireland doesnt want apples back taxes but the irish arent so sure
# Processing 448/2143: eu rules look to unify digital market but us sees protectionism
# Processing 449/2143: daily report bay area claims transport center of the world title
# Processing 450/2143: apples iphone 7 and watch updates what you really need to know
# Processing 451/2143: iphone 7 and wireless headphones analyzing apples announcements
# Processing 452/2143: whats really missing from the new iphone cuttingedge design
# Processing 453/2143: morning agenda aigs exchief on trial apple taxes driverless updates
# Processing 454/2143: daily report iphone season is here but these days surprises are rare
# Processing 455/2143: converting spreadsheets in apples numbers to excel
# Processing 456/2143: put os x photos in the raw format
# Processing 457/2143: apples emoji gun control
# Processing 458/2143: daily report venture capitals endangered middle class
# Processing 459/2143: frank oceans blonde amplifies discord in the music business
# Processing 460/2143: google duo makes video calling between operating systems easier
# Processing 461/2143: once taunted by steve jobs companies are now big customers of apple
# Processing 462/2143: apple owes 145 billion in back taxes to ireland eu says
# Processing 463/2143: daily report the tax man comes for apple in ireland
# Processing 464/2143: apple congress and the missing taxes
# Processing 465/2143: debate over privacy finds little agreement
# Processing 466/2143: hillary clinton vows to defeat terrorism but cautions about shutting borders and torture
# Processing 467/2143: hunting the genetic signs of postpartum depression with an iphone app
# Processing 468/2143: us says it may not need apples help to unlock iphone
# Processing 469/2143: these apps promise to encrypt your smartphone communications
# Processing 470/2143: saving notes and highlights in ibooks
# Processing 471/2143: the government answers apple in the iphone case
# Processing 472/2143: rev robert palladino scribe who shaped apples fonts dies at 83
# Processing 473/2143: white house officials soften approach at rsa conference
# Processing 474/2143: to woo apple foxconn bets 35 billion on sharp
# Processing 475/2143: morning agenda feds neel kashkari says banks still too big to fail
# Processing 476/2143: apple still holds the keys to its cloud service but reluctantly
# Processing 477/2143: in poll on apple public sides with fbi
# Processing 478/2143: apple is said to be trying to make it harder to hack iphones
# Processing 479/2143: us asks tech and entertainment industries help in fighting terrorism
# Processing 480/2143: apples line in the sand was over a year in the making
# Processing 481/2143: seeking iphone data through the front door
# Processing 482/2143: apple wins ruling in new york iphone hacking order
# Processing 483/2143: apple and dr dre are said to be planning an original tv show
# Processing 484/2143: apple shareholders show their support for tim cook
# Processing 485/2143: morning agenda leon cooperman could face showdown with regulators
# Processing 486/2143: morning agenda ackmans reputation at risk
# Processing 487/2143: at rsa conference unlikely allies address value of digital security
# Processing 488/2143: privacy and the iphone
# Processing 489/2143: sizing up apples new downsized devices
# Processing 490/2143: apple gets tech industry backing in iphone dispute despite misgivings
# Processing 491/2143: europes antitrust enforcer on google apple and the year ahead
# Processing 492/2143: forget the new iphone for apple its all about the dollar
# Processing 493/2143: cracking the mystery of the missing itunes files
# Processing 494/2143: apples modest product upgrades take back seat to worries on iphone encryption
# Processing 495/2143: privacy vs security battle lines drawn
# Processing 496/2143: apples stance highlights a more confrontational tech industry
# Processing 497/2143: for apple a search for a moral high ground in a heated debate
# Processing 498/2143: farhad and mike hash out the weeks big topic apple
# Processing 499/2143: in nod to law enforcement in apple case obama ends attempt to straddle privacy divide
# Processing 500/2143: apple the fbi and a collection of very old laws
# Processing 501/2143: when the apple and fbi fight really began
# Processing 502/2143: the apple case will grope its way into your future
# Processing 503/2143: narrow focus may aid fbi in apple case
# Processing 504/2143: a brief explanation of apples showdown with the us government
# Processing 505/2143: amazon and pandora to gauge musics value in the internet age
# Processing 506/2143: phone makers could cut off drivers so why dont they
# Processing 507/2143: will the new apple iphone have a headphone jack rumormongers say it wont
# Processing 508/2143: make the macs share menu more useful
# Processing 509/2143: daily report tweaks on the road to wireless but no pyrotechnics from apple
# Processing 510/2143: apple opens the imessage door and the ephemera rushes in
# Processing 511/2143: ireland to appeal tax ruling in apple case
# Processing 512/2143: how tesla and apple could be good for each other
# Processing 513/2143: more fun on your wrist with new apps for the apple watch
# Processing 514/2143: ending apples offshore tax dodge
# Processing 515/2143: swiping a screen rather than flip a page in baseball
# Processing 516/2143: apple is said to owe back taxes to irish government
# Processing 517/2143: apple will pay a bug bounty to hackers who report flaws
# Processing 518/2143: should you charge your phone overnight
# Processing 519/2143: iphone users urged to update software after security flaws are found
# Processing 520/2143: apples gun emoji
# Processing 521/2143: morning agenda truck of takata airbag parts explodes apple faces taxes mondelez abandons hershey
# Processing 522/2143: yesterday outraged by apples tax dodge today by its tax bill
# Processing 523/2143: frank ocean releases a visual album with more to come
# Processing 524/2143: when every company is a tech company does the label matter
# Processing 525/2143: morning agenda timothy cooks tax arguments troncs just say no defense alphabet drives onto ubers turf
# Processing 526/2143: daily report more clean energy brought to you by the cloud
# Processing 527/2143: google duo challenges facetime
# Processing 528/2143: picking a digital publishing format
# Processing 529/2143: a few reasons your phone isnt getting the update
# Processing 530/2143: adding old movies to an oldfashioned ipod
# Processing 531/2143: apple becomes a green energy supplier with itself as customer
# Processing 532/2143: factchecking apples claims on eu tax ruling
# Processing 533/2143: readers ask about apples new iphone and watch
# Processing 534/2143: take a picture quickly in ios 10
# Processing 535/2143: iphone 7 review though not perfect new iphones keep apples promises
# Processing 536/2143: here come the iphone 7 and ios 10 apps what to try first
# Processing 537/2143: apple kicks the tires at mclaren
# Processing 538/2143: daily report the iphone 7 verdict is in
# Processing 539/2143: apple offers free app to teach children coding ipads sold separately
# Processing 540/2143: elizabeth warren what apple teaches us about taxes
# Processing 541/2143: extending the power of os x photos
# Processing 542/2143: farhads and mikes week in tech the iphones super mario moment
# Processing 543/2143: apple flounders but tidal will not steady the boat
# Processing 544/2143: tech behemoths report their results
# Processing 545/2143: apple in seeming jab at spotify proposes simpler songwriting royalties
# Processing 546/2143: apples ios 10 is available for beta testers who want a head start
# Processing 547/2143: morning agenda half of williams board resigns
# Processing 548/2143: staying under the os x radar
# Processing 549/2143: burning data with a hot spot
# Processing 550/2143: farhads and mikes week in tech death denial and selfdriving cars
# Processing 551/2143: easy editing for mac photos
# Processing 552/2143: the oppressive gospel of minimalism
# Processing 553/2143: why the world is drawing battle lines against american tech giants
# Processing 554/2143: weighing the system upgrade decision
# Processing 555/2143: apple to offer app developers access to siri and imessage
# Processing 556/2143: apple may soon open retail stores in india
# Processing 557/2143: american tech giants vs the nationstate
# Processing 558/2143: tekserve precursor to the apple store to close after 29 years
# Processing 559/2143: apple uneasy over donald trump wont support republican convention
# Processing 560/2143: hands off my smiley face emoji become corporate tools
# Processing 561/2143: zen and the art of managing smartphone photos
# Processing 562/2143: taking os x security seriously
# Processing 563/2143: move around an imac by touch
# Processing 564/2143: daily report googles day in europes court highlights nature of new tech
# Processing 565/2143: farhads and mikes week in tech the political evolution of silicon valley
# Processing 566/2143: google pixel review assessing the new smartphone
# Processing 567/2143: jims and nicks week in tech smoldering phones the yahoo markdown and amazon music
# Processing 568/2143: daily report at apple us jobs that go beyond manufacturing
# Processing 569/2143: make siri hear you on a mac mini
# Processing 570/2143: take your smartphone photography to the next level
# Processing 571/2143: daily report more fake retail apps means more users are at risk
# Processing 572/2143: a look at apples sprawling new campus in texas
# Processing 573/2143: future earns his third straight no 1 with evol
# Processing 574/2143: for alphabet the path to becoming the most valuable company in the world
# Processing 575/2143: google joins race to speed up mobile delivery of news articles
# Processing 576/2143: apple letter on iphone security draws muted tech industry response
# Processing 577/2143: in the government vs apple who wears the black hat
# Processing 578/2143: moving files to a mac from a pc
# Processing 579/2143: farhad and mike have a big story apple and some scraps
# Processing 580/2143: justice department calls apples refusal to unlock iphone a marketing strategy
# Processing 581/2143: finding ways to get live tv on a mac
# Processing 582/2143: mark zuckerberg backs apple in its refusal to unlock iphone
# Processing 583/2143: fbi error locked san bernardino attackers iphone
# Processing 584/2143: apple may be willing to risk contempt charge
# Processing 585/2143: apple and us bitterly turn up volume in iphone privacy fight
# Processing 586/2143: in apple debate on digital privacy and the iphone questions still remain
# Processing 587/2143: checking the graphics card specifications on your computer
# Processing 588/2143: farhad and mike parse virtual reality tech and the apple standoff
# Processing 589/2143: apple iphone hearing vw diesel update and luxury cars
# Processing 590/2143: farhad and mike on how apples new smaller iphone is easing the pain
# Processing 591/2143: keeping tabs on the sxsw interactive scene
# Processing 592/2143: in the apple case a debate over data hits home
# Processing 593/2143: apple sees value in its stand to protect security
# Processing 594/2143: chappatte on apple and the fbi
# Processing 595/2143: should the authorities be able to access your iphone
# Processing 596/2143: positions become sharper in apple showdown
# Processing 597/2143: public split between concern over terrorism and privacy
# Processing 598/2143: times readers weigh in on the apple debate
# Processing 599/2143: apple goes to court and fbi presses congress to settle iphone privacy fight
# Processing 600/2143: apples privacy fight tests relationship with white house
# Processing 601/2143: magic leap an augmented reality firm raises 793 million
# Processing 602/2143: analyzing apples argument that first amendment applies to its code
# Processing 603/2143: apple iphone standoff ends for now
# Processing 604/2143: apple and justice dept trade barbs in iphone privacy case
# Processing 605/2143: apple invokes rights of the american people in its fight
# Processing 606/2143: apples new challenge learning how the us cracked its iphone
# Processing 607/2143: legal briefs flood in to support apple
# Processing 608/2143: us says it has unlocked iphone without apple
# Processing 609/2143: apple and yahoo each struggle for control of their futures
# Processing 610/2143: finding photo programs that recognize faces
# Processing 611/2143: the iphone stays locked for now
# Processing 612/2143: apple is rolling up backers in iphone privacy fight against fbi
# Processing 613/2143: apple and samsung clash in the supreme court and sony goes virtual
# Processing 614/2143: apple predicts a big holiday bounce after its biggest rival samsung falters
# Processing 615/2143: us tech giants are investing billions to keep data in europe
# Processing 616/2143: paying 15 billion for twitter will be hard for anyone to justify
# Processing 617/2143: farhad and mikes week in tech microsoft apple and halloween
# Processing 618/2143: morning agenda new antitrust era relief for vw owners apples optimism
# Processing 619/2143: conundrum for justices does a design patent cover a whole smartphone
# Processing 620/2143: apples new macbook pro gets more touchy
# Processing 621/2143: apple and tesla to report earnings
# Processing 622/2143: when you outgrow your icloud storage
# Processing 623/2143: fighting ios calendar spam
# Processing 624/2143: beware iphone users fake retail apps are surging before holidays
# Processing 625/2143: how apple empowers and employs the american working class
# Processing 626/2143: turn an ipadmade movie into a dvd
# Processing 627/2143: moving a macs photos library
# Processing 628/2143: cold in your hotel room by voice or tablet you can change that
# Processing 629/2143: apples new macbook pro fast and light but not for everyone
# Processing 630/2143: dublin appeals 143 billion tax charge against apple
# Processing 631/2143: william moves wearables off the wrist with the help of kendall jenner and apple
# Processing 632/2143: in china toilets have trumps name without his permission
# Processing 633/2143: making siri spell your name right
# Processing 634/2143: farhads and mikes week in tech the cautionary tale of the fall of yahoo
# Processing 635/2143: reasons to believe the ai boom is real
# Processing 636/2143: spotify and apple music the goth vs the stoner
# Processing 637/2143: joshua brown who died in selfdriving accident tested limits of his tesla
# Processing 638/2143: apple pleases by not disappointing so much
# Processing 639/2143: what your router is trying to tell you
# Processing 640/2143: apples iphone sales drop again but services are a bright spot
# Processing 641/2143: keeping an iphone online when the signal is weak
# Processing 642/2143: amazon unveils online education service for teachers
# Processing 643/2143: silicon valley finds trumps disruption unwelcome
# Processing 644/2143: finding files on a mac running el capitan
# Processing 645/2143: farhads and mikes week in tech that business of microsoft buying linkedin
# Processing 646/2143: tech makes its pitch to the education community
# Processing 647/2143: illustrating your thoughts in ios notes
# Processing 648/2143: farhads and mikes week in tech are apples headphone jacks the new floppy drive
# Processing 649/2143: buybacks by companies like apple may signal danger not growth
# Processing 650/2143: apple developer conference a more open siri and other upgrades
# Processing 651/2143: apple moves toward a wireless future one tweak at a time
# Processing 652/2143: farhads and pauls week in tech apples china conundrum and samsungs recall conundrum
# Processing 653/2143: whom to vote for employees tend to follow their leader
# Processing 654/2143: apple is said to be rethinking strategy on selfdriving cars
# Processing 655/2143: samsung to recall 25 million galaxy note 7s over battery fires
# Processing 656/2143: white house pushes for exportimport bank deal as apple readies iphone update
# Processing 657/2143: apple is said to be talking to vehicle technology companies
# Processing 658/2143: apple in ireland
# Processing 659/2143: census bureau to report income data as tech rules take effect in europe
# Processing 660/2143: tim cook apple chief defends tax practices and says cash will return to us
# Processing 661/2143: waiting for round 2 in the phone fight
# Processing 662/2143: marking up a macs ibook pages
# Processing 663/2143: why you may want a smaller iphone and your questions answered
# Processing 664/2143: morning agenda the unsettling acquisitiveness of anbang
# Processing 665/2143: apple and justice dept prepare to face off in court
# ...
# Processing 1957/2143: the google trial is going to rewrite our future
# Processing 1958/2143: china denies banning iphones but cites unspecified security concerns
# Processing 1959/2143: the big number 1199
# Processing 1960/2143: biden administration unveils tougher guidelines on mergers
# Processing 1961/2143: i love you lets stalk each other
# Processing 1962/2143: the economic stakes in the hollywood shutdown
# Processing 1963/2143: warren and graham team up to take on big tech
# Processing 1964/2143: lindsey graham and elizabeth warren when it comes to big tech enough is enough
# Processing 1965/2143: a first try of apples 3500 vision pro headset
# Processing 1966/2143: business lessons from blinkens trip to china
# Processing 1967/2143: apple is stepping into the metaverse will anyone care
# Processing 1968/2143: can apple take the metaverse mainstream
# Processing 1969/2143: as us and chinese officials meet businesses temper their hopes
# Processing 1970/2143: business leaders join biden in welcoming modi to the us
# Processing 1971/2143: apples face computer crypto chaos and how teens really feel about social media
# Processing 1972/2143: apple knows you didnt mean to type ducking
# Processing 1973/2143: how the lionel messi deal stymied saudi arabia
# Processing 1974/2143: but would you wear it
# Processing 1975/2143: this is why google paid billions for apple to change a single setting
# Processing 1976/2143: consumer bureau seeks to supervise digital payment apps
# Processing 1977/2143: apple says it will improve the green vs blue texting experience
# Processing 1978/2143: google ceo says tech giant has improved the web for all consumers
# Processing 1979/2143: inside googles plan to stop apple from getting serious about search
# Processing 1980/2143: apples new film strategy debuts with killers of the flower moon
# Processing 1981/2143: spotify gave subscribers music and podcasts next audiobooks
# Processing 1982/2143: jon stewarts show on apple is ending
# Processing 1983/2143: the patent fight that could take apple watches off the market
# Processing 1984/2143: what the us has argued in the google antitrust trial
# Processing 1985/2143: foxconn apples manufacturer in china is said to be under tax audit
# Processing 1986/2143: investing has been ugly stick with it anyway
# Processing 1987/2143: read the document
# Processing 1988/2143: apples sales drop slightly while profit is up 11 percent
# Processing 1989/2143: how the biden administration took the pen away from meta google and amazon
# Processing 1990/2143: another google antitrust battle reaches court in epic games case
# Processing 1991/2143: apple cofounder steve wozniak is doing good after minor stroke
# Processing 1992/2143: what the bidenxi talks accomplished and didnt
# Processing 1993/2143: vague iphone alert triggers serious accusations of spying in india
# Processing 1994/2143: apple is doing its part to end green bubble shaming its our turn
# Processing 1995/2143: the long shadow of steve jobs looms over the turmoil at openai
# Processing 1996/2143: advertisers flee x as outcry over musks endorsement of antisemitic post grows
# Processing 1997/2143: you paid 1000 for an iphone but apple still controls it
# Processing 1998/2143: saudi arabias whatever it takes strategy boosts oil prices
# Processing 1999/2143: why i cant bet against apples mixedreality prowess
# Processing 2000/2143: dont wear the goggles their vision is bleak
# Processing 2001/2143: what trumps latest indictment means for the 2024 race
# Processing 2002/2143: apple debuts its next big product a virtual reality headset
# Processing 2003/2143: why is apple getting spatial
# Processing 2004/2143: apple reaches deal with investors to audit its labor practices
# Processing 2005/2143: a short seller costs an indian giant billions
# Processing 2006/2143: why does big tech make it so hard to fix your devices
# Processing 2007/2143: streaming changed tv is tv changing streaming back
# Processing 2008/2143: live nation faces a skeptical senate
# Processing 2009/2143: the secs crypto crackdown intensifies
# Processing 2010/2143: regulators find apples secrecy violates workers rights
# Processing 2011/2143: easy to use mobile payment apps are also easy to misuse
# Processing 2012/2143: tim cook dines with trump at maralago
# Processing 2013/2143: apple sued for failing to curtail child sexual abuse material on icloud
# Processing 2014/2143: the great capitulation
# Processing 2015/2143: the messy modern music business according to larry jackson
# Processing 2016/2143: how to find your way around that updated photos app
# Processing 2017/2143: on these apps the dark promise of mothers sexually abusing children
# Processing 2018/2143: switching from iphone to android is easy its the aftermath that stings
# Processing 2019/2143: pay later lenders have an issue with credit bureaus
# Processing 2020/2143: beeper messaging app is acquired as a bet on a regulatory shift
# Processing 2021/2143: apple says it was ordered to pull whatsapp from china app store
# Processing 2022/2143: apple lifts some restrictions on iphone repairs
# Processing 2023/2143: fifa said to be close to tv deal with apple for new tournament
# Processing 2024/2143: apple reports decline in sales and profit amid iphone struggles in china
# Processing 2025/2143: some iphone customers could get up to 349 in an apple settlement
# Processing 2026/2143: apple will revamp siri to catch up to its chatbot competitors
# Processing 2027/2143: what will warren buffett bet on next
# Processing 2028/2143: apples new ipad ad leaves its creative audience feeling flat
# Processing 2029/2143: scarjo vs chatgpt neuralinks first patient opens up and microsofts ai pcs
# Processing 2030/2143: us antitrust case against google is just the start
# Processing 2031/2143: someones going to end up dead settlements over fatal astroworld concert
# Processing 2032/2143: apple says destructive ipad ad missed the mark
# Processing 2033/2143: how to clean up your phones camera roll
# Processing 2034/2143: in venice george clooney talks president biden and american politics
# Processing 2035/2143: how to turn your old iphone into an ai phone and skip the upgrade
# Processing 2036/2143: can apples iphones pass the ai test
# Processing 2037/2143: foldables are becoming good enough to be your next smartphone
# Processing 2038/2143: why does my iphone keep asking me to check in with my ex
# Processing 2039/2143: amazon joins hollywoods top lobbying group
# Processing 2040/2143: apple unveils new iphones with builtin artificial intelligence
# Processing 2041/2143: after apple jony ive is building an empire of his own
# Processing 2042/2143: breaking up with china is hard to do
# Processing 2043/2143: chinas huawei shows the world its 2800 trifold phone
# Processing 2044/2143: after google antitrust ruling heres where other big tech cases stand
# Processing 2045/2143: sales of macs and ipads lead apples quarterly revenue up 5
# Processing 2046/2143: googles monopoly money is the ai bubble popping the hotmess express
# Processing 2047/2143: apple store workers get first us contract
# Processing 2048/2143: apple giving ground on app store rules to appease regulators
# Processing 2049/2143: google debuts aipowered phones in latest attempt to best the iphone
# Processing 2050/2143: new details on gaza ceasefire obstacles and musk interviews trump
# Processing 2051/2143: tech bosses preach patience as they spend and spend on ai
# Processing 2052/2143: abortion access on the ballot and hamas wont attend peace talks
# Processing 2053/2143: apple and nvidia in talks to invest in openai
# Processing 2054/2143: apple blocks epic games from using iphone tools in escalation of feud
# Processing 2055/2143: apple reverses course and allows epic games to start competing app store
# Processing 2056/2143: you texted i hadnt noticed
# Processing 2057/2143: is chinas era of high growth over
# Processing 2058/2143: musk vs openai europes tech crackdown and a month with the vision pro
# Processing 2059/2143: if nvidia keeps rising like this it will be bigger than the global economy
# Processing 2060/2143: how regulations fractured apples app store
# Processing 2061/2143: apples problems around the globe are piling up
# Processing 2062/2143: justice dept sues apple smartphones and children with jonathan haidt and reddits ipo
# Processing 2063/2143: big american tech profits from chinese ad spending spree
# Processing 2064/2143: apple has a new plan for its app store many developers hate it
# Processing 2065/2143: 40 years ago this ad changed the super bowl forever
# Processing 2066/2143: indias quiet push to steal more of chinas iphone business
# Processing 2067/2143: how apple used its car project to drive wider innovation
# Processing 2068/2143: ai promises give tech earnings a jolt
# Processing 2069/2143: why is big tech still cutting jobs
# Processing 2070/2143: can fitness trackers really make you fitter
# Processing 2071/2143: republican dysfunction and mom convicted in school shooting case
# Processing 2072/2143: apple sees first quarterly revenue increase in a year
# Processing 2073/2143: we tried the apple vision pro can congress protect kids online cruises crash
# Processing 2074/2143: the united states vs the iphone
# Processing 2075/2143: forced to change tech giants bow to global onslaught of rules
# Processing 2076/2143: how the fight against apple could redefine antitrust law
# Processing 2077/2143: apple keeps losing patent cases its solution rewrite the rules
# Processing 2078/2143: an analog library of all the lives ive lived
# Processing 2079/2143: the second coming of the microsoft antitrust battle
# Processing 2080/2143: us sues apple accusing it of maintaining an iphone monopoly
# Processing 2081/2143: eu takes aim at alphabet apple and meta in wideranging investigations
# Processing 2082/2143: apple fined 2 billion by eu for using app store to thwart competition
# Processing 2083/2143: apple and google are discussing a deal to bring generative ai to iphones
# Processing 2084/2143: vision pro review apples first headset lacks polish and purpose
# Processing 2085/2143: behind apples doomed car project false starts and wrong turns
# Processing 2086/2143: apple kills its electric car project
# Processing 2087/2143: stop wearing vision pro goggles while driving your tesla us says
# Processing 2088/2143: testing apples vision pro
# Processing 2089/2143: google and apple face billions in penalties after losing eu appeals
# Processing 2090/2143: apple rethinks its movie strategy after a string of misses
# Processing 2091/2143: coming to iphone city an electric car factory from foxconn
# Processing 2092/2143: telegram founders indictment thrusts encryption into the spotlight
# Processing 2093/2143: the apple of one business reporters eye
# Processing 2094/2143: how to clean up your phones photo library to free up space
# Processing 2095/2143: your driving app is leading you astray
# Processing 2096/2143: apple settles eu case by opening its payment service to rivals
# Processing 2097/2143: the future of streaming according to the moguls figuring it out
# Processing 2098/2143: can apple rescue the vision pro
# Processing 2099/2143: what the arrival of ai phones and computers means for our data
# Processing 2100/2143: welcome to the era of the ai smartphone
# Processing 2101/2143: hollywood sharpens aim at online pirates
# Processing 2102/2143: hey siri lets talk about how apple is giving you an ai makeover
# Processing 2103/2143: apple joins the ai party elons wild week and hatgpt
# Processing 2104/2143: apple jumps into ai fray with apple intelligence
# Processing 2105/2143: that muchdespised apple ad could be more disturbing than it looks
# Processing 2106/2143: apple is first company charged under new eu competition law
# Processing 2107/2143: the trustbuster who has apple and google in his sights
# Processing 2108/2143: us to push for gaza ceasefire apple gets sued and more
# Processing 2109/2143: read the lawsuit against apple
# Processing 2110/2143: five us cases targeting big tech
# Processing 2111/2143: can xeroxs parc a silicon valley icon find new life with sri
# Processing 2112/2143: garland accuses apple of violating federal antitrust law
# Processing 2113/2143: apple and goldman sachs must pay nearly 90 million in creditcard inquiry
# Processing 2114/2143: microsoft and openais close partnership shows signs of fraying
# Processing 2115/2143: founder mode explains the rise of trump in silicon valley
# Processing 2116/2143: apples ai is landing soon on iphones heres what its like
# Processing 2117/2143: can you turn off big techs ai tools sometimes and heres how
# Processing 2118/2143: apples quarterly profit down because of tax payment in europe
# Processing 2119/2143: did apple just kill social apps
# Processing 2120/2143: how to use images from your phone to search the web
# Processing 2121/2143: the cuttingedge hearing aids that you may already own
# Processing 2122/2143: hate noisy restaurants stick this in your ear
# Processing 2123/2143: the worlds pioneering tech cop is making her exit
# Processing 2124/2143: before the election tech ceos were quietly courting trump
# Processing 2125/2143: nvidia becomes most valuable public company topping microsoft
# Processing 2126/2143: grab them then stump them
# Processing 2127/2143: israeli hostage rescue fallout and far right wreaks havoc in europe
# Processing 2128/2143: i was addicted to my smartphone so i switched to a flip phone for a month
# Processing 2129/2143: microsoft tops apple to become most valuable public company
# Processing 2130/2143: apple takes messaging crackdown to customers macs
# Processing 2131/2143: apple says it will remove a health feature from new apple watches
# Processing 2132/2143: these seven tech stocks are driving the market
# Processing 2133/2143: the sp 500 through the prism of a magnificent 7
# Processing 2134/2143: the tech that needs fixing in 2024 and what got fixed last year
# Processing 2135/2143: the true price of apples 3500 vision pro is closer to 4600
# Processing 2136/2143: why making face computers cool isnt easy
# Processing 2137/2143: how to cut down your screen time but still get stuff done
# Processing 2138/2143: apple to offer rare discount on iphones in china
# Processing 2139/2143: apple takes a humble approach to launching its newest device
# Processing 2140/2143: apple overhauls app store in europe in response to new digital law
# Processing 2141/2143: the apple vision pro is a marvel but who will buy it
# Processing 2142/2143: us moves closer to filing sweeping antitrust case against apple
# Processing 2143/2143: charms can personalize your watch
#         pub_date                                           headline  \
# 0     2015-04-07     mba programs that get you where you want to go
# 1     2015-04-14                                  what were reading
# 2     2015-04-13  ibm creates watson health to analyze medical data
# 3     2015-04-22  whats that on beyoncs wrist let me guess an ap...
# 4     2015-04-01  daily report tech leaders come together to opp...
# ...          ...                                                ...
# 2138  2024-01-19  apple takes a humble approach to launching its...
# 2139  2024-01-25  apple overhauls app store in europe in respons...
# 2140  2024-01-31  the apple vision pro is a marvel but who will ...
# 2141  2024-01-05  us moves closer to filing sweeping antitrust c...
# 2142  2024-01-18                  charms can personalize your watch
#
#      gemini_sentiment
# 0             neutral
# 1             neutral
# 2             neutral
# 3             neutral
# 4            negative
# ...               ...
# 2138          neutral
# 2139          neutral
# 2140          neutral
# 2141         negative
# 2142          neutral
#
# [2143 rows x 3 columns]
# C:\Users\Tammy\AppData\Local\Temp\ipykernel_6220\4223195494.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gemini_sentiment'] = sentiment_list

# %%
df_new['gemini_sentiment'].value_counts()
# Out:
# gemini_sentiment
# neutral     1123
# negative     733
# positive     287
# Name: count, dtype: int64

# %%
df_new.head()
# Out:
#      pub_date                                           headline  \
# 0  2015-04-07     mba programs that get you where you want to go
# 1  2015-04-14                                  what were reading
# 2  2015-04-13  ibm creates watson health to analyze medical data
# 3  2015-04-22  whats that on beyoncs wrist let me guess an ap...
# 4  2015-04-01  daily report tech leaders come together to opp...
#
#   gemini_sentiment
# 0          neutral
# 1          neutral
# 2          neutral
# 3          neutral
# 4         negative

# %% [markdown]
# ## Save results to csv

# %%
df_new.to_csv('gemini_sentiment_analysis_results_AAPL_headlines.csv', index=False)

# %% [markdown]
# # Archive

# %% [markdown]
# ## Testing Gemini with curated news dataset

# %%
#get test dataset for prompt engineering
import numpy as np

def undersample_labels(df):
    """
    Undersamples the DataFrame so that each class in the 'label' column 
    has the same number of samples as the least frequent class.

    Parameters:
    df (pd.DataFrame): The input DataFrame with a 'label' column.

    Returns:
    pd.DataFrame: The undersampled DataFrame.
    """

    # Find the least frequent class count
    min_class_size = df['label'].value_counts().min()

    # Initialize an empty list to store undersampled data
    undersampled_data = []

    # Iterate through each unique class in 'label' and sample data
    for label in df['label'].unique():
        sampled_df = df[df['label'] == label].sample(n=min_class_size, random_state=42, replace=False)
        undersampled_data.append(sampled_df)

    # Combine sampled data, shuffle, and reset index
    undersampled_df = pd.concat(undersampled_data).sample(frac=1, random_state=42).reset_index(drop=True)

    return undersampled_df

# %%
undersampled_df = undersample_labels(df)
undersampled_df['label'].value_counts()
# Out:
# label
# positive    604
# negative    604
# neutral     604
# Name: count, dtype: int64

# %%
#extract a small dataset to improve prompt engineering 
# Sample 30 instances from each sentiment class
sample_size = 10  # Adjust this number based on your needs

test_df = undersampled_df.groupby('label', group_keys=False).apply(lambda x: x.sample(min(len(x), sample_size), random_state=42))

print(test_df)
# Out:
#          label                                           headline
# 368   negative  adp news may 29 2009 bank of america bofa down...
# 1366  negative  as a result of the negotiations the employment...
# 1704  negative  revenue was slightly down at x20ac 495 million...
# 268   negative  net sales decreased to eur 2205 mn from eur 47...
# 571   negative  tallink silja attributes the significant drop ...
# 920   negative    net sales have been eaten by the weak us dollar
# 55    negative  finnish geosentric s net sales decreased to eu...
# 1411  negative  in a separate announcement to the helsinki sto...
# 277   negative  in q2 of 2009 profit before taxes amounted to ...
# 1125  negative  kone said in court papers that the union actio...
# 303    neutral  these restrictions do not apply to statutory d...
# 1298   neutral  this solution is an extension to the existing ...
# 1701   neutral  last week however nokia announced that it will...
# 200    neutral                                       nwc analysis
# 537    neutral  a worm set to activate friday will corrupt doc...
# 824    neutral  below are unaudited consolidated results for a...
# 25     neutral  currently glaston employs approximately 1500 p...
# 1377   neutral  the company will issue an inaugural eurobond d...
# 203    neutral  also westpac is to issue a benchmark 18 month ...
# 975    neutral  rimi supermarket is the key customer in magist...
# 316   positive  kazgiprotsvetmet and outotec finland have sign...
# 1409  positive  operating profit rose to eur 47 mn from eur 36 mn
# 1710  positive  sales for the department store division increa...
# 219   positive  the fair value of the company s investment pro...
# 528   positive  cost cutting measures which have produced arou...
# 839   positive  with capman as a partner we will be able to fu...
# 26    positive  the total delivery volume of paper businesses ...
# 1460  positive  paper maker stora enso oyj said friday it has ...
# 220   positive  the robust growth was the result of the inclus...
# 1063  positive  quarterly diluted eps on continuing operations...
# C:\Users\Tammy\AppData\Local\Temp\ipykernel_32876\1116950502.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_df = undersampled_df.groupby('label', group_keys=False).apply(lambda x: x.sample(min(len(x), sample_size), random_state=42))

# %%
test_df['label'].value_counts()
# Out:
# label
# negative    10
# neutral     10
# positive    10
# Name: count, dtype: int64

# %%
#save the test data into csv 
test_df.to_csv("test_set_prompting.csv", index=False)

# %% [markdown]
# ## For Zero Shot

# %%
# Function to construct the prompt and get sentiment
def find_sentiment_zero_shot(text):
    prompt = f"""Evaluate the sentiment conveyed by the headline from an investment perspective. 
Assign one of the following sentiment labels:
Positive: For headlines with positive implications.
Negative: For headlines with negative implications.
Neutral: For headlines with unclear or neutral implications.

Headline: "{text}"
Sentiment:"""
    
    sentiment = gemini_predict(prompt)
    return sentiment

# %%
import time
# Apply the sentiment classification with delay
def apply_with_delay(df, sentiment_column, delay=4):
    sentiment_list = []
    
    for idx, headline in enumerate(df[sentiment_column]):
        print(f"Processing {idx + 1}/{len(df)}: {headline}")  # Progress indicator
        
        sentiment = find_sentiment_zero_shot(headline).lower()  # Gemini prediction in lowercase
        sentiment_list.append(sentiment)
        
        time.sleep(delay)  # Respect API rate limits
    
    # Add Gemini's predictions while keeping original labels intact
    df['gemini_sentiment'] = sentiment_list
    return df

# %%
test_df = apply_with_delay(test_df, 'headline')
print(test_df[['headline', 'label', 'gemini_sentiment']])
# Out:
# Processing 1/30: adp news may 29 2009 bank of america bofa downgraded today its ratings on swedishfinnish paper maker stora enso oyj hel sterv and on finnish sector player upmkymmene oyj hel upm1v to underperf
# Processing 2/30: as a result of the negotiations the employment of 130 blue and whitecollar employees at the oulu plant would be terminated
# Processing 3/30: revenue was slightly down at x20ac 495 million 634 million compared to x20ac 497 million a year earlier
# Processing 4/30: net sales decreased to eur 2205 mn from eur 4700 mn in the corresponding period in 2009
# Processing 5/30: tallink silja attributes the significant drop to problems with the booking system that was taken into operation in october the sale of trailer ferry sky wind and the route between stockholm and riga which has won passengers from the helsinkistockholm route
# Processing 6/30: net sales have been eaten by the weak us dollar
# Processing 7/30: finnish geosentric s net sales decreased to eur 939000 in januarymarch 2009
# Processing 8/30: in a separate announcement to the helsinki stock exchange atria revealed that the company s third quarter profits declined from eur13 9 m in the third quarter of last year to eur12 7 m in this year s q3
# Processing 9/30: in q2 of 2009 profit before taxes amounted to eur 136 mn down from eur 268 mn in q2 of 2008
# Processing 10/30: kone said in court papers that the union action delayed repairs to elevators at the federal courthouse on jan 21 and the saltonstall state office building on jan 23
# Processing 11/30: these restrictions do not apply to statutory dividends
# Processing 12/30: this solution is an extension to the existing online mediation solution delivered earlier by comptel and ibm
# Processing 13/30: last week however nokia announced that it will pursue a longterm relationship with microsoft and make the windows phone 7 operating system the foundation for nokia mobile phones
# Processing 14/30: nwc analysis
# Processing 15/30: a worm set to activate friday will corrupt documents using the most common file types including
# Processing 16/30: below are unaudited consolidated results for aspocomp group under ifrs reporting standards
# Processing 17/30: currently glaston employs approximately 1500 persons
# Processing 18/30: the company will issue an inaugural eurobond deal in the near future subject to market conditions
# Processing 19/30: also westpac is to issue a benchmark 18 month frn deal in euros
# Processing 20/30: rimi supermarket is the key customer in magistral center
# Processing 21/30: kazgiprotsvetmet and outotec finland have signed an agreement on strategic cooperation in the marketing and providing of minerals processing and metallurgical plants and related services in kazakhstan and the surrounding countries
# Processing 22/30: operating profit rose to eur 47 mn from eur 36 mn
# Processing 23/30: sales for the department store division increased by 15 and sales for the clothing store subsidiary seppala increased by 8 meanwhile sales for hobby hall decreased by 12
# Processing 24/30: the fair value of the company s investment properties grew to eur 2803 billion at the end of march 2009 from eur 2691 million a year ago
# Processing 25/30: cost cutting measures which have produced around eur70m of savings over the past nine months have dampened the airline s loss finnair said
# Processing 26/30: with capman as a partner we will be able to further develop our business and continue to focus on providing quality restaurant services for our customers says christopher wynne ceo of papa john s russia
# Processing 27/30: the total delivery volume of paper businesses in 2010 was 1155000 tonnes up from 1132000 tonnes in 2009
# Processing 28/30: paper maker stora enso oyj said friday it has been acquitted of charges that it participated in a paper pricefixing conspiracy in the united states
# Processing 29/30: the robust growth was the result of the inclusion of clothing chain lindex in the group in december 2007
# Processing 30/30: quarterly diluted eps on continuing operations came in at 021 eur compared with last year s 012 eur
#                                                headline     label  \
# 368   adp news may 29 2009 bank of america bofa down...  negative
# 1366  as a result of the negotiations the employment...  negative
# 1704  revenue was slightly down at x20ac 495 million...  negative
# 268   net sales decreased to eur 2205 mn from eur 47...  negative
# 571   tallink silja attributes the significant drop ...  negative
# 920     net sales have been eaten by the weak us dollar  negative
# 55    finnish geosentric s net sales decreased to eu...  negative
# 1411  in a separate announcement to the helsinki sto...  negative
# 277   in q2 of 2009 profit before taxes amounted to ...  negative
# 1125  kone said in court papers that the union actio...  negative
# 303   these restrictions do not apply to statutory d...   neutral
# 1298  this solution is an extension to the existing ...   neutral
# 1701  last week however nokia announced that it will...   neutral
# 200                                        nwc analysis   neutral
# 537   a worm set to activate friday will corrupt doc...   neutral
# 824   below are unaudited consolidated results for a...   neutral
# 25    currently glaston employs approximately 1500 p...   neutral
# 1377  the company will issue an inaugural eurobond d...   neutral
# 203   also westpac is to issue a benchmark 18 month ...   neutral
# 975   rimi supermarket is the key customer in magist...   neutral
# 316   kazgiprotsvetmet and outotec finland have sign...  positive
# 1409  operating profit rose to eur 47 mn from eur 36 mn  positive
# 1710  sales for the department store division increa...  positive
# 219   the fair value of the company s investment pro...  positive
# 528   cost cutting measures which have produced arou...  positive
# 839   with capman as a partner we will be able to fu...  positive
# 26    the total delivery volume of paper businesses ...  positive
# 1460  paper maker stora enso oyj said friday it has ...  positive
# 220   the robust growth was the result of the inclus...  positive
# 1063  quarterly diluted eps on continuing operations...  positive
#
#      gemini_sentiment
# 368          negative
# 1366         negative
# 1704         negative
# 268          negative
# 571          negative
# 920          negative
# 55           negative
# 1411         negative
# 277          negative
# 1125         negative
# 303          positive
# 1298          neutral
# 1701          neutral
# 200           neutral
# 537          negative
# 824           neutral
# 25            neutral
# 1377          neutral
# 203           neutral
# 975           neutral
# 316          positive
# 1409         positive
# 1710         positive
# 219          positive
# 528          positive
# 839          positive
# 26           positive
# 1460         positive
# 220           neutral
# 1063         positive

# %%
#make a class for all the studd used to train the LLM and the inputs should be in a different folder.

# %% [markdown]
# ## Results for Zero Shot Prompting

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure labels are lowercase in both actual and predicted columns
cm = confusion_matrix(
    test_df['label'].str.lower(),
    test_df['gemini_sentiment'],
    labels=['positive', 'neutral', 'negative']
)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['positive', 'neutral', 'negative'],
            yticklabels=['positive', 'neutral', 'negative'])
plt.xlabel('Predicted Sentiment')
plt.ylabel('Actual Sentiment')
plt.title("Confusion Matrix: Gemini's Sentiment Predictions")
plt.show()

# Detailed classification report
print(classification_report(
    test_df['label'].str.lower(),
    test_df['gemini_sentiment'],
    labels=['positive', 'neutral', 'negative']
))
# Out:
#               precision    recall  f1-score   support
#
#     positive       0.90      0.90      0.90        10
#      neutral       0.89      0.80      0.84        10
#     negative       0.91      1.00      0.95        10
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# ## Results for few shot prompting

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure labels are lowercase in both actual and predicted columns
cm = confusion_matrix(
    test_df['label'].str.lower(),
    test_df['gemini_sentiment'],
    labels=['positive', 'neutral', 'negative']
)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['positive', 'neutral', 'negative'],
            yticklabels=['positive', 'neutral', 'negative'])
plt.xlabel('Predicted Sentiment')
plt.ylabel('Actual Sentiment')
plt.title("Confusion Matrix: Gemini's Sentiment Predictions")
plt.show()

# Detailed classification report
print(classification_report(
    test_df['label'].str.lower(),
    test_df['gemini_sentiment'],
    labels=['positive', 'neutral', 'negative']
))
# Out:
#               precision    recall  f1-score   support
#
#     positive       0.91      1.00      0.95        10
#      neutral       1.00      0.80      0.89        10
#     negative       0.91      1.00      0.95        10
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.93      0.93        30
# weighted avg       0.94      0.93      0.93        30
