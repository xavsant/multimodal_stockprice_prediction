# %% [markdown]
# ### Data Processing

# %% [markdown]
# #### Setup

# %%
import pandas as pd
import json
import os
from pathlib import Path
import numpy as np

# %% [markdown]
# #### Reading JSON data into df

# %%
# Iterate through all articles in document
base_dir = Path('../../data/raw')
company = 'Apple_Inc'

def read_file(path):
    # Load content from json
    with open(path, 'r') as file:
        all_data = json.load(file)

    # Select response
    data = all_data['response']['docs']

    return data
   

def read_articles(data):

    column_list = ['pub_date','abstract','snippet','lead_para','headline','doc_type','section_name','type_of_material','rank','web_url']
    df = pd.DataFrame(columns=column_list)

    for article in data:
        # print(article)
        # Retrieve components
        pub_date = article['pub_date']

        abstract = article['abstract']
        snippet = article['snippet']
        lead_para = article['lead_paragraph']
        headline = article['headline']['main']

        doc_type = article['document_type']
        section_name = article['section_name']
        type_of_material = article.get('type_of_material', None) # will throw an error 

        keywords = article['keywords']
        rank = next((item['rank'] for item in keywords if item['name'] == 'organizations' and item['value'] == 'Apple Inc'), None) # next retrieves first matching rank, may not be necessary

        web_url = article['web_url']

        # Assign to new row in df
        df.loc[len(df)] = [pub_date,
                           abstract,
                           snippet,
                           lead_para,
                           headline,
                           doc_type,
                           section_name,
                           type_of_material,
                           rank,
                           web_url]
    
    return df


# MAIN function below
def compile_company_df(base_dir, company):
    
    column_list = ['pub_date','abstract','snippet','lead_para','headline','doc_type','section_name','type_of_material','rank','web_url']
    df = pd.DataFrame(columns=column_list)

    # Run through directory files
    for year in range(2015, 2025):
        year_dir = base_dir / str(year) 

        for file in year_dir.rglob("*"):
            if file.is_file() and company in file.name and 'fulltext' not in file.name: # modify this if fulltext check not req
                data = read_file(year_dir / file.name)
                temp_df = read_articles(data)
                df = pd.concat([df, temp_df], ignore_index=True)
    
    return df   

df = compile_company_df(base_dir, company)
# read_articles(data)
# read_file('../../data/raw/2015/organizations_Apple_Inc_mth01_pg0.json')
# data

# %% [markdown]
# #### Checking df
#
# Findings:
# <br><br>
# (1) Use abstract instead of snippet
# * Snippet and abstract are exactly the same in all except 6 cases + abstract is more complete
# * Snippet has 3 "" (empty string) values
# <br><br>
#
# (2) Consider either abstract OR lead para
# * Abstract and lead para frequently have some overlaps
# * Lead para is often longer/more detailed, but may not summarise the key point
# <br><br>
#
# (3) Null/empty string values
# * Lead para has 19 "" (empty string) values
# * Type of material has 1 null value
# <br><br>
#
# (4) No duplicates
# * Only repeats in headline/abstract occasionally, published on diff dates (regularly published column)
# <br><br>
#
# (Using Apple Inc as an example)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2143 entries, 0 to 2142
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pub_date          2143 non-null   object
#  1   abstract          2143 non-null   object
#  2   snippet           2143 non-null   object
#  3   lead_para         2143 non-null   object
#  4   headline          2143 non-null   object
#  5   doc_type          2143 non-null   object
#  6   section_name      2143 non-null   object
#  7   type_of_material  2142 non-null   object
#  8   rank              2143 non-null   object
#  9   web_url           2143 non-null   object
# dtypes: object(10)
# memory usage: 167.6+ KB

# %%
# Check if abstract == snippet
df[df.abstract != df.snippet].shape
# Out:
# (6, 10)

# %%
# Check if lead para == abstract
df[df.abstract != df.lead_para].shape
df[df.abstract != df.lead_para].head(10)
# Out:
#                    pub_date  \
# 0  2015-04-07T09:17:59+0000
# 1  2015-04-14T20:46:01+0000
# 2  2015-04-13T22:00:31+0000
# 3  2015-04-22T19:42:26+0000
# 4  2015-04-01T10:21:53+0000
# 5  2015-04-08T12:01:17+0000
# 6  2015-04-07T13:32:19+0000
# 7  2015-04-14T00:51:55+0000
# 8  2015-04-08T12:01:04+0000
# 9  2015-04-23T17:42:36+0000
#
#                                             abstract  \
# 0  Want to work at Amazon, Apple or McKinsey? Som...
# 1  Get recommendations from New York Times report...
# 2  The business unit will partner with companies ...
# 3  With superstars first in line, Apple appears t...
# 4  In an industry that avoids controversy, the he...
# 5  Spending seven days learning to use, and getti...
# 6  The iTunes software can automatically sync wit...
# 7  Laurence D. Fink, chief of BlackRock, the worl...
# 8  When apps are streamlined and first-generation...
# 9  Tips for Time Warner Cable customers who want ...
#
#                                              snippet  \
# 0  Want to work at Amazon, Apple or McKinsey? Som...
# 1  Get recommendations from New York Times report...
# 2  The business unit will partner with companies ...
# 3  With superstars first in line, Apple appears t...
# 4  In an industry that avoids controversy, the he...
# 5  Spending seven days learning to use, and getti...
# 6  The iTunes software can automatically sync wit...
# 7  Laurence D. Fink, chief of BlackRock, the worl...
# 8  When apps are streamlined and first-generation...
# 9  Tips for Time Warner Cable customers who want ...
#
#                                            lead_para  \
# 0  With some 13,000 graduate schools of business ...
# 1  Get recommendations from New York Times report...
# 2  IBM is taking its Watson artificial-intelligen...
# 3  Two weeks ago, Pharrell Williams posted an Ins...
# 4  The technology industry’s leaders have found t...
# 5  I picked up my Apple Watch last Wednesday at A...
# 6                                   ITunes Problems
# 7  On Tuesday morning, the chief executives of 50...
# 8  It took three days — three long, often confusi...
# 9  Q. I want to be able to set programs to record...
#
#                                             headline doc_type  section_name  \
# 0  M.B.A. Programs That Get You Where You Want to Go  article     Education
# 1                                 What We’re Reading  article         Blogs
# 2  IBM Creates Watson Health to Analyze Medical Data  article    Technology
# 3  What’s That on Beyoncé’s Wrist? Let Me Guess ....  article         Style
# 4  Daily Report: Tech Leaders Come Together to Op...  article    Technology
# 5         Dear Diary: My Week Wearing an Apple Watch  article    Technology
# 6           Diagnosing a Syncing Problem With iTunes  article    Technology
# 7  BlackRock’s Chief, Laurence Fink, Urges Other ...  article  Business Day
# 8  Apple Watch Review: Bliss, but Only After a St...  article    Technology
# 9                       Remotely Controlling the DVR  article    Technology
#
#   type_of_material rank                                            web_url
# 0             News    7  https://www.nytimes.com/2015/04/12/education/e...
# 1             News   13  https://news.blogs.nytimes.com/2015/04/14/what...
# 2             News    8  https://bits.blogs.nytimes.com/2015/04/13/ibm-...
# 3             News    1  https://www.nytimes.com/2015/04/23/style/whats...
# 4             News    3  https://bits.blogs.nytimes.com/2015/04/01/dail...
# 5             News    1  https://www.nytimes.com/2015/04/09/technology/...
# 6         Question    5  https://www.nytimes.com/2015/04/09/technology/...
# 7             News    7  https://www.nytimes.com/2015/04/14/business/de...
# 8             News    2  https://www.nytimes.com/2015/04/09/technology/...
# 9         Question    6  https://www.nytimes.com/2015/04/24/technology/...

# %%
df.iloc[176, 1:3].abstract
# Out:
# 'We’re not creating the new businesses we should be, and these giants have to be broken up.'

# %%
df.iloc[176, 1:3].snippet
# Out:
# 'We’re not creating the new businesses we should be, and these giants have to be broken up.'

# %%
#check for empty strings
(df == "").sum()
# Out:
# pub_date             0
# abstract             0
# snippet              3
# lead_para           19
# headline             0
# doc_type             0
# section_name         0
# type_of_material     0
# rank                 0
# web_url              0
# dtype: int64

# %%
df[df.snippet == ""]
# Out:
#                       pub_date  \
# 1575  2021-05-27T12:21:50+0000
# 1598  2021-05-03T11:31:09+0000
# 1641  2021-02-16T21:27:40+0000
#
#                                                abstract snippet  \
# 1575  When Apple and Google collaborated last year o...
# 1598  Apple and Epic Games, maker of the wildly popu...
# 1641  A North Dakota bill that an Apple executive ha...
#
#                                               lead_para  \
# 1575  When Apple and Google collaborated last year o...
# 1598  Apple and Epic Games, maker of the wildly popu...
# 1641  A North Dakota bill that an Apple executive ha...
#
#                                                headline doc_type  \
# 1575  Virus alert apps powered by Apple and Google h...  article
# 1598  Apple and Epic Games head to court over app re...  article
# 1641  North Dakota lawmakers vote down a bill that t...  article
#
#       section_name type_of_material rank  \
# 1575  Business Day             News    5
# 1598  Business Day             News    5
# 1641  Business Day             News    2
#
#                                                 web_url
# 1575  https://www.nytimes.com/2021/05/27/business/vi...
# 1598  https://www.nytimes.com/2021/05/03/business/ap...
# 1641  https://www.nytimes.com/2021/02/16/business/no...

# %%
# 19 lead_paras blank
df[df.lead_para == ""]
# Out:
#                       pub_date  \
# 55    2015-05-22T13:14:57+0000
# 69    2015-06-10T15:45:58+0000
# 90    2015-08-26T16:38:32+0000
# 106   2015-02-27T15:06:31+0000
# 109   2015-02-11T14:35:37+0000
# 114   2015-10-14T20:42:04+0000
# 149   2015-09-16T13:32:10+0000
# 157   2015-08-07T13:36:02+0000
# 184   2015-09-04T15:22:20+0000
# 194   2015-07-15T17:56:34+0000
# 222   2015-03-02T17:55:05+0000
# 262   2015-06-12T14:07:31+0000
# 275   2015-09-22T16:30:20+0000
# 280   2015-04-03T13:42:14+0000
# 319   2015-01-02T17:09:23+0000
# 338   2015-04-17T14:07:02+0000
# 406   2016-03-21T10:03:22+0000
# 1081  2018-11-12T17:13:15+0000
# 1796  2022-03-24T09:00:31+0000
#
#                                                abstract  \
# 55    You can send the message to someone not in the...
# 69    Some independent booksellers gain a portion of...
# 90    Microsoft collects personal data on users of W...
# 106   Learn about the differences between Amazon Fir...
# 109   Tips on how to transfer photographs into iPhot...
# 114   Upgrading from an older version of Windows can...
# 149   If your computer did not come with a microphon...
# 157   Recovering discarded photos before they are go...
# 184   How to get your Windows 10 operating system to...
# 194   How to rid the bookmarks menu of a utility you...
# 222   The Internal Revenue Service is not emailing y...
# 262   Tips for mirroring your phone’s display on a M...
# 275   Twitter’s apps make use of the spell-checking ...
# 280   The inexpensive device links a standard audio ...
# 319   You can adjust your settings so that only cert...
# 338   Apps will allow users to peek at their balance...
# 406   Times reporters provided live analysis from th...
# 1081  What does it mean to be digital? Think back to...
# 1796  More than 400 companies have withdrawn, at lea...
#
#                                                 snippet lead_para  \
# 55    You can send the message to someone not in the...
# 69    Some independent booksellers gain a portion of...
# 90    Microsoft collects personal data on users of W...
# 106   Learn about the differences between Amazon Fir...
# 109   Tips on how to transfer photographs into iPhot...
# 114   Upgrading from an older version of Windows can...
# 149   If your computer did not come with a microphon...
# 157   Recovering discarded photos before they are go...
# 184   How to get your Windows 10 operating system to...
# 194   How to rid the bookmarks menu of a utility you...
# 222   The Internal Revenue Service is not emailing y...
# 262   Tips for mirroring your phone’s display on a M...
# 275   Twitter’s apps make use of the spell-checking ...
# 280   The inexpensive device links a standard audio ...
# 319   You can adjust your settings so that only cert...
# 338   Apps will allow users to peek at their balance...
# 406   Times reporters provided live analysis from th...
# 1081  What does it mean to be digital? Think back to...
# 1796  More than 400 companies have withdrawn, at lea...
#
#                                                headline  doc_type  \
# 55               Forwarding Text Messages on the iPhone   article
# 69                      Shop Locally, Download Globally   article
# 90                        Staying Private in Windows 10   article
# 106     Choosing Between Amazon’s TV Streaming Hardware   article
# 109                          Importing Images to iPhoto   article
# 114                       Restoring Sound to Windows 10   article
# 149                  How to Talk to Microsoft’s Cortana   article
# 157    Digging for Trashed Pictures in Mac’s Photos App   article
# 184           Coaxing a Printer to Work With Windows 10   article
# 194      Picking Pockets Off the Firefox Bookmarks List   article
# 222                                  The Tax Con Cometh   article
# 262                 Recording a Phone’s Screen on a Mac   article
# 275                           Spell-Checking Your Tweet   article
# 280   Converting Audio From a Cassette to MP3 Requir...   article
# 319                     Sharing Flickr Photos Privately   article
# 338     Banking on Apple Watch Will Be Limited, for Now   article
# 406   A Smaller iPhone and Other Highlights From App...   article
# 1081  Getting Digital Right: Posers, Players and Pro...  paidpost
# 1796                                No Longer in Russia   article
#
#       section_name type_of_material rank  \
# 55      Technology         Question    6
# 69      Technology         Question    4
# 90      Technology         Question    6
# 106     Technology         Question    4
# 109     Technology         Question   12
# 114     Technology         Question    7
# 149     Technology         Question    5
# 157     Technology         Question    1
# 184     Technology         Question    2
# 194     Technology         Question    7
# 222     Technology         Question    4
# 262     Technology         Question    1
# 275     Technology         Question    3
# 280     Technology         Question    3
# 319     Technology         Question    5
# 338     Your Money             News    3
# 406     Technology             News    5
# 1081       T Brand             None    3
# 1796  Business Day             News    4
#
#                                                 web_url
# 55    https://www.nytimes.com/2015/05/23/technology/...
# 69    https://www.nytimes.com/2015/06/11/technology/...
# 90    https://www.nytimes.com/2015/08/27/technology/...
# 106   https://www.nytimes.com/2015/02/27/technology/...
# 109   https://www.nytimes.com/2015/02/12/technology/...
# 114   https://www.nytimes.com/2015/10/15/technology/...
# 149   https://www.nytimes.com/2015/09/17/technology/...
# 157   https://www.nytimes.com/2015/08/08/technology/...
# 184   https://www.nytimes.com/2015/09/05/technology/...
# 194   https://www.nytimes.com/2015/07/16/technology/...
# 222   https://www.nytimes.com/2015/03/05/technology/...
# 262   https://www.nytimes.com/2015/06/13/technology/...
# 275   https://www.nytimes.com/2015/09/24/technology/...
# 280   https://www.nytimes.com/2015/04/03/technology/...
# 319   https://www.nytimes.com/2015/01/02/technology/...
# 338   https://www.nytimes.com/2015/04/17/your-money/...
# 406   https://www.nytimes.com/live/apple-iphone-even...
# 1081  https://www.nytimes.com/paidpost/pwc/getting-d...
# 1796  https://www.nytimes.com/2022/03/24/business/co...

# %%
# check for duplicates 
df.duplicated().sum()
df[['headline']].duplicated().sum() # 6 duplicates, but on different days, due to regular published column
df[df[['headline']].duplicated()]
# Out:
#                       pub_date  \
# 13    2015-05-08T20:58:24+0000
# 50    2015-04-24T21:04:40+0000
# 282   2015-04-07T21:14:06+0000
# 367   2016-02-19T21:52:48+0000
# 924   2017-07-30T18:23:44+0000
# 1776  2022-09-07T21:55:35+0000
#
#                                                abstract  \
# 13    Get recommendations from New York Times report...
# 50    Get recommendations from New York Times report...
# 282   Get recommendations from New York Times report...
# 367   Get recommendations from New York Times report...
# 924   The world’s most valuable company appears to h...
# 1776  Here’s what you need to know at the end of the...
#
#                                                 snippet  \
# 13    Get recommendations from New York Times report...
# 50    Get recommendations from New York Times report...
# 282   Get recommendations from New York Times report...
# 367   Get recommendations from New York Times report...
# 924   The world’s most valuable company appears to h...
# 1776  Here’s what you need to know at the end of the...
#
#                                               lead_para  \
# 13    Get recommendations from New York Times report...
# 50    Get recommendations from New York Times report...
# 282   Get recommendations from New York Times report...
# 367   Get recommendations from New York Times report...
# 924   HONG KONG — Software made by foreign companies...
# 1776  (Want to get this newsletter in your inbox? He...
#
#                                                headline doc_type section_name  \
# 13                                   What We’re Reading  article        Blogs
# 50                                   What We’re Reading  article        Blogs
# 282                                  What We’re Reading  article        Blogs
# 367                                  What We’re Reading  article        Blogs
# 924   Apple Removes Apps From China Store That Help ...  article   Technology
# 1776                    Your Wednesday Evening Briefing  article     Briefing
#
#      type_of_material rank                                            web_url
# 13               News   15  https://news.blogs.nytimes.com/2015/05/08/what...
# 50               News   21  https://news.blogs.nytimes.com/2015/04/24/what...
# 282              News   16  https://news.blogs.nytimes.com/2015/04/07/what...
# 367              News   19  https://news.blogs.nytimes.com/2016/02/19/what...
# 924              News    2  https://www.nytimes.com/2017/07/30/technology/...
# 1776             News    6  https://www.nytimes.com/2022/09/07/briefing/vo...

# %%
# Check headlines
pd.set_option('display.max_colwidth', None)
print(df['headline'])
# Out:
# 0                         M.B.A. Programs That Get You Where You Want to Go
# 1                                                        What We’re Reading
# 2                         IBM Creates Watson Health to Analyze Medical Data
# 3           What’s That on Beyoncé’s Wrist? Let Me Guess ... an Apple Watch
# 4            Daily Report: Tech Leaders Come Together to Oppose Indiana Law
#                                        ...
# 2138           Apple Takes a Humble Approach to Launching Its Newest Device
# 2139    Apple Overhauls App Store in Europe, in Response to New Digital Law
# 2140                 The Apple Vision Pro Is a Marvel. But Who Will Buy It?
# 2141      U.S. Moves Closer to Filing Sweeping Antitrust Case Against Apple
# 2142                                      Charms Can Personalize Your Watch
# Name: headline, Length: 2143, dtype: object

# %%
# Check lead paras
df['lead_para'].head(10)
# Out:
# 0                                                                                                                                                                                                                                                                       With some 13,000 graduate schools of business across the globe, the M.B.A. degree has clearly become a commodity.
# 1                                                                                                                                                                                                               Get recommendations from New York Times reporters and editors, highlighting great stories from around the web. What We’re Reading emails are sent twice a week. Sign up »
# 2                                                                                                                                                                                                                       IBM is taking its Watson artificial-intelligence technology into health care in a big way with industry partners, a pair of acquisitions and an ambitious agenda.
# 3                                                                                                                                                                                                                                                                    Two weeks ago, Pharrell Williams posted an Instagram video of his Apple Watch. The clip has more than 119,000 likes.
# 4    The technology industry’s leaders have found their collective voice on a social issue in the last week, rallying with great intensity against a new Indiana law that will allow businesses, they predict, to discriminate against gay couples. The heads of Apple, Salesforce.com, Yelp and Square have all publicly criticized the law, as have some leaders from other industries.
# 5                                                                                               I picked up my Apple Watch last Wednesday at Apple headquarters in Cupertino, Calif. After interviewing some of the designers and engineers who worked on the device, I was given a guided tour of the watch, similar to what customers will receive when they buy one at an Apple Store.
# 6                                                                                                                                                                                                                                                                                                                                                                        ITunes Problems
# 7                                                                                                                                                                                                                                On Tuesday morning, the chief executives of 500 of the nation’s largest companies will receive a letter in the mail that will most likely surprise them.
# 8                                                                                                                                                                                                                                               It took three days — three long, often confusing and frustrating days — for me to fall for the Apple Watch. But once I fell, I fell hard.
# 9                                                                                                                                                                                                               Q. I want to be able to set programs to record on my digital video recorder from my iPhone, but the Time Warner Cable app keeps crashing on me when I try. What can I do?
# Name: lead_para, dtype: object

# %%
# Check abstract
df['abstract'].head(10)
# Out:
# 0                                                      Want to work at Amazon, Apple or McKinsey? Some business schools have impressive records placing graduates in certain fields and even companies.
# 1    Get recommendations from New York Times reporters and editors, highlighting interesting stories from around the web. In this installment, great reads from Stacy Cowley, Quentin Hardy and others.
# 2    The business unit will partner with companies including Apple, Medtronic and Johnson & Johnson, offering IBM’s Watson technology as a cloud-based tool at many levels of the health care industry.
# 3                                                                     With superstars first in line, Apple appears to be seeking exclusivity by limiting where its watches are sold and who wears them.
# 4                                                   In an industry that avoids controversy, the heads of several prominent companies, including Apple and Salesforce.com, have chosen to pick a battle.
# 5                                                                                 Spending seven days learning to use, and getting used to, the Apple Watch proved to be a mostly rewarding experience.
# 6                                          The iTunes software can automatically sync with iPads, iPhones and iPod Touch players, but even if the feature is enabled in iTunes, a few conditions apply.
# 7                                                                               Laurence D. Fink, chief of BlackRock, the world’s largest asset manager, warns of harm in dividends and stock buybacks.
# 8                                                                  When apps are streamlined and first-generation bugs are fixed, the Apple Watch has the potential to be a life-changer. (With video.)
# 9                                                                                                          Tips for Time Warner Cable customers who want to use their iPhones to manage DVR recordings.
# Name: abstract, dtype: object

# %% [markdown]
# #### Data Cleaning
#
# 1. Reformat date to datetime
# 2. Remove snippet
# 3. Remove rows with null/empty string values

# %%
# Reformat the date
df['pub_date'] = pd.to_datetime(df['pub_date']) 
df['pub_date'] = df['pub_date'].dt.date

# Remove snippet
df.drop(labels='snippet', inplace=True, axis=1)

# Remove null/empty string rows
df.replace('', np.nan, inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#      pub_date  \
# 0  2015-04-07
# 1  2015-04-14
# 2  2015-04-13
# 3  2015-04-22
# 4  2015-04-01
#
#                                                                                                                                                                                              abstract  \
# 0                                                    Want to work at Amazon, Apple or McKinsey? Some business schools have impressive records placing graduates in certain fields and even companies.
# 1  Get recommendations from New York Times reporters and editors, highlighting interesting stories from around the web. In this installment, great reads from Stacy Cowley, Quentin Hardy and others.
# 2  The business unit will partner with companies including Apple, Medtronic and Johnson & Johnson, offering IBM’s Watson technology as a cloud-based tool at many levels of the health care industry.
# 3                                                                   With superstars first in line, Apple appears to be seeking exclusivity by limiting where its watches are sold and who wears them.
# 4                                                 In an industry that avoids controversy, the heads of several prominent companies, including Apple and Salesforce.com, have chosen to pick a battle.
#
#                                                                                                                                                                                                                                                                                                                                                                               lead_para  \
# 0                                                                                                                                                                                                                                                                     With some 13,000 graduate schools of business across the globe, the M.B.A. degree has clearly become a commodity.
# 1                                                                                                                                                                                                             Get recommendations from New York Times reporters and editors, highlighting great stories from around the web. What We’re Reading emails are sent twice a week. Sign up »
# 2                                                                                                                                                                                                                     IBM is taking its Watson artificial-intelligence technology into health care in a big way with industry partners, a pair of acquisitions and an ambitious agenda.
# 3                                                                                                                                                                                                                                                                  Two weeks ago, Pharrell Williams posted an Instagram video of his Apple Watch. The clip has more than 119,000 likes.
# 4  The technology industry’s leaders have found their collective voice on a social issue in the last week, rallying with great intensity against a new Indiana law that will allow businesses, they predict, to discriminate against gay couples. The heads of Apple, Salesforce.com, Yelp and Square have all publicly criticized the law, as have some leaders from other industries.
#
#                                                           headline doc_type  \
# 0                M.B.A. Programs That Get You Where You Want to Go  article
# 1                                               What We’re Reading  article
# 2                IBM Creates Watson Health to Analyze Medical Data  article
# 3  What’s That on Beyoncé’s Wrist? Let Me Guess ... an Apple Watch  article
# 4   Daily Report: Tech Leaders Come Together to Oppose Indiana Law  article
#
#   section_name type_of_material rank  \
# 0    Education             News    7
# 1        Blogs             News   13
# 2   Technology             News    8
# 3        Style             News    1
# 4   Technology             News    3
#
#                                                                                                     web_url
# 0   https://www.nytimes.com/2015/04/12/education/edlife/mba-programs-that-get-you-where-you-want-to-go.html
# 1                                           https://news.blogs.nytimes.com/2015/04/14/what-were-reading-46/
# 2              https://bits.blogs.nytimes.com/2015/04/13/ibm-creates-watson-health-to-analyze-medical-data/
# 3    https://www.nytimes.com/2015/04/23/style/whats-that-on-beyonces-wrist-let-me-guess-an-apple-watch.html
# 4  https://bits.blogs.nytimes.com/2015/04/01/daily-report-tech-leaders-come-together-to-oppose-indiana-law/

# %%
# Checking df info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2124 entries, 0 to 2142
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pub_date          2124 non-null   object
#  1   abstract          2124 non-null   object
#  2   lead_para         2124 non-null   object
#  3   headline          2124 non-null   object
#  4   doc_type          2124 non-null   object
#  5   section_name      2124 non-null   object
#  6   type_of_material  2124 non-null   object
#  7   rank              2124 non-null   object
#  8   web_url           2124 non-null   object
# dtypes: object(9)
# memory usage: 165.9+ KB

# %%
# save data to csv
file_name = '{}_text_data'.format(company)
df.to_csv('../../data/cleaned/{}.csv'.format(file_name), index=False)

# check = pd.read_csv('../../data/cleaned/{}'.format(file_name))
# check
